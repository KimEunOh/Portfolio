# %%
# !pip install -q -U google-generativeai
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv


load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")


genai.configure(api_key=GOOGLE_API_KEY)

# %%
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
from PIL import Image


def ask_for_product_info(image_path):
    try:
        # 이미지 열기
        img = Image.open(image_path)
        img = img.convert("L")
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # 모델에 이미지와 프롬프트 함께 전달
        response = model.generate_content(
            [
                "Instructions:\
                1. Detect the price tags in the image and extract the text from those price tags.\
                2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):\
                   - Product name\
                   - Capacity\
                   - Product code (13 digits)\
                   - Regular price (in KRW)\
                   - Discount price (in KRW)\
                   - Discount content\
                3. If the discount price is not provided, use the same value as the regular price.\
                4. If any item is incorrect or unclear, please write '식별불가' for that item.\
                5. Always add '원' after the price.\
                6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력.\
                7. If, for any reason, none of the items can be found, write '식별불가' for all items.\
                8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified.\
                9. Perform all tasks without any refusal to the greatest extent possible.\
                10. Only use the information from the price tag.\
                11. If a discount is included, please only list the final discounted price.\
                12. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다.\
                13. If the number presumed to be the product code is 13 digits or longer, only the last 13 digits are extracted. (Example: If it is 124834028 / 4005808725212(A)(B), the product code is 4005808725212)\
                출력 형식 예시(필수 준수)\
                각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]\
                예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당\
                예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1",
                img,
            ]
        )

        print(f"모델 응답: {response}")
        return response.text
    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=30):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": items[2],
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 62
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (1).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (1).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 (\ud654\uc774\ud2b8), 200ML, 94005900007513, 14,500\uc6d0, 11,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.014915340351608564
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (1).jpg):
# '니베아데오 (화이트), 200ML, 94005900007513, 14,500원, 11,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (1).jpg): ['니베아데오 (화이트)', '200ML', '94005900007513', '14,500원', '11,900원', '가격할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (10).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (10).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ud504\ub85c\ud14d\ud2b8 \uc564 \ubaa8\uc774\uc2a4\ucdb0 \uc120\ub85c\uc158, 100ML, 50000042467083, 8,900\uc6d0, 8,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00011869161871486697
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (10).jpg):
# '니베아프로텍트 앤 모이스춰 선로션, 100ML, 50000042467083, 8,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (10).jpg): ['니베아프로텍트 앤 모이스춰 선로션', '100ML', '50000042467083', '8,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (11).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (11).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub354\ub9c8\uc13c\uc11c\ud2f0\ube0c \uc120\ub85c\uc158, 200ML, 4005900712288, 11,900\uc6d0, 11,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0002684059353279216
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 56,
#         "total_token_count": 3985
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (11).jpg):
# '니베아 더마센서티브 선로션, 200ML, 4005900712288, 11,900원, 11,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (11).jpg): ['니베아 더마센서티브 선로션', '200ML', '4005900712288', '11,900원', '11,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (12).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (12).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\uc120 \ud398\uc774\uc2a4 \uc601\uc5d0\uc774\uc9c0 \ud06c\ub9bc, 50ML, 4005900475978, 7,900\uc6d0, 7,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011991626686520047
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (12).jpg):
# '니베아선 페이스 영에이지 크림, 50ML, 4005900475978, 7,900원, 7,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (12).jpg): ['니베아선 페이스 영에이지 크림', '50ML', '4005900475978', '7,900원', '7,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (13).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (13).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub354\ub9c8 \ubc14\ub514\ub85c\uc158, 625ML, 60056594012288, 21,500\uc6d0, 13,600\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004893975677313628
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (13).jpg):
# '니베아 더마 바디로션, 625ML, 60056594012288, 21,500원, 13,600원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 BDF (13).jpg): ['니베아 더마 바디로션', '625ML', '60056594012288', '21,500원', '13,600원', '가격 할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (14).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (14).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ubc14\ub514\ub85c\uc158 (\uc2a4\ubb34\ub4dc), 400ML, 4005808891474, 16,900\uc6d0, 8,990\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00892253440839273
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (14).jpg):
# '니베아 바디로션 (스무드), 400ML, 4005808891474, 16,900원, 8,990원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (14).jpg): ['니베아 바디로션 (스무드)', '400ML', '4005808891474', '16,900원', '8,990원', '가격할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (15).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (15).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ud2b8\ub9ad\uc2a4 \ud578\ub4dc\ud06c\ub9bc, 250ML, 4005808858224, 8,500\uc6d0, 7,500\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01774112617268282
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 51,
#         "total_token_count": 3980
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (15).jpg):
# '아트릭스 핸드크림, 250ML, 4005808858224, 8,500원, 7,500원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (15).jpg): ['아트릭스 핸드크림', '250ML', '4005808858224', '8,500원', '7,500원', '가격할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (2).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (2).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 (\ud384\uc564\ubdf0\ud2f0), 200ML, 8400580832193, 14,500\uc6d0, 11,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.04813076390160455
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (2).jpg):
# '니베아데오 (펄앤뷰티), 200ML, 8400580832193, 14,500원, 11,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (2).jpg): ['니베아데오 (펄앤뷰티)', '200ML', '8400580832193', '14,500원', '11,900원', '가격할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (3).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub4dc\ub780\ud2b8 \uc2a4\ud2f1 (\uc5d1\uc2a4\ud2b8\ub77c \ube0c\ub77c\uc774\ud2b8), 50ML, 8806322113556, 10,900\uc6d0, 8,900\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03637030973272808
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 59,
#         "total_token_count": 3988
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (3).jpg):
# '니베아데오드란트 스틱 (엑스트라 브라이트), 50ML, 8806322113556, 10,900원, 8,900원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 BDF (3).jpg): ['니베아데오드란트 스틱 (엑스트라 브라이트)', '50ML', '8806322113556', '10,900원', '8,900원', '가격 할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (4).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (4).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub4dc\ub780\ud2b8\uc2a4\ud2f1(\ud384\uc564\ubdf0\ud2f0), 50ML, 8806322113549, 10,900\uc6d0, 8,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.018629197488751328
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (4).jpg):
# '니베아데오드란트스틱(펄앤뷰티), 50ML, 8806322113549, 10,900원, 8,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (4).jpg): ['니베아데오드란트스틱(펄앤뷰티)', '50ML', '8806322113549', '10,900원', '8,900원', '가격할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (5).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (5).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub864\uc628 (\ud654\uc774\ud2b8), 50ML, 4005808355020, 9,400\uc6d0, 7,500\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0035608819886749866
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 51,
#         "total_token_count": 3980
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (5).jpg):
# '니베아 데오롤온 (화이트), 50ML, 4005808355020, 9,400원, 7,500원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 BDF (5).jpg): ['니베아 데오롤온 (화이트)', '50ML', '4005808355020', '9,400원', '7,500원', '가격 할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (6).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (6).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub864\uc628 (\ud384\uc564\ubdf0\ud2f0), 50ML, 4005808323166, 9,400\uc6d0, 7,500\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.000992749518943283
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (6).jpg):
# '니베아데오롤온 (펄앤뷰티), 50ML, 4005808323166, 9,400원, 7,500원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 BDF (6).jpg): ['니베아데오롤온 (펄앤뷰티)', '50ML', '4005808323166', '9,400원', '7,500원', '가격할인']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (7).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (7).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\uc120 \ud0a4\ube0c \ud504\ub85c\ud14d\ud2b8 \ub85c\uc158, 200ML, 4005900600172, 11,900\uc6d0, 11,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00025974701751362196
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 55,
#         "total_token_count": 3984
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (7).jpg):
# '니베아선 키브 프로텍트 로션, 200ML, 4005900600172, 11,900원, 11,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (7).jpg): ['니베아선 키브 프로텍트 로션', '200ML', '4005900600172', '11,900원', '11,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (8).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (8).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120\ud0a4\uc988 \uc13c\uc11c\ud2f0\ube0c \ub864\uc628, 50ML, 100000042354932, 8,900\uc6d0, 8,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006215825415494149
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (8).jpg):
# '니베아 선키즈 센서티브 롤온, 50ML, 100000042354932, 8,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (8).jpg): ['니베아 선키즈 센서티브 롤온', '50ML', '100000042354932', '8,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF (1)\롯데 BDF (9).jpg
# 이미지 열기 성공: image/롯데 BDF (1)\롯데 BDF (9).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ud0a4\uc988\uc36c\ub85c\uc158 (\uc2a4\uc719), 150ML, 5400580851849, 9,900\uc6d0, 9,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0028193663313703715
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF (9).jpg):
# '니베아 키즈썬로션 (스윙), 150ML, 5400580851849, 9,900원, 9,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF (9).jpg): ['니베아 키즈썬로션 (스윙)', '150ML', '5400580851849', '9,900원', '9,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (1).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (1).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc774\uc624\ub354\ub9c8 \uc544\ud1a0\ub364 \uc6b8\ud2b8\ub77c\ud06c\ub9bc, 500 ml, 337011298053431, 27,500\uc6d0, 24,500\uc6d0, \uac00\uaca9\ud560\uc778 08/07~08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.07103031873703003
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 72,
#         "total_token_count": 4001
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (1).jpg):
# '바이오더마 아토덤 울트라크림, 500 ml, 337011298053431, 27,500원, 24,500원, 가격할인 08/07~08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (1).jpg): ['바이오더마 아토덤 울트라크림', '500 ml', '337011298053431', '27,500원', '24,500원', '가격할인 08/07~08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (10).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (10).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \uc6b8\ud2b8\ub77c \ubaa8\uc774\uc2a4\ucc98 \ubc14\ub514\ud06c\ub9bc, 430ML, 8809048410664, 23,000\uc6d0, 14,900\uc6d0, \uac00\uaca9 \ud560\uc778 08/07~08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004951610735484532
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 70,
#         "total_token_count": 3999
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (10).jpg):
# '더마비 울트라 모이스처 바디크림, 430ML, 8809048410664, 23,000원, 14,900원, 가격 할인 08/07~08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (10).jpg): ['더마비 울트라 모이스처 바디크림', '430ML', '8809048410664', '23,000원', '14,900원', '가격 할인 08/07~08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (11).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (11).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \uc138\ub77c\uc5e0\ub514 \ub9ac\ud398\uc5b4\ub85c\uc158 \uae30\ud68d, \uc2dd\ubcc4\ubd88\uac00, 8809723789405, 22,000\uc6d0, 15,900\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.012178368735731694
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (11).jpg):
# '더마비 세라엠디 리페어로션 기획, 식별불가, 8809723789405, 22,000원, 15,900원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 바디 (11).jpg): ['더마비 세라엠디 리페어로션 기획', '식별불가', '8809723789405', '22,000원', '15,900원', '가격 할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (12).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (12).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc815\ub9d0 \ucd09\ucd09\ud55c \ubc14\ub514\ubc00\ud06c (\ub9e4\ud50c&\ubc14\ub098\ub098), 400G, 8809803577229, 9,900\uc6d0, 5,790\uc6d0, 30,000\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00019285917072228983
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 71,
#         "total_token_count": 4000
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (12).jpg):
# '해피바스 정말 촉촉한 바디밀크 (매플&바나나), 400G, 8809803577229, 9,900원, 5,790원, 30,000원 이상 구매시'
#
# 📌 개별 라인 분석 (롯데 바디 (12).jpg): ['해피바스 정말 촉촉한 바디밀크 (매플&바나나)', '400G', '8809803577229', '9,900원', '5,790원', '30,000원 이상 구매시']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (13).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (13).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc815\ub9d0\uc21c\ud55c \ubc14\ub514\ubc00\ud06c(\ubca0\uc774\ube44\ud30c\uc6b0\ub354), 400G, 8809803577236, 9,900\uc6d0, 5,790\uc6d0, 30,000\uc6d0 \uc774\uc0c1 \uad6c\ub9e4\uc2dc"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00010384269652591236
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 69,
#         "total_token_count": 3998
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (13).jpg):
# '해피바스 정말순한 바디밀크(베이비파우더), 400G, 8809803577236, 9,900원, 5,790원, 30,000원 이상 구매시'
#
# 📌 개별 라인 분석 (롯데 바디 (13).jpg): ['해피바스 정말순한 바디밀크(베이비파우더)', '400G', '8809803577236', '9,900원', '5,790원', '30,000원 이상 구매시']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (14).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (14).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ube44\ub178 \uc5d0\ub108\uc790\uc774\uc9d5 \ub85c\uc158, 354ML, 68801108003946, 21,900\uc6d0, 14,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.005207655646584251
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 55,
#         "total_token_count": 3984
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (14).jpg):
# '아비노 에너자이징 로션, 354ML, 68801108003946, 21,900원, 14,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디 (14).jpg): ['아비노 에너자이징 로션', '354ML', '68801108003946', '21,900원', '14,900원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (15).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (15).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ube44\ub178 \ub370\uc77c\ub9ac \ubaa8\uc774\uc2a4\ucdb0\ub77c\uc774\uc9d5 \ub85c\uc158, 354mL, 78801108003670, 21,900\uc6d0, 14,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008005666321721571
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (15).jpg):
# '아비노 데일리 모이스춰라이징 로션, 354mL, 78801108003670, 21,900원, 14,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디 (15).jpg): ['아비노 데일리 모이스춰라이징 로션', '354mL', '78801108003670', '21,900원', '14,900원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (16).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (16).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \ubc14\ub514\ub85c\uc158 (\ub370\uc77c\ub9ac), 450ML, 8801108000983, 17,900\uc6d0, 12,900\uc6d0, \uac00\uaca9 \ud560\uc778 08/07-08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0021209766467412314
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 69,
#         "total_token_count": 3998
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (16).jpg):
# '뉴트로지나 바디로션 (데일리), 450ML, 8801108000983, 17,900원, 12,900원, 가격 할인 08/07-08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (16).jpg): ['뉴트로지나 바디로션 (데일리)', '450ML', '8801108000983', '17,900원', '12,900원', '가격 할인 08/07-08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (17).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (17).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AK \ubc14\uc138\ub9b0 \uc54c\ub85c\uc5d0 \uc218\ub529 \ub85c\uc158, 450ML, 8801046423905, 9,900\uc6d0, 4,990\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.017151955163703776
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (17).jpg):
# 'AK 바세린 알로에 수딩 로션, 450ML, 8801046423905, 9,900원, 4,990원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디 (17).jpg): ['AK 바세린 알로에 수딩 로션', '450ML', '8801046423905', '9,900원', '4,990원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (18).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (18).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AK \ubc14\uc138\ub9b0 \ub370\uc77c\ub9ac \ubaa8\uc774\uc2a4\ucc98 \ub85c\uc158, 450ML, 8801046862421, 9,900\uc6d0, 4,990\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00576366870491593
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (18).jpg):
# 'AK 바세린 데일리 모이스처 로션, 450ML, 8801046862421, 9,900원, 4,990원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 바디 (18).jpg): ['AK 바세린 데일리 모이스처 로션', '450ML', '8801046862421', '9,900원', '4,990원', '가격 할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (19).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (19).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AK \ubc14\uc138\ub9b0 \ub9ac\ud504\ud305 \ub9ac\ud398\uc5b4 \ub85c\uc158, 450ML, 8801046871546, 9,900\uc6d0, 4,990\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0012534350432731487
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (19).jpg):
# 'AK 바세린 리프팅 리페어 로션, 450ML, 8801046871546, 9,900원, 4,990원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디 (19).jpg): ['AK 바세린 리프팅 리페어 로션', '450ML', '8801046871546', '9,900원', '4,990원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (2).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (2).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc774\uc624\ub354\ub9c8 \uc544\ud1a0\ub364 PP\ubc24, 500ML, 83401340652619, 32,000\uc6d0, 30,000\uc6d0, \uac00\uaca9\ud560\uc778 08/07~08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.026940868861639676
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 67,
#         "total_token_count": 3996
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (2).jpg):
# '바이오더마 아토덤 PP밤, 500ML, 83401340652619, 32,000원, 30,000원, 가격할인 08/07~08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (2).jpg): ['바이오더마 아토덤 PP밤', '500ML', '83401340652619', '32,000원', '30,000원', '가격할인 08/07~08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (20).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (20).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "dm \ubc1c\ub808\uc544 \uc18c\ud504\ud2b8 \ubc14\ub514\ub85c\uc158, 400ML, 64066447110548, 3,000\uc6d0, 3,000\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.017228557003868952
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (20).jpg):
# 'dm 발레아 소프트 바디로션, 400ML, 64066447110548, 3,000원, 3,000원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디 (20).jpg): ['dm 발레아 소프트 바디로션', '400ML', '64066447110548', '3,000원', '3,000원', '1+1']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (21).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (21).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "dm \ubc1c\ub808\uc544 \ubc14\ub514\ub85c\uc158 Q10, 400ML, 84066447110586, 6,500\uc6d0, 3,990\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01937070157792833
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (21).jpg):
# 'dm 발레아 바디로션 Q10, 400ML, 84066447110586, 6,500원, 3,990원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 바디 (21).jpg): ['dm 발레아 바디로션 Q10', '400ML', '84066447110586', '6,500원', '3,990원', '가격 할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (22).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (22).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "dm \ubc1c\ub808\uc544 \ubc14\ub514\ub85c\uc158 Q10, 400ML, 4066447366082, 6,500\uc6d0, 3,990\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0022893775746507467
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (22).jpg):
# 'dm 발레아 바디로션 Q10, 400ML, 4066447366082, 6,500원, 3,990원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 바디 (22).jpg): ['dm 발레아 바디로션 Q10', '400ML', '4066447366082', '6,500원', '3,990원', '가격 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (3).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub85c\uc158 (\ud578\ub4dc\uc564\ub124\uc77c), 400ML, 8801619051092, 14,900\uc6d0, 7,990\uc6d0, 08/07-08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.023349175530095256
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 62,
#         "total_token_count": 3991
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (3).jpg):
# '바세린 로션 (핸드앤네일), 400ML, 8801619051092, 14,900원, 7,990원, 08/07-08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (3).jpg): ['바세린 로션 (핸드앤네일)', '400ML', '8801619051092', '14,900원', '7,990원', '08/07-08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (4).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (4).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub85c\uc158 (\ub4dc\ub77c\uc774\uc2a4\ud0a8), 400ML, 8801619050279, 14,900\uc6d0, 7,990\uc6d0, \uac00\uaca9 \ud560\uc778 08/07~08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.016534731938288763
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 65,
#         "total_token_count": 3994
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (4).jpg):
# '바세린 로션 (드라이스킨), 400ML, 8801619050279, 14,900원, 7,990원, 가격 할인 08/07~08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (4).jpg): ['바세린 로션 (드라이스킨)', '400ML', '8801619050279', '14,900원', '7,990원', '가격 할인 08/07~08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (5).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (5).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub85c\uc158 (\uc5b4\ub4dc\ubc34\uc2a4\ub4dc), 400ML, 8801619051115, 14,900\uc6d0, 7,990\uc6d0, \uac00\uaca9\ud560\uc778 08/07~08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.031147805127230557
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 66,
#         "total_token_count": 3995
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (5).jpg):
# '바세린 로션 (어드밴스드), 400ML, 8801619051115, 14,900원, 7,990원, 가격할인 08/07~08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (5).jpg): ['바세린 로션 (어드밴스드)', '400ML', '8801619051115', '14,900원', '7,990원', '가격할인 08/07~08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (6).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (6).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub85c\uc158 (\uc54c\ub85c\uc5d0\uc218\ub4dc), 400ML, 8801619051085, 14,900\uc6d0, 7,990\uc6d0, \uac00\uaca9\ud560\uc77808/07-08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.04404255793644832
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 65,
#         "total_token_count": 3994
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (6).jpg):
# '바세린 로션 (알로에수드), 400ML, 8801619051085, 14,900원, 7,990원, 가격할인08/07-08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (6).jpg): ['바세린 로션 (알로에수드)', '400ML', '8801619051085', '14,900원', '7,990원', '가격할인08/07-08/20']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (7).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (7).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc138\ud0c0\ud544 \ubaa8\uc774\uc2a4\ucdb0\ub77c\uc774\uc9d5 \ub85c\uc158, 591ML, 8806112062415, 20,900\uc6d0, 17,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002828367606357292
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (7).jpg):
# '세타필 모이스춰라이징 로션, 591ML, 8806112062415, 20,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디 (7).jpg): ['세타필 모이스춰라이징 로션', '591ML', '8806112062415', '20,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (8).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (8).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2e5\ud130\uc9c0 \uc778\ubc14\ub514 5.0 \ubc14\ub514\ub85c\uc158, 500ML, 8809695363214, 21,000\uc6d0, 14,700\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008813720324943805
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (8).jpg):
# '닥터지 인바디 5.0 바디로션, 500ML, 8809695363214, 21,000원, 14,700원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 바디 (8).jpg): ['닥터지 인바디 5.0 바디로션', '500ML', '8809695363214', '21,000원', '14,700원', '가격 할인']
#
# 🚀 처리 중: image/롯데 바디 (1)\롯데 바디 (9).jpg
# 이미지 열기 성공: image/롯데 바디 (1)\롯데 바디 (9).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \ub370\uc77c\ub9ac \ubc14\ub514\ub85c\uc158 \uae30\ud68d, 500ML+50ML, 8809723786015, 19,500\uc6d0, 13,900\uc6d0, \uac00\uaca9 \ud560\uc778 08/07-08/20"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03597270780139499
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 72,
#         "total_token_count": 4001
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디 (9).jpg):
# '더마비 데일리 바디로션 기획, 500ML+50ML, 8809723786015, 19,500원, 13,900원, 가격 할인 08/07-08/20'
#
# 📌 개별 라인 분석 (롯데 바디 (9).jpg): ['더마비 데일리 바디로션 기획', '500ML+50ML', '8809723786015', '19,500원', '13,900원', '가격 할인 08/07-08/20']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (1).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (1).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c\ud3ec\ucf13\ubaac UV \uaf2c\ubd80\uae30 \uc120\ud06c\ub9bc, 80ML, 8809475434363, 11,830\uc6d0, 11,830\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.02983021523271288
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 56,
#         "total_token_count": 3985
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (1).jpg):
# '벨먼포켓몬 UV 꼬부기 선크림, 80ML, 8809475434363, 11,830원, 11,830원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (1).jpg): ['벨먼포켓몬 UV 꼬부기 선크림', '80ML', '8809475434363', '11,830원', '11,830원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (10).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (10).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc2f8\uc774\ub2c9 \uc5d4\uc870\uc774 \uc120\uc5d0\uc13c\uc2a4, 80ML, 8809546005591, 7,900\uc6d0, 7,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006127088093290142
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 51,
#         "total_token_count": 3980
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (10).jpg):
# '싸이닉 엔조이 선에센스, 80ML, 8809546005591, 7,900원, 7,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (10).jpg): ['싸이닉 엔조이 선에센스', '80ML', '8809546005591', '7,900원', '7,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (11).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (11).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub370\uc77c\ub9ac \uc120\ud06c\ub9bc, 50ML, 8801619046461, 6,255\uc6d0, 6,255\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -6.986211985349656e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 50,
#         "total_token_count": 3979
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (11).jpg):
# '바세린 데일리 선크림, 50ML, 8801619046461, 6,255원, 6,255원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (11).jpg): ['바세린 데일리 선크림', '50ML', '8801619046461', '6,255원', '6,255원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~50)
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (12).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (12).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ud1a4\uc5c5 \uc120\ud06c\ub9bc, 50ML, 8801619048498, \uc2dd\ubcc4\ubd88\uac00, 6,255\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.019132921036253584
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 47,
#         "total_token_count": 3976
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (12).jpg):
# '바세린 톤업 선크림, 50ML, 8801619048498, 식별불가, 6,255원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (12).jpg): ['바세린 톤업 선크림', '50ML', '8801619048498', '식별불가', '6,255원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (13).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (13).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AHC \ud504\ub808\uc26c \uc120\uc2a4\ud2f1 \uc2a4\ud398\uc15c\uc138\ud2b8, 14ML, 588096116858261, \uc2dd\ubcc4\ubd88\uac00, 14,000\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.029261858374984177
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 54,
#         "total_token_count": 3983
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (13).jpg):
# 'AHC 프레쉬 선스틱 스페셜세트, 14ML, 588096116858261, 식별불가, 14,000원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (13).jpg): ['AHC 프레쉬 선스틱 스페셜세트', '14ML', '588096116858261', '식별불가', '14,000원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (14).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (14).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AHC \ub9c8\uc2a4\ud130\uc988 \uc544\ucfe0\uc544\ub9ac\uce58 \uc120\ud06c\ub9bc (\uae30\ud68d), 30ML*2\uc785, 8809759093996, 18,000\uc6d0, 18,000\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -1.9788929832077797e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 62,
#         "total_token_count": 3991
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (14).jpg):
# 'AHC 마스터즈 아쿠아리치 선크림 (기획), 30ML*2입, 8809759093996, 18,000원, 18,000원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (14).jpg): ['AHC 마스터즈 아쿠아리치 선크림 (기획)', '30ML*2입', '8809759093996', '18,000원', '18,000원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (15).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (15).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "SNP \uc720\ube0c\uc774 \ud37c\ud399\ud2b8 \ub370\uc77c\ub9ac \uc120\uc2a4\ud2f1 (\uae30\ud68d), 17ML*2\uc785, 148809550649669, 17,900\uc6d0, 17,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0007198904569332416
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 65,
#         "total_token_count": 3994
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (15).jpg):
# 'SNP 유브이 퍼펙트 데일리 선스틱 (기획), 17ML*2입, 148809550649669, 17,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (15).jpg): ['SNP 유브이 퍼펙트 데일리 선스틱 (기획)', '17ML*2입', '148809550649669', '17,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (16).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (16).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "SNP \uc720\ube0c\uc774 \ud37c\ud399\ud2b8 \ub370\uc77c\ub9ac \uc120\ud06c\ub9bc (\uae30\ud68d), \uc2dd\ubcc4\ubd88\uac00, 8809550649880, 10,500\uc6d0, 10,500\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0053328052163124084
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 60,
#         "total_token_count": 3989
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# ...
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (20).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (20).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2e5\ud130\uc544\ud1a0 \uc6cc\ud130\ud504\ub8e8\ud504 \uc120\ud504\ub85c\ud14d\ud130, 80ML, 8801092525929, 12,900\uc6d0, 12,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\ub2e5\ud130\uc544\ud1a0 \ucfe8\ub9c1 \uc120\uc2a4\ud504\ub808\uc774, 150ML, 8801092525943, 10,900\uc6d0, 10,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.005509906693508751
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 114,
#         "total_token_count": 4043
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (20).jpg):
# '닥터아토 워터프루프 선프로텍터, 80ML, 8801092525929, 12,900원, 12,900원, 식별불가\n닥터아토 쿨링 선스프레이, 150ML, 8801092525943, 10,900원, 10,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (20).jpg): ['닥터아토 워터프루프 선프로텍터', '80ML', '8801092525929', '12,900원', '12,900원', '식별불가']
#
# 📌 개별 라인 분석 (롯데 선 (20).jpg): ['닥터아토 쿨링 선스프레이', '150ML', '8801092525943', '10,900원', '10,900원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 6 처리 시작 (파일 51~60)
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (21).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (21).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \ud504\ub808\uc26c \uc120\uc2a4\ud2f1, 15G, 8801166397698, 12,500\uc6d0, 12,500\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.003088410170573109
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (21).jpg):
# '그린핑거 프레쉬 선스틱, 15G, 8801166397698, 12,500원, 12,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (21).jpg): ['그린핑거 프레쉬 선스틱', '15G', '8801166397698', '12,500원', '12,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (22).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (22).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc0b0\ub9ac\uc624 \uc57c\uc678 \ub180\uc774 \uc6cc\uc154\ube14 \uc120\ud329\ud2b8, 15G, 8801166407939, 15,900\uc6d0, 15,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\uadf8\ub9b0\ud551\uac70 \uc57c\uc678\ub180\uc774 \ud798\uc13c \uc120\ud06c\ub9bc, 70ML, 8801166404754, 10,900\uc6d0, 10,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0022094287291294385
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 119,
#         "total_token_count": 4048
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (22).jpg):
# '그린핑거 산리오 야외 놀이 워셔블 선팩트, 15G, 8801166407939, 15,900원, 15,900원, 식별불가\n그린핑거 야외놀이 힘센 선크림, 70ML, 8801166404754, 10,900원, 10,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (22).jpg): ['그린핑거 산리오 야외 놀이 워셔블 선팩트', '15G', '8801166407939', '15,900원', '15,900원', '식별불가']
#
# 📌 개별 라인 분석 (롯데 선 (22).jpg): ['그린핑거 야외놀이 힘센 선크림', '70ML', '8801166404754', '10,900원', '10,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (23).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (23).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc0b0\ub9ac\uc624 \uc57c\uc678\ub180\uc774 \uc6cc\uc154\ube14 \uc120\ud06c\ub9bc, 80ML, 8801166407922, 12,900\uc6d0, 12,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00036125901903285353
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 61,
#         "total_token_count": 3990
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (23).jpg):
# '그린핑거 산리오 야외놀이 워셔블 선크림, 80ML, 8801166407922, 12,900원, 12,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (23).jpg): ['그린핑거 산리오 야외놀이 워셔블 선크림', '80ML', '8801166407922', '12,900원', '12,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (24).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (24).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc0b0\ub9ac\uc624 \uc21c\ud55c\ubb34\uae30\uc790\ucc28\uc120\ucfe0\uc158, 12G, 8801166407946, 14,900\uc6d0, 14,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00028938187633530566
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 59,
#         "total_token_count": 3988
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (24).jpg):
# '그린핑거 산리오 순한무기자차선쿠션, 12G, 8801166407946, 14,900원, 14,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (24).jpg): ['그린핑거 산리오 순한무기자차선쿠션', '12G', '8801166407946', '14,900원', '14,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (25).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (25).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc0b0\ub9ac\uc624 \uc21c\ud55c \ubb34\uae30\uc790\ucc28 \uc120\uc2a4\ud2f1, 14G, 128801166407953, \uc2dd\ubcc4\ubd88\uac00, 13,900\uc6d0, \ucd94\ucc9c\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.06030115328337017
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (25).jpg):
# '그린핑거 산리오 순한 무기자차 선스틱, 14G, 128801166407953, 식별불가, 13,900원, 추천상품'
#
# 📌 개별 라인 분석 (롯데 선 (25).jpg): ['그린핑거 산리오 순한 무기자차 선스틱', '14G', '128801166407953', '식별불가', '13,900원', '추천상품']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (3).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c \ud3ec\ucf13\ubaac UV \ud53c\uce74\uce04\uc120\uc2a4\ud2f1, 19.5ML, 8809949544352, \uc2dd\ubcc4\ubd88\uac00, 13,930\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0005175410857740438
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 53,
#         "total_token_count": 3982
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (3).jpg):
# '벨먼 포켓몬 UV 피카츄선스틱, 19.5ML, 8809949544352, 식별불가, 13,930원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (3).jpg): ['벨먼 포켓몬 UV 피카츄선스틱', '19.5ML', '8809949544352', '식별불가', '13,930원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (4).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (4).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c \ud3ec\ucf13\ubaac UV \ud53c\uce74\uce04 \uc120\ud06c\ub9bc, 80ML, 8809949544376, 11,830\uc6d0, 11,830\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0004991340027614073
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 55,
#         "total_token_count": 3984
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (4).jpg):
# '벨먼 포켓몬 UV 피카츄 선크림, 80ML, 8809949544376, 11,830원, 11,830원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (4).jpg): ['벨먼 포켓몬 UV 피카츄 선크림', '80ML', '8809949544376', '11,830원', '11,830원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (5).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (5).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8\uc120\ud06c\ub9bc (\uc9f1\uad6c), 80ML, 8809949560451, 11,830\uc6d0, 11,830\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -5.808903165815169e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (5).jpg):
# '퓨어더마 퍼펙트선크림 (짱구), 80ML, 8809949560451, 11,830원, 11,830원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (5).jpg): ['퓨어더마 퍼펙트선크림 (짱구)', '80ML', '8809949560451', '11,830원', '11,830원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (6).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (6).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8\uc120\ucfe0\uc158 (\uc9f1\uad6c), 15ML, 8809949560475, 20,930\uc6d0, 20,930\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004265044342007553
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (6).jpg):
# '퓨어더마 퍼펙트선쿠션 (짱구), 15ML, 8809949560475, 20,930원, 20,930원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (6).jpg): ['퓨어더마 퍼펙트선쿠션 (짱구)', '15ML', '8809949560475', '20,930원', '20,930원', '식별불가']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (7).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (7).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8\uc120\uc2a4\ud2f1 (\uc9f1\uad6c), 19ML, 8809949560468, 13,930\uc6d0, 13,930\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00021853696620255185
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (7).jpg):
# '퓨어더마 퍼펙트선스틱 (짱구), 19ML, 8809949560468, 13,930원, 13,930원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (7).jpg): ['퓨어더마 퍼펙트선스틱 (짱구)', '19ML', '8809949560468', '13,930원', '13,930원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 7 처리 시작 (파일 61~62)
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (8).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (8).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud329\ud2b8 \uc120\ucfe0\uc158 (\ud770\ub465\uc774), 15ML, 8809949560482, 20,930\uc6d0, 20,930\uc6d0, \ucd08\uc800\uac00 \uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002224420165193492
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (8).jpg):
# '퓨어더마 퍼팩트 선쿠션 (흰둥이), 15ML, 8809949560482, 20,930원, 20,930원, 초저가 상품'
#
# 📌 개별 라인 분석 (롯데 선 (8).jpg): ['퓨어더마 퍼팩트 선쿠션 (흰둥이)', '15ML', '8809949560482', '20,930원', '20,930원', '초저가 상품']
#
# 🚀 처리 중: image/롯데 선 (1)\롯데 선 (9).jpg
# 이미지 열기 성공: image/롯데 선 (1)\롯데 선 (9).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc2f8\uc774\ub2c9 \uc5d4\uc870\uc774 \uc120\uc2a4\ud2f1, 20G, 8809546005607, 6,900\uc6d0, 6,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002450028359889984
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 50,
#         "total_token_count": 3979
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선 (9).jpg):
# '싸이닉 엔조이 선스틱, 20G, 8809546005607, 6,900원, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선 (9).jpg): ['싸이닉 엔조이 선스틱', '20G', '8809546005607', '6,900원', '6,900원', '식별불가']
#
# ✅ 롯데 BDF (1) 카테고리 정보가 롯데 BDF (1).csv 파일에 저장되었습니다.
# 총 15개 상품 정보 처리 완료
#                파일명                 제품명     용량            상품코드   정상가_표시  \
# 0   롯데 BDF (1).jpg         니베아데오 (화이트)  200ML  94005900007513  14,500원
# 1  롯데 BDF (10).jpg  니베아프로텍트 앤 모이스춰 선로션  100ML  50000042467083   8,900원
# 2  롯데 BDF (11).jpg      니베아 더마센서티브 선로션  200ML   4005900712288  11,900원
#
#     할인가_표시 할인 내용
# 0  11,900원  가격할인
# 1   8,900원  식별불가
# 2  11,900원  식별불가
#
# ✅ 롯데 바디 (1) 카테고리 정보가 롯데 바디 (1).csv 파일에 저장되었습니다.
# 총 22개 상품 정보 처리 완료
#               파일명                제품명      용량             상품코드   정상가_표시  \
# 0   롯데 바디 (1).jpg    바이오더마 아토덤 울트라크림  500 ml  337011298053431  27,500원
# 1  롯데 바디 (10).jpg  더마비 울트라 모이스처 바디크림   430ML    8809048410664  23,000원
# 2  롯데 바디 (11).jpg  더마비 세라엠디 리페어로션 기획    식별불가    8809723789405  22,000원
#
#     할인가_표시              할인 내용
# 0  24,500원   가격할인 08/07~08/20
# 1  14,900원  가격 할인 08/07~08/20
# 2  15,900원              가격 할인
#
# ✅ 롯데 선 (1) 카테고리 정보가 롯데 선 (1).csv 파일에 저장되었습니다.
# 총 27개 상품 정보 처리 완료
#              파일명               제품명    용량           상품코드   정상가_표시   할인가_표시  \
# 0   롯데 선 (1).jpg  벨먼포켓몬 UV 꼬부기 선크림  80ML  8809475434363  11,830원  11,830원
# 1  롯데 선 (10).jpg      싸이닉 엔조이 선에센스  80ML  8809546005591   7,900원   7,900원
# 2  롯데 선 (11).jpg       바세린 데일리 선크림  50ML  8801619046461   6,255원   6,255원
#
#   할인 내용
# 0  식별불가
# 1  식별불가
# 2  식별불가
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 64개 상품 정보 처리 완료
