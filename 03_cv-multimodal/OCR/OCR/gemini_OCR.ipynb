# %%
# !pip install -q -U google-generativeai
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv


load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")


genai.configure(api_key=GOOGLE_API_KEY)

# %%
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
from PIL import Image


def ask_for_product_info(image_path):
    try:
        # 이미지 열기
        img = Image.open(image_path)
        img = img.convert("L")
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # 모델에 이미지와 프롬프트 함께 전달
        response = model.generate_content(
            [
                "Instructions:\
                1. Detect the price tags in the image and extract the text from those price tags.\
                2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):\
                   - Product name\
                   - Capacity\
                   - Product code (13 digits)\
                   - Regular price (in KRW)\
                   - Discount price (in KRW)\
                   - Discount content\
                3. If the discount price is not provided, use the same value as the regular price.\
                4. If any item is incorrect or unclear, please write '식별불가' for that item.\
                5. Always add '원' after the price.\
                6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력.\
                7. If, for any reason, none of the items can be found, write '식별불가' for all items.\
                8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified.\
                9. Perform all tasks without any refusal to the greatest extent possible.\
                10. Only use the information from the price tag.\
                11. If a discount is included, please only list the final discounted price.\
                12. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다.\
                13. If the number presumed to be the product code is 13 digits or longer, only the last 13 digits are extracted. (Example: If it is 124834028 / 4005808725212(A)(B), the product code is 4005808725212)\
                출력 형식 예시(필수 준수)\
                각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]\
                예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당\
                예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1",
                img,
            ]
        )

        print(f"모델 응답: {response}")
        return response.text
    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=30):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": items[2],
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 99
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (1).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (1).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc2a4\ubb34\ub4dc \ubc14\ub514 \ub85c\uc158, 400ml, 4005808891474, 16,900\uc6d0, 16,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.030814312122486257
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (1).jpg):
# '니베아 스무드 바디 로션, 400ml, 4005808891474, 16,900원, 16,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (1).jpg): ['니베아 스무드 바디 로션', '400ml', '4005808891474', '16,900원', '16,900원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (10).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (10).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ud504\ub85c\ud14d\ud2b8 \ub9e8 \ubaa8\uc774\uc2a4\ucdb0 \uc120 \ub85c\uc158, 100ml\ub2f9, 0000042467083, 17,800\uc6d0, 17,800\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.020148553450902305
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (10).jpg):
# '니베아 선 프로텍트 맨 모이스춰 선 로션, 100ml당, 0000042467083, 17,800원, 17,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (10).jpg): ['니베아 선 프로텍트 맨 모이스춰 선 로션', '100ml당', '0000042467083', '17,800원', '17,800원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (11).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (11).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ub124\uc544 \ud0a4\uc988 \uc6b8\ud2b8\ub77c \ud504\ub85c\uc81d\ud2b8 \ub85c\uc158, 150ml, 4005808518494, 19,800\uc6d0, 19,800\uc6d0, 1+1\n\ub2c8\ub124\uc544 \uc6b8\ud2b8\ub77c \ud1a4\uc11c\ud2f0\ube0c \uc120\ub85c\uc158, 200ml, \uc2dd\ubcc4\ubd88\uac00, 23,800\uc6d0, 23,800\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.036084124335536254
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 108,
#         "total_token_count": 3005
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (11).jpg):
# '니네아 키즈 울트라 프로젝트 로션, 150ml, 4005808518494, 19,800원, 19,800원, 1+1\n니네아 울트라 톤서티브 선로션, 200ml, 식별불가, 23,800원, 23,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (11).jpg): ['니네아 키즈 울트라 프로젝트 로션', '150ml', '4005808518494', '19,800원', '19,800원', '1+1']
#
# 📌 개별 라인 분석 (이마트 BDF(!) (11).jpg): ['니네아 울트라 톤서티브 선로션', '200ml', '식별불가', '23,800원', '23,800원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (12).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (12).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624 \ub864\uc628 \ub4dc\ub77c\uc774\ucef4\ud3ec\ud2b8 50ml, 50ml, 4005808725212, 7,520\uc6d0, 7,520\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006872305582309592
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 58,
#         "total_token_count": 2955
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (12).jpg):
# '니베아 데오 롤온 드라이컴포트 50ml, 50ml, 4005808725212, 7,520원, 7,520원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (12).jpg): ['니베아 데오 롤온 드라이컴포트 50ml', '50ml', '4005808725212', '7,520원', '7,520원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (13).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (13).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub4dc\ub780\ud2b8 \ub864\uc628 \ub354\ub9c8 \ucee8\ud2b8\ub864 \ud4e8\uc5b4, \uc2dd\ubcc4\ubd88\uac00, 4005808676590, 8,940\uc6d0, 8,900\uc6d0, \ud560\uc778 \uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01978758374849955
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (13).jpg):
# '니베아 데오드란트 롤온 더마 컨트롤 퓨어, 식별불가, 4005808676590, 8,940원, 8,900원, 할인 상품'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (13).jpg): ['니베아 데오드란트 롤온 더마 컨트롤 퓨어', '식별불가', '4005808676590', '8,940원', '8,900원', '할인 상품']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (14).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (14).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub4dc\ub780\ud2b8 \uc2a4\ud2f1 \ub4dc\ub77c\uc774 \uc564 \ucf64\ud3ec\ud2b8, 50g, 8806322187027, 8,930\uc6d0, 8,900\uc6d0, \ud560\uc778\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.06631530341455492
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 59,
#         "total_token_count": 2956
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (14).jpg):
# '니베아 데오드란트 스틱 드라이 앤 콤포트, 50g, 8806322187027, 8,930원, 8,900원, 할인상품'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (14).jpg): ['니베아 데오드란트 스틱 드라이 앤 콤포트', '50g', '8806322187027', '8,930원', '8,900원', '할인상품']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (15).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (15).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\uc2a4\ud504\ub808\uc774 \ub4dc\ub77c\uc774\ucef4\ud3ec\ud2b8200ml, \uc2dd\ubcc4\ubd88\uac00, 4005808321735, 11,900\uc6d0, 11,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -8.659775679310163e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (15).jpg):
# '니베아 데오스프레이 드라이컴포트200ml, 식별불가, 4005808321735, 11,900원, 11,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (15).jpg): ['니베아 데오스프레이 드라이컴포트200ml', '식별불가', '4005808321735', '11,900원', '11,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (2).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (2).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc775\uc2a4\ud504\ub808\uc2a4 \ubc14\ub514 \ub85c\uc158, 400ml, 4005808891436, 16,900\uc6d0, 16,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00353462142603738
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 56,
#         "total_token_count": 2953
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (2).jpg):
# '니베아 익스프레스 바디 로션, 400ml, 4005808891436, 16,900원, 16,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (2).jpg): ['니베아 익스프레스 바디 로션', '400ml', '4005808891436', '16,900원', '16,900원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (3).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (3).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 Q10 \ubc14\ub514\ub85c\uc158 \ud654\uc774\ud2b8, 400ml, 4005808297470, \uc2dd\ubcc4\ubd88\uac00, 16,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01535773048034081
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 52,
#         "total_token_count": 2949
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (3).jpg):
# '니베아 Q10 바디로션 화이트, 400ml, 4005808297470, 식별불가, 16,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (3).jpg): ['니베아 Q10 바디로션 화이트', '400ml', '4005808297470', '식별불가', '16,900원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (4).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (4).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 Q10 \ub9ac\uce58 \ubc14\ub514 \ub85c\uc158, 400ml, 4005800098833, 16,900\uc6d0, 16,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0016153803361313684
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 56,
#         "total_token_count": 2953
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (4).jpg):
# '니베아 Q10 리치 바디 로션, 400ml, 4005800098833, 16,900원, 16,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (4).jpg): ['니베아 Q10 리치 바디 로션', '400ml', '4005800098833', '16,900원', '16,900원', '1+1']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (5).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (5).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub9e8\uc13c\uc11c\ud2f0\ube0c\uc250\uc774\ube59\ud3fc, 200ml, 4005808817207, 5,200\uc6d0, 5,200\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.014071195213883012
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (5).jpg):
# '니베아맨센서티브쉐이빙폼, 200ml, 4005808817207, 5,200원, 5,200원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (5).jpg): ['니베아맨센서티브쉐이빙폼', '200ml', '4005808817207', '5,200원', '5,200원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (6).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (6).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub9e8\uc13c\uc11c\ud2f0\ube0c\uc250\uc774\ube59\uc824, 200ml, 4005808817405, 5,200\uc6d0, 5,200\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0032732646774362635
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (6).jpg):
# '니베아맨센서티브쉐이빙젤, 200ml, 4005808817405, 5,200원, 5,200원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (6).jpg): ['니베아맨센서티브쉐이빙젤', '200ml', '4005808817405', '5,200원', '5,200원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (7).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (7).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub77c\uc774\ud2b8 \uc120 \uc138\ub7fc, 90ml, 4005808984763, 19,500\uc6d0, 19,500\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0042446001487619735
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 51,
#         "total_token_count": 2948
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (7).jpg):
# '니베아 라이트 선 세럼, 90ml, 4005808984763, 19,500원, 19,500원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (7).jpg): ['니베아 라이트 선 세럼', '90ml', '4005808984763', '19,500원', '19,500원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (8).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (8).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc6b8\ud2b8\ub77c \uc13c\uc11c\ud2f0\ube0c \uc120 \ub85c\uc158 200ml, 200ml, \uc2dd\ubcc4\ubd88\uac00, 23,800\uc6d0, 23,800\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.012536114012753521
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (8).jpg):
# '니베아 울트라 센서티브 선 로션 200ml, 200ml, 식별불가, 23,800원, 23,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (8).jpg): ['니베아 울트라 센서티브 선 로션 200ml', '200ml', '식별불가', '23,800원', '23,800원', '1+1']
#
# 🚀 처리 중: image/이마트 BDF(!) (1)\이마트 BDF(!) (9).jpg
# 이미지 열기 성공: image/이마트 BDF(!) (1)\이마트 BDF(!) (9).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ud398\uc774\uc2a4 \uc218\ub529 \uc13c\uc11c\ud2f0\ube0c \ud06c\ub9bc, 50ml, 4005900475220, \uc2dd\ubcc4\ubd88\uac00, 15,800\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009701143611561169
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 55,
#         "total_token_count": 2952
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF(!) (9).jpg):
# '니베아 선 페이스 수딩 센서티브 크림, 50ml, 4005900475220, 식별불가, 15,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF(!) (9).jpg): ['니베아 선 페이스 수딩 센서티브 크림', '50ml', '4005900475220', '식별불가', '15,800원', '1+1']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(1).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(1).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub3c4\ub8e8\ucf54 \ud074\ub798\uc2dd \uc250\uc774\ube59\ud3fc175ml*2, \uc2dd\ubcc4\ubd88\uac00, 8809389188505, 6,900\uc6d0, 4,830\uc6d0, 30%"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0008474386714655777
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 58,
#         "total_token_count": 2955
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(1).jpg):
# '도루코 클래식 쉐이빙폼175ml*2, 식별불가, 8809389188505, 6,900원, 4,830원, 30%'
#
# 📌 개별 라인 분석 (이마트 맨(1).jpg): ['도루코 클래식 쉐이빙폼175ml*2', '식별불가', '8809389188505', '6,900원', '4,830원', '30%']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(2).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(2).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \ud3ec\uc624\ubbf8\uba58\uc194175g, 175g, 7702018002344, 5,600\uc6d0, 5,600\uc6d0, \ud53c\uc564\uc9c0 \ud589\uc0ac\uc0c1\ud488 3\ub9cc\uc6d0 \uc774\uc0c1 \uacb0\uc81c\uc2dc 5\ucc9c\uc6d0 \uc0c1\ud488\uad8c \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.013128837494000997
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 73,
#         "total_token_count": 2970
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(2).jpg):
# '질레트 포오미멘솔175g, 175g, 7702018002344, 5,600원, 5,600원, 피앤지 행사상품 3만원 이상 결제시 5천원 상품권 증정'
#
# 📌 개별 라인 분석 (이마트 맨(2).jpg): ['질레트 포오미멘솔175g', '175g', '7702018002344', '5,600원', '5,600원', '피앤지 행사상품 3만원 이상 결제시 5천원 상품권 증정']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(3).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(3).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \uc2a4\ud0a8\ud14d \uc824, 195g, 4902430913829, 6,860\uc6d0, 6,860\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009090152382850648
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 50,
#         "total_token_count": 2947
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(3).jpg):
# '질레트 스킨텍 젤, 195g, 4902430913829, 6,860원, 6,860원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 맨(3).jpg): ['질레트 스킨텍 젤', '195g', '4902430913829', '6,860원', '6,860원', '식별불가']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(4).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(4).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \uc2a4\ud0a8\ud14d \ud3fc, 245g, 4902430913836, 9,000\uc6d0, 9,000\uc6d0, \uc0c1\ud488\uad8c \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.02715424299240112
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 50,
#         "total_token_count": 2947
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(4).jpg):
# '질레트 스킨텍 폼, 245g, 4902430913836, 9,000원, 9,000원, 상품권 증정'
#
# 📌 개별 라인 분석 (이마트 맨(4).jpg): ['질레트 스킨텍 폼', '245g', '4902430913836', '9,000원', '9,000원', '상품권 증정']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(5).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(5).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc804 \ud558\uc774\ub4dc\ub77c\uc824 \uc6b8\ud2b8\ub77c\ud504\ub85c\ud14d\uc158, 195g, 7702018864447, 9,800\uc6d0, 6,860\uc6d0, 30%"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -7.836482421095883e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 56,
#         "total_token_count": 2953
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(5).jpg):
# '퓨전 하이드라젤 울트라프로텍션, 195g, 7702018864447, 9,800원, 6,860원, 30%'
#
# 📌 개별 라인 분석 (이마트 맨(5).jpg): ['퓨전 하이드라젤 울트라프로텍션', '195g', '7702018864447', '9,800원', '6,860원', '30%']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(6).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(6).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud504\ub85c\uae00\ub77c\uc774\ub4dc \ud22c\uc778\uc6d0 \uc250\uc774\ube59\ud3fc, 245g, 4902430590013, \uc2dd\ubcc4\ubd88\uac00, 11,600\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004325808781497883
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 53,
#         "total_token_count": 2950
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(6).jpg):
# '프로글라이드 투인원 쉐이빙폼, 245g, 4902430590013, 식별불가, 11,600원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 맨(6).jpg): ['프로글라이드 투인원 쉐이빙폼', '245g', '4902430590013', '식별불가', '11,600원', '식별불가']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(7).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(7).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \ud504\ub85c\uae00\ub77c\uc774\ub4dc \ud4e8\uc5b4\uc2a4\ud3ec\uce20 \ub4c0\uc624\ubc31, \uc2dd\ubcc4\ubd88\uac00, 4902430732048, 14,600\uc6d0, 14,600\uc6d0, \uc0c1\ud488\uad8c \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0001493443890164296
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(7).jpg):
# '질레트 프로글라이드 퓨어스포츠 듀오백, 식별불가, 4902430732048, 14,600원, 14,600원, 상품권 증정'
#
# 📌 개별 라인 분석 (이마트 맨(7).jpg): ['질레트 프로글라이드 퓨어스포츠 듀오백', '식별불가', '4902430732048', '14,600원', '14,600원', '상품권 증정']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(8).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(8).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8\ub7a9\uc2a4 \ud035 \ub9b0\uc2a4 \uc250\uc774\ube0c\ud3fc, 240ml, 4987176132277, 15,900\uc6d0, 15,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.010210967670052739
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 59,
#         "total_token_count": 2956
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(8).jpg):
# '질레트랩스 퀵 린스 쉐이브폼, 240ml, 4987176132277, 15,900원, 15,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 맨(8).jpg): ['질레트랩스 퀵 린스 쉐이브폼', '240ml', '4987176132277', '15,900원', '15,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 맨(1)\이마트 맨(9).jpg
# 이미지 열기 성공: image/이마트 맨(1)\이마트 맨(9).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8\ub7a9\uc2a4 \ub798\ud53c\ub4dc \ud3ec\ubc0d\uc6e8\uc774\ube0c\uc824, 198ml, 4987176132284, 15,900\uc6d0, 11,130\uc6d0, 30% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.05400214820611672
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 61,
#         "total_token_count": 2958
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 맨(9).jpg):
# '질레트랩스 래피드 포밍웨이브젤, 198ml, 4987176132284, 15,900원, 11,130원, 30% 할인'
#
# 📌 개별 라인 분석 (이마트 맨(9).jpg): ['질레트랩스 래피드 포밍웨이브젤', '198ml', '4987176132284', '15,900원', '11,130원', '30% 할인']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(1) - 복사본.jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(1) - 복사본.jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \uc138\ub77c\uc5e0\ub514 \ub9ac\ud398\uc5b4 \ud06c\ub9bc, 200ml, 8809911693972, 9,600\uc6d0, 9,600\uc6d0, \ucd94\ucc9c\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03337808670821013
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(1) - 복사본.jpg):
# '더마비 세라엠디 리페어 크림, 200ml, 8809911693972, 9,600원, 9,600원, 추천상품'
#
# 📌 개별 라인 분석 (이마트 바디(1) - 복사본.jpg): ['더마비 세라엠디 리페어 크림', '200ml', '8809911693972', '9,600원', '9,600원', '추천상품']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(1).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(1).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \uc138\ub77c\uc5e0\ub514 \ub9ac\ud398\uc5b4 \ud06c\ub9bc, 200ml, 8809911693972, 9,600\uc6d0, 9,600\uc6d0, \ucd94\ucc9c\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.013556743109667743
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(1).jpg):
# '더마비 세라엠디 리페어 크림, 200ml, 8809911693972, 9,600원, 9,600원, 추천상품'
#
# 📌 개별 라인 분석 (이마트 바디(1).jpg): ['더마비 세라엠디 리페어 크림', '200ml', '8809911693972', '9,600원', '9,600원', '추천상품']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(10).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(10).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \ud37c\ud4f8\ubd80\ud2f0\ud06c \ubc14\ub514\ub85c\uc158 \uc0c1\ud0c8\uba38\uc2a4\ud06c, \uc2dd\ubcc4\ubd88\uac00, 8809925195363, 13,900\uc6d0, 11,400\uc6d0, \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.014301926402722374
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 59,
#         "total_token_count": 2956
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(10).jpg):
# '해피바스 퍼퓸부티크 바디로션 상탈머스크, 식별불가, 8809925195363, 13,900원, 11,400원, 할인'
#
# 📌 개별 라인 분석 (이마트 바디(10).jpg): ['해피바스 퍼퓸부티크 바디로션 상탈머스크', '식별불가', '8809925195363', '13,900원', '11,400원', '할인']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(11).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(11).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \ud37c\ud4f8\ubd80\ud2f0\ud06c \ubc14\ub514\ub85c\uc158 \ub85c\uc988 \ube14\ub7ec\uc26c, \uc2dd\ubcc4\ubd88\uac00, 8809925195356, 13,900\uc6d0, 11,400\uc6d0, \ud560\uc778\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0022255533164547334
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 62,
#         "total_token_count": 2959
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(11).jpg):
# '해피바스 퍼퓸부티크 바디로션 로즈 블러쉬, 식별불가, 8809925195356, 13,900원, 11,400원, 할인상품'
#
# 📌 개별 라인 분석 (이마트 바디(11).jpg): ['해피바스 퍼퓸부티크 바디로션 로즈 블러쉬', '식별불가', '8809925195356', '13,900원', '11,400원', '할인상품']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(12).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(12).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\uc2dc\uce74 \ubc14\ub514\ub85c\uc158 \ud654\uc774\ud2b8\uba38\uc2a4\ud06c, 730ml, 8801051240122, 12,900\uc6d0, 7,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.053750796751542526
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 55,
#         "total_token_count": 2952
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(12).jpg):
# '퓨어시카 바디로션 화이트머스크, 730ml, 8801051240122, 12,900원, 7,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디(12).jpg): ['퓨어시카 바디로션 화이트머스크', '730ml', '8801051240122', '12,900원', '7,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(13).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(13).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\uc2dc\uce74\ubc14\ub514\ub85c\uc158\ubca0\uc774\ube44\ud30c\uc6b0\ub354730ml, \uc2dd\ubcc4\ubd88\uac00, 8801051291292, 12,900\uc6d0, 7,900\uc6d0, \ud560\uc778\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.019856766859690348
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(13).jpg):
# '퓨어시카바디로션베이비파우더730ml, 식별불가, 8801051291292, 12,900원, 7,900원, 할인상품'
#
# 📌 개별 라인 분석 (이마트 바디(13).jpg): ['퓨어시카바디로션베이비파우더730ml', '식별불가', '8801051291292', '12,900원', '7,900원', '할인상품']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(14).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(14).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc138\ud0c0\ud544 \ubaa8\uc774\uc2a4\ucdb0\ub77c\uc774\uc9d5 \ud06c\ub9bc, 550G, 3499320013369, 22,320\uc6d0, 22,320\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0010366985505377805
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(14).jpg):
# '세타필 모이스춰라이징 크림, 550G, 3499320013369, 22,320원, 22,320원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디(14).jpg): ['세타필 모이스춰라이징 크림', '550G', '3499320013369', '22,320원', '22,320원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(15).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(15).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44 \uc6b8\ud2b8\ub77c \ubaa8\uc774\uc2a4\ucc98 \ubc14\ub514\ud06c\ub9bc, 430ml, 8809048410664, \uc2dd\ubcc4\ubd88\uac00, 14,950\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00937788795541834
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(15).jpg):
# '더마비 울트라 모이스처 바디크림, 430ml, 8809048410664, 식별불가, 14,950원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디(15).jpg): ['더마비 울트라 모이스처 바디크림', '430ml', '8809048410664', '식별불가', '14,950원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(16).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(16).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ub354\ub9c8\ube44 1\ub370\uc77c\ub9ac \ubaa8\uc774\uc2a4\ucc98\ubc14\ub514\ub85c\uc158, 500ml, 8809554840337, \uc2dd\ubcc4\ubd88\uac00, 13,650\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.014177085033484868
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 56,
#         "total_token_count": 2953
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(16).jpg):
# '뉴더마비 1데일리 모이스처바디로션, 500ml, 8809554840337, 식별불가, 13,650원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디(16).jpg): ['뉴더마비 1데일리 모이스처바디로션', '500ml', '8809554840337', '식별불가', '13,650원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(17).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(17).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub354\ub9c8\ube44AC\ucee8\ud2b8\ub864\ubc14\ub514\ub85c\uc158, 400, \uc2dd\ubcc4\ubd88\uac00, 11,100\uc6d0, 11,100\uc6d0, \ucd94\ucc9c \uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.028483593186666798
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 43,
#         "total_token_count": 2940
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(17).jpg):
# '더마비AC컨트롤바디로션, 400, 식별불가, 11,100원, 11,100원, 추천 상품'
#
# 📌 개별 라인 분석 (이마트 바디(17).jpg): ['더마비AC컨트롤바디로션', '400', '식별불가', '11,100원', '11,100원', '추천 상품']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(18).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(18).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc138\ud0c0\ud544 \uc9c4\uc815 \uc824\ud06c\ub9bc, 226g, 3499320013536, \uc2dd\ubcc4\ubd88\uac00, 14,800\uc6d0, \ucd94\ucc9c\uc0c1\ud488"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004709440834668218
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 49,
#         "total_token_count": 2946
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(18).jpg):
# '세타필 진정 젤크림, 226g, 3499320013536, 식별불가, 14,800원, 추천상품'
#
# 📌 개별 라인 분석 (이마트 바디(18).jpg): ['세타필 진정 젤크림', '226g', '3499320013536', '식별불가', '14,800원', '추천상품']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(19).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(19).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc774\uc544\uc6b0\uc5b4 \ubc14\ub514\ub85c\uc158 \ubbfc\ud2b8\ub77c\ubca4\ub354, 1000ml, 8809700497866, 15,600\uc6d0, 12,480\uc6d0, 20%"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -6.839384865489299e-06
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 59,
#         "total_token_count": 2956
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(19).jpg):
# '바이아우어 바디로션 민트라벤더, 1000ml, 8809700497866, 15,600원, 12,480원, 20%'
#
# 📌 개별 라인 분석 (이마트 바디(19).jpg): ['바이아우어 바디로션 민트라벤더', '1000ml', '8809700497866', '15,600원', '12,480원', '20%']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(2).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(2).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub77c \uba54\ubaa8\ub9ac\uc544 \uc6b0\ub514, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00, 3,000\uc6d0, 2,000\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.089400188342945
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 37,
#         "total_token_count": 2934
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(2).jpg):
# '라 메모리아 우디, 식별불가, 식별불가, 3,000원, 2,000원, 가격 할인'
#
# 📌 개별 라인 분석 (이마트 바디(2).jpg): ['라 메모리아 우디', '식별불가', '식별불가', '3,000원', '2,000원', '가격 할인']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(20).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(20).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \uc2dc\uce74 \uc5d0\uba40\uc83c, 310ml, 8801108002475, 13,200\uc6d0, 13,200\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0013343992608564872
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 54,
#         "total_token_count": 2951
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(20).jpg):
# '뉴트로지나 시카 에멀젼, 310ml, 8801108002475, 13,200원, 13,200원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디(20).jpg): ['뉴트로지나 시카 에멀젼', '310ml', '8801108002475', '13,200원', '13,200원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(21).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(21).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ube44\ub178 \uc2a4\ud2b8\ub808\uc2a4\ub9b4\ub9ac\ud504 \ub85c\uc158, 354ml, 8801108003748, 21,900\uc6d0, 13,140\uc6d0, 40%"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00011679134754972025
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 55,
#         "total_token_count": 2952
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(21).jpg):
# '아비노 스트레스릴리프 로션, 354ml, 8801108003748, 21,900원, 13,140원, 40%'
#
# 📌 개별 라인 분석 (이마트 바디(21).jpg): ['아비노 스트레스릴리프 로션', '354ml', '8801108003748', '21,900원', '13,140원', '40%']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(22).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(22).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ucfe4\ub2ec \ud4e8\uc5b4 \ubc14\ub514\ub85c\uc158 718ml \ubca0\uc774\ube44\ud30c\uc6b0\ub354, 718ml, 8809568748490, 14,900\uc6d0, 14,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.001737586222589016
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 64,
#         "total_token_count": 2961
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(22).jpg):
# '쿤달 퓨어 바디로션 718ml 베이비파우더, 718ml, 8809568748490, 14,900원, 14,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디(22).jpg): ['쿤달 퓨어 바디로션 718ml 베이비파우더', '718ml', '8809568748490', '14,900원', '14,900원', '1+1']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~50)
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(23).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(23).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "1+1(\ucfe4\ub2ec \ud4e8\uc5b4 \ubc14\ub514\ub85c\uc158 718ml 3\uc885), \uc2dd\ubcc4\ubd88\uac00, 8809568748506, 14,900\uc6d0, 14,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.023474911227822304
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 64,
#         "total_token_count": 2961
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(23).jpg):
# '1+1(쿤달 퓨어 바디로션 718ml 3종), 식별불가, 8809568748506, 14,900원, 14,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디(23).jpg): ['1+1(쿤달 퓨어 바디로션 718ml 3종)', '식별불가', '8809568748506', '14,900원', '14,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(24).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(24).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ucfe4\ub2ec \ubc14\ub514\ub85c\uc158 718ml \uc77c\ub791\uc77c\ub791, \uc2dd\ubcc4\ubd88\uac00, 8809953771621, 14,900\uc6d0, 14,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03242254668268664
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 58,
#         "total_token_count": 2955
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(24).jpg):
# '쿤달 바디로션 718ml 일랑일랑, 식별불가, 8809953771621, 14,900원, 14,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디(24).jpg): ['쿤달 바디로션 718ml 일랑일랑', '식별불가', '8809953771621', '14,900원', '14,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(3).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(3).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub77c \uba54\ubaa8\ub9ac\uc544 \ub77c\ubca4\ub354 \uba38\uc2a4\ud06c \ubc14\ub514\ub85c\uc158, 390ml, 8801046412145, 3,000\uc6d0, 2,000\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004597299749200995
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 55,
#         "total_token_count": 2952
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(3).jpg):
# '라 메모리아 라벤더 머스크 바디로션, 390ml, 8801046412145, 3,000원, 2,000원, 가격할인'
#
# 📌 개별 라인 분석 (이마트 바디(3).jpg): ['라 메모리아 라벤더 머스크 바디로션', '390ml', '8801046412145', '3,000원', '2,000원', '가격할인']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(4).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(4).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc624\ub9ac\uc9c0\ub110 \ubc14\ub514\ub85c\uc158 \ud30c\uc6b0\ub354, 500g, 8809803540438, 9,900\uc6d0, 8,900\uc6d0, 1,000\uc6d0"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006281936665376028
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 60,
#         "total_token_count": 2957
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 바디(4).jpg):
# '해피바스 오리지널 바디로션 파우더, 500g, 8809803540438, 9,900원, 8,900원, 1,000원'
#
# 📌 개별 라인 분석 (이마트 바디(4).jpg): ['해피바스 오리지널 바디로션 파우더', '500g', '8809803540438', '9,900원', '8,900원', '1,000원']
#
# 🚀 처리 중: image/이마트 바디(15)\이마트 바디(5).jpg
# 이미지 열기 성공: image/이마트 바디(15)\이마트 바디(5).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(37).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(37).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \ud30c\uc6cc\uc274\ub4dc \uc120\uc2a4\ud2f1 \uc6cc\ud130\ud504\ub8e8\ud504, 1Bg, 8801166389365, 24,980\uc6d0, 24,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778 [\uad50\ucc28\uac00\ub2a5]"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01067360623242104
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 73,
#         "total_token_count": 2970
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(37).jpg):
# '그린핑거 파워쉴드 선스틱 워터프루프, 1Bg, 8801166389365, 24,980원, 24,980원, 2개 구매시 50% 할인 [교차가능]'
#
# 📌 개별 라인 분석 (이마트썬(37).jpg): ['그린핑거 파워쉴드 선스틱 워터프루프', '1Bg', '8801166389365', '24,980원', '24,980원', '2개 구매시 50% 할인 [교차가능]']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(38).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(38).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc57c\uc678\ub180\uc774 \uc6cc\uc154\ube14 \uc120\ud06c\ub9bc, BDml(\uc2dc), 8801156407922, 25,980\uc6d0, 25,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.038890383460304954
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 66,
#         "total_token_count": 2963
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(38).jpg):
# '그린핑거 야외놀이 워셔블 선크림, BDml(시), 8801156407922, 25,980원, 25,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트썬(38).jpg): ['그린핑거 야외놀이 워셔블 선크림', 'BDml(시)', '8801156407922', '25,980원', '25,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(39).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(39).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \ubb3c\ub180\uc774 \uc120\ud06c\ub9bc \uc6cc\ud130\ud504\ub8e8\ud504, 50ml, 8801186308122, \uc2dd\ubcc4\ubd88\uac00, 21,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0451714727613661
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 63,
#         "total_token_count": 2960
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(39).jpg):
# '그린핑거 물놀이 선크림 워터프루프, 50ml, 8801186308122, 식별불가, 21,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트썬(39).jpg): ['그린핑거 물놀이 선크림 워터프루프', '50ml', '8801186308122', '식별불가', '21,980원', '2개 구매시 50% 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 10 처리 시작 (파일 91~99)
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(4).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(4).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubcf8\ud2b8\ub9ac \ubca0\ub9ac\uc158\ube14\ub7ed SPF50+PA++++, 50ml, 2000001211373, 14,980\uc6d0, 8,988\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.005602689962538462
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 63,
#         "total_token_count": 2960
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(4).jpg):
# '본트리 베리션블럭 SPF50+PA++++, 50ml, 2000001211373, 14,980원, 8,988원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트썬(4).jpg): ['본트리 베리션블럭 SPF50+PA++++', '50ml', '2000001211373', '14,980원', '8,988원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(40).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(40).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc57c\uc678\ub180\uc774 \ud798\uc13c \uc120\ud06c\ub9bc, 70ml, 8801166404754, 21,980\uc6d0, 21,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01672515869140625
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 65,
#         "total_token_count": 2962
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(40).jpg):
# '그린핑거 야외놀이 힘센 선크림, 70ml, 8801166404754, 21,980원, 21,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트썬(40).jpg): ['그린핑거 야외놀이 힘센 선크림', '70ml', '8801166404754', '21,980원', '21,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(41).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(41).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2e5\ud130\uc544\ud1a0 \ub354\ub9c8 \uc13c\uc11c\ud2f0\ube0c \uc120\ud504\ub85c\ud14d\ud130, 50ml, 8801092527459, 29,980\uc6d0, 29,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008045619103445936
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 67,
#         "total_token_count": 2964
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(41).jpg):
# '닥터아토 더마 센서티브 선프로텍터, 50ml, 8801092527459, 29,980원, 29,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트썬(41).jpg): ['닥터아토 더마 센서티브 선프로텍터', '50ml', '8801092527459', '29,980원', '29,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(42).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(42).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ud1a0\uc564\uc624\ud22c \ubb34\uae30\uc790\ucc28\uc120 \ud06c\ub9bc50G, 50G, 8809620751222, 13987\uc6d0, 20,980\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778 [\uad50\ucc28\uac00\ub2a5]"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011351959806093027
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 71,
#         "total_token_count": 2968
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(42).jpg):
# '아토앤오투 무기자차선 크림50G, 50G, 8809620751222, 13987원, 20,980원, 2개 구매시 50% 할인 [교차가능]'
#
# 📌 개별 라인 분석 (이마트썬(42).jpg): ['아토앤오투 무기자차선 크림50G', '50G', '8809620751222', '13987원', '20,980원', '2개 구매시 50% 할인 [교차가능]']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(5).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(5).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc140\ud4e8\uc804\uc528 \ub808\uc774\uc800 \uc36c\uc2a4\ud06c\ub9b0 100 35ml, 35ml, 88096946520417, 27,980\uc6d0, 16,788\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\ud55c\uc815.\uae30\ud68d \uc120\ud06c\ub9bc 35g+\ud3fc \ud074\ub80c\uc800 15 ml, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.036973555153663004
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 109,
#         "total_token_count": 3006
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(5).jpg):
# '셀퓨전씨 레이저 썬스크린 100 35ml, 35ml, 88096946520417, 27,980원, 16,788원, 식별불가\n한정.기획 선크림 35g+폼 클렌저 15 ml, 식별불가, 식별불가, 식별불가, 식별불가, 식별불가'
#
# 📌 개별 라인 분석 (이마트썬(5).jpg): ['셀퓨전씨 레이저 썬스크린 100 35ml', '35ml', '88096946520417', '27,980원', '16,788원', '식별불가']
#
# 📌 개별 라인 분석 (이마트썬(5).jpg): ['한정.기획 선크림 35g+폼 클렌저 15 ml', '식별불가', '식별불가', '식별불가', '식별불가', '식별불가']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(6).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(6).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc140\ud4e8\uc804\uc528 AC \uc36c, \uc2dd\ubcc4\ubd88\uac00, 8809694627300, 27,980\uc6d0, 16,788\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008430783163037216
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 57,
#         "total_token_count": 2954
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(6).jpg):
# '셀퓨전씨 AC 썬, 식별불가, 8809694627300, 27,980원, 16,788원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트썬(6).jpg): ['셀퓨전씨 AC 썬', '식별불가', '8809694627300', '27,980원', '16,788원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(7).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(7).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc57c\ub2e4 \uc120 \uc5d0\uc13c\uc2a4 \uae30\ud68d, \uc2dd\ubcc4\ubd88\uac00, 8809340386919, 20,980\uc6d0, 12,588\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03450646893731479
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 58,
#         "total_token_count": 2955
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(7).jpg):
# '야다 선 에센스 기획, 식별불가, 8809340386919, 20,980원, 12,588원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트썬(7).jpg): ['야다 선 에센스 기획', '식별불가', '8809340386919', '20,980원', '12,588원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(8).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(8).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\uba5c\ub85c\uc6b0 \ub370\uc77c\ub9ac \ud1a4\uc5c5 \uc120\ud06c\ub9bc 50ml 2\uc785, \uc2dd\ubcc4\ubd88\uac00, 8809438489607, 11,900\uc6d0, 7,140\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.007707151628675915
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 63,
#         "total_token_count": 2960
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(8).jpg):
# '퓨어멜로우 데일리 톤업 선크림 50ml 2입, 식별불가, 8809438489607, 11,900원, 7,140원, 식별불가'
#
# 📌 개별 라인 분석 (이마트썬(8).jpg): ['퓨어멜로우 데일리 톤업 선크림 50ml 2입', '식별불가', '8809438489607', '11,900원', '7,140원', '식별불가']
#
# 🚀 처리 중: image/이마트썬(34)\이마트썬(9).jpg
# 이미지 열기 성공: image/이마트썬(34)\이마트썬(9).jpg, 크기: (720, 1600)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uba54\ub514\ud544_\ub808\ub4dc\ub77d\ud1a0 \uc120\ud06c\ub9bc \uae30\ud68d\uc138\ud2b8, \uc2dd\ubcc4\ubd88\uac00, 8809941823196, 8,000\uc6d0, 5,000\uc6d0, 1\uac1c\ub2f9 5000\uc6d0"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0036143674965827695
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2897,
#         "candidates_token_count": 62,
#         "total_token_count": 2959
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트썬(9).jpg):
# '메디필_레드락토 선크림 기획세트, 식별불가, 8809941823196, 8,000원, 5,000원, 1개당 5000원'
#
# 📌 개별 라인 분석 (이마트썬(9).jpg): ['메디필_레드락토 선크림 기획세트', '식별불가', '8809941823196', '8,000원', '5,000원', '1개당 5000원']
#
# ✅ 이마트 BDF(!) (1) 카테고리 정보가 이마트 BDF(!) (1).csv 파일에 저장되었습니다.
# 총 16개 상품 정보 처리 완료
#                    파일명                     제품명      용량           상품코드  \
# 0   이마트 BDF(!) (1).jpg           니베아 스무드 바디 로션   400ml  4005808891474
# 1  이마트 BDF(!) (10).jpg  니베아 선 프로텍트 맨 모이스춰 선 로션  100ml당  0000042467083
# 2  이마트 BDF(!) (11).jpg      니네아 키즈 울트라 프로젝트 로션   150ml  4005808518494
#
#     정상가_표시   할인가_표시 할인 내용
# 0  16,900원  16,900원   1+1
# 1  17,800원  17,800원   1+1
# 2  19,800원  19,800원   1+1
#
# ✅ 이마트 맨(1) 카테고리 정보가 이마트 맨(1).csv 파일에 저장되었습니다.
# 총 9개 상품 정보 처리 완료
#             파일명                  제품명    용량           상품코드  정상가_표시  할인가_표시  \
# 0  이마트 맨(1).jpg  도루코 클래식 쉐이빙폼175ml*2  식별불가  8809389188505  6,900원  4,830원
# 1  이마트 맨(2).jpg        질레트 포오미멘솔175g  175g  7702018002344  5,600원  5,600원
# 2  이마트 맨(3).jpg            질레트 스킨텍 젤  195g  4902430913829  6,860원  6,860원
#
#                             할인 내용
# 0                             30%
# 1  피앤지 행사상품 3만원 이상 결제시 5천원 상품권 증정
# 2                            식별불가
#
# ✅ 이마트 바디(15) 카테고리 정보가 이마트 바디(15).csv 파일에 저장되었습니다.
# 총 25개 상품 정보 처리 완료
#                    파일명                    제품명     용량           상품코드   정상가_표시  \
# 0  이마트 바디(1) - 복사본.jpg        더마비 세라엠디 리페어 크림  200ml  8809911693972   9,600원
# 1        이마트 바디(1).jpg        더마비 세라엠디 리페어 크림  200ml  8809911693972   9,600원
# 2       이마트 바디(10).jpg  해피바스 퍼퓸부티크 바디로션 상탈머스크   식별불가  8809925195363  13,900원
#
#     할인가_표시 할인 내용
# 0   9,600원  추천상품
# 1   9,600원  추천상품
# 2  11,400원    할인
#
# ✅ 이마트 핸드(1) 카테고리 정보가 이마트 핸드(1).csv 파일에 저장되었습니다.
# 총 8개 상품 정보 처리 완료
#              파일명                제품명    용량           상품코드  정상가_표시  할인가_표시 할인 내용
# 0  이마트 핸드(1).jpg  카밀 핸드&네일 크림 프레쉬 N  75ml  4000196936660  5,400원  5,400원  식별불가
# 1  이마트 핸드(2).jpg  카밀 핸드&네일 크림 스위티 N  75ml  4000196936707  5,400원  5,400원  식별불가
# 2  이마트 핸드(3).jpg     카밀 핸드&네일 크림 자몽  75ml  4000196936684  5,400원  5,400원  식별불가
#
# ✅ 이마트썬(34) 카테고리 정보가 이마트썬(34).csv 파일에 저장되었습니다.
# 총 45개 상품 정보 처리 완료
#             파일명                        제품명    용량           상품코드   정상가_표시  \
# 0   이마트썬(1).jpg  바이오더마 포토덤 페디아트릭스 테 SPF50+  식별불가  3701129807286  35,980원
# 1  이마트썬(10).jpg     자민경 프리마크 그린 캡슐 모이스처 선크  식별불가  8809147351196   9,980원
# 2  이마트썬(11).jpg     자민경 프리마크 블루 캡슐 모이스처 선크  식별불가  8809147351189   9,980원
#
#     할인가_표시          할인 내용
# 0  17,990원  신세계포인트 적립시 할인
# 1   7,980원  신세계포인트 적립시 할인
# 2   7,980원  신세계포인트 적립시 할인
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 103개 상품 정보 처리 완료
