# %%
# !pip install -q -U google-generativeai
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# python-jose 3.4.0 requires pyasn1<0.5.0,>=0.4.1, but you have pyasn1 0.6.1 which is incompatible.
#
# [notice] A new release of pip available: 22.2.1 -> 25.1
# [notice] To update, run: python3.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv



load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")



genai.configure(api_key=GOOGLE_API_KEY)

# %%
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
from PIL import Image


def ask_for_product_info(image_path):
    try:
        # 이미지 열기
        img = Image.open(image_path)
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # 모델에 이미지와 프롬프트 함께 전달
        response = model.generate_content(
            [
                "Instructions:\
                1. Detect the price tags in the image and extract the text from those price tags.\
                2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):\
                   - Product name\
                   - Capacity\
                   - Product code (13 digits)\
                   - Regular price (in KRW)\
                   - Discount price (in KRW)\
                   - Discount content\
                3. If the discount price is not provided, use the same value as the regular price.\
                4. If any item is incorrect or unclear, please write '식별불가' for that item.\
                5. Always add '원' after the price.\
                6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력.\
                7. If, for any reason, none of the items can be found, write '식별불가' for all items.\
                8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified.\
                9. Perform all tasks without any refusal to the greatest extent possible.\
                10. Only use the information from the price tag.\
                11. If a discount is included, please only list the final discounted price.\
                12. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다.\
                출력 형식 예시(필수 준수)\
                각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]\
                예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당\
                예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1",
                img,
            ]
        )

        print(f"모델 응답: {response}")
        return response.text
    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=60):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": items[2],
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 71
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(1).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(1).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\uc120 \ud0a4\ube0c \ud504\ub85c\ud14d\ud2b8 \ub85c\uc158, 200ML, 4040059006001, 23,800\uc6d0, 11,900\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00010591220077976846
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(1).jpg):
# '니베아선 키브 프로텍트 로션, 200ML, 4040059006001, 23,800원, 11,900원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(1).jpg): ['니베아선 키브 프로텍트 로션', '200ML', '4040059006001', '23,800원', '11,900원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(10).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(10).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 \ub354\ub9c8\ucee8\ud2b8\ub97c \ub864\uc628 (\ud4e8\uc5b4 \uc13c\uc11c\ud2f0\ube0c), 50ML, 304005808676590, 10,400\uc6d0, 8,900\uc6d0, \ud56b\uc378\uba38\ud074\ub9ac\ub2dd \ub86f\ub370 KB\uad6d\ubbfc\uc2e0NH\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.013431506736256251
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 107,
#         "total_token_count": 2402
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(10).jpg):
# '니베아데오 더마컨트를 롤온 (퓨어 센서티브), 50ML, 304005808676590, 10,400원, 8,900원, 핫썸머클리닝 롯데 KB국민신NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(10).jpg): ['니베아데오 더마컨트를 롤온 (퓨어 센서티브)', '50ML', '304005808676590', '10,400원', '8,900원', '핫썸머클리닝 롯데 KB국민신NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(11).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(11).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub864\uc628 (\ud654\uc774\ud2b8), 50ML, 614005808355020, 9,400\uc6d0, 7,500\uc6d0, \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00854947520237343
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 51,
#         "total_token_count": 2346
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(11).jpg):
# '니베아 데오롤온 (화이트), 50ML, 614005808355020, 9,400원, 7,500원, 증정'
#
# 📌 개별 라인 분석 (롯데 BDF(11).jpg): ['니베아 데오롤온 (화이트)', '50ML', '614005808355020', '9,400원', '7,500원', '증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(12).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(12).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub4dc\ub780\ud2b8 \uc2a4\ud2f1 (\uc5d1\uc2a4\ud2b8\ub77c \ube0c\ub77c\uc774\ud2b8), 50ML, 8806322113556, 10,900\uc6d0, 8,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002383551355135643
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(12).jpg):
# '니베아데오드란트 스틱 (엑스트라 브라이트), 50ML, 8806322113556, 10,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF(12).jpg): ['니베아데오드란트 스틱 (엑스트라 브라이트)', '50ML', '8806322113556', '10,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(13).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(13).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub4dc\ub780\ud2b8\uc2a4\ud2f1(\ub4dc\ub77c\uc774\ucef4\ud3ec\ud2b8), 50ML, 8806322107227, 10,900\uc6d0, 8,900\uc6d0, \ud56b\uc378\uba38\ud074\ub9ac\ub2dd \ub86f\ub370KB\uad6d\ubbfc\uc2e0NH\ub18d\ud611\uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0\ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.012148684925503202
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 99,
#         "total_token_count": 2394
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(13).jpg):
# '니베아데오드란트스틱(드라이컴포트), 50ML, 8806322107227, 10,900원, 8,900원, 핫썸머클리닝 롯데KB국민신NH농협삼성카드 50,000원이상구매시 5천원롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(13).jpg): ['니베아데오드란트스틱(드라이컴포트)', '50ML', '8806322107227', '10,900원', '8,900원', '핫썸머클리닝 롯데KB국민신NH농협삼성카드 50,000원이상구매시 5천원롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(14).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(14).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub4dc\ub780\ud2b8\uc2a4\ud2f1(\ud384\uc564\ubdf0\ud2f0), 50ML, 198806322113549, 10,900\uc6d0, 8,900\uc6d0, \ud56b\uc378\uba38\ucfe8\ub7ec\ub2dd \ub86f\ub370KB\uad6d\ubbfc \uc2e0\ud654NH\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006688144861483106
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 102,
#         "total_token_count": 2397
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(14).jpg):
# '니베아데오드란트스틱(펄앤뷰티), 50ML, 198806322113549, 10,900원, 8,900원, 핫썸머쿨러닝 롯데KB국민 신화NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(14).jpg): ['니베아데오드란트스틱(펄앤뷰티)', '50ML', '198806322113549', '10,900원', '8,900원', '핫썸머쿨러닝 롯데KB국민 신화NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(15).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(15).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 (\ud384\uc564\ubdf0\ud2f0), 200ML, 1440058083219331, 14,500\uc6d0, 11,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0211041203716345
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(15).jpg):
# '니베아데오 (펄앤뷰티), 200ML, 1440058083219331, 14,500원, 11,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 BDF(15).jpg): ['니베아데오 (펄앤뷰티)', '200ML', '1440058083219331', '14,500원', '11,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(16).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(16).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624 (\ub4dc\ub77c\uc774), 200ML, 4005808321735, 14,500\uc6d0, 11,900\uc6d0, \ud56b\uc378\uba38\ucfe8\ub7ec \ub86f\ub370KB\uad6d\ubbfc\uc2e0NH\ub18d\ud611\uc0bc\uc131\uce74\ub4dc 50,000\uc6d0 \uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011927834023600039
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 92,
#         "total_token_count": 2387
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(16).jpg):
# '니베아 데오 (드라이), 200ML, 4005808321735, 14,500원, 11,900원, 핫썸머쿨러 롯데KB국민신NH농협삼성카드 50,000원 이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(16).jpg): ['니베아 데오 (드라이)', '200ML', '4005808321735', '14,500원', '11,900원', '핫썸머쿨러 롯데KB국민신NH농협삼성카드 50,000원 이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(17).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(17).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 (\ud654\uc774\ud2b8), 200ML, 394005900007513, 14,500\uc6d0, 11,900\uc6d0, \ud56b\uc378\uba38\ud074\ub9ac\ub2dd \ub86f\ub370KB\uad6d\ubbfc\uc2e0\ud654NH\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0\ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00933440588414669
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 96,
#         "total_token_count": 2391
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(17).jpg):
# '니베아데오 (화이트), 200ML, 394005900007513, 14,500원, 11,900원, 핫썸머클리닝 롯데KB국민신화NH농협 삼성카드 50,000원이상구매시 5천원롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(17).jpg): ['니베아데오 (화이트)', '200ML', '394005900007513', '14,500원', '11,900원', '핫썸머클리닝 롯데KB국민신화NH농협 삼성카드 50,000원이상구매시 5천원롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(18).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(18).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ud06c\ub9bc, 150ML, 184005808801046, 6,500\uc6d0, 5,200\uc6d0, \uac00\uaca9 \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0014613599193339444
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 49,
#         "total_token_count": 2344
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(18).jpg):
# '니베아 크림, 150ML, 184005808801046, 6,500원, 5,200원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 BDF(18).jpg): ['니베아 크림', '150ML', '184005808801046', '6,500원', '5,200원', '가격 할인']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(2).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(2).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120\ud0a4\uc988 \uc13c\uc11c\ud2f0\ube0c \ub864\uc628, 50ML, 460000042354932, 17,800\uc6d0, 8,900\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009557339549064636
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 60,
#         "total_token_count": 2355
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(2).jpg):
# '니베아 선키즈 센서티브 롤온, 50ML, 460000042354932, 17,800원, 8,900원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(2).jpg): ['니베아 선키즈 센서티브 롤온', '50ML', '460000042354932', '17,800원', '8,900원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(3).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(3).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ud504\ub85c\ud14d\ud2b8 \uc564 \ubaa8\uc774\uc2a4\ucdb0 \uc120\ub85c\uc158, \uc2dd\ubcc4\ubd88\uac00, 2300000424670, 17,800\uc6d0, 8,900\uc6d0, \ub2f4\uc744\uc218\ub85d \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009400484925609524
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(3).jpg):
# '니베아프로텍트 앤 모이스춰 선로션, 식별불가, 2300000424670, 17,800원, 8,900원, 담을수록 할인'
#
# 📌 개별 라인 분석 (롯데 BDF(3).jpg): ['니베아프로텍트 앤 모이스춰 선로션', '식별불가', '2300000424670', '17,800원', '8,900원', '담을수록 할인']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(4).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(4).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub354\ub9c8\uc13c\uc11c\ud2f0\ube0c \uc120\ub85c\uc158, 200ML, 84005900712288, 23,800\uc6d0, 11,900\uc6d0, 1\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -1.0569260250461303e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(4).jpg):
# '니베아 더마센서티브 선로션, 200ML, 84005900712288, 23,800원, 11,900원, 1개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(4).jpg): ['니베아 더마센서티브 선로션', '200ML', '84005900712288', '23,800원', '11,900원', '1개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(5).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(5).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ud0a4\uc988\uc36c\ub85c\uc158 (\uc2a4\uc719), 150ML, 4740058085184, 19,800\uc6d0, 9,900\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0004920681406344686
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 56,
#         "total_token_count": 2351
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(5).jpg):
# '니베아 키즈썬로션 (스윙), 150ML, 4740058085184, 19,800원, 9,900원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(5).jpg): ['니베아 키즈썬로션 (스윙)', '150ML', '4740058085184', '19,800원', '9,900원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(6).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(6).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\uc120 \ud398\uc774\uc2a4 \uc601\uc5d0\uc774\uc9c0 \ud06c\ub9bc, 50ML, 5340059004759781, 15,800\uc6d0, 7,900\uc6d0, 1\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00013241519530614217
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 60,
#         "total_token_count": 2355
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(6).jpg):
# '니베아선 페이스 영에이지 크림, 50ML, 5340059004759781, 15,800원, 7,900원, 1개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(6).jpg): ['니베아선 페이스 영에이지 크림', '50ML', '5340059004759781', '15,800원', '7,900원', '1개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(7).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(7).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120\uc138\ub7fc, 90ML, 254005808984763, 19,500\uc6d0, 9,750\uc6d0, 1\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.039275797513815075
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 52,
#         "total_token_count": 2347
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(7).jpg):
# '니베아 선세럼, 90ML, 254005808984763, 19,500원, 9,750원, 1개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 BDF(7).jpg): ['니베아 선세럼', '90ML', '254005808984763', '19,500원', '9,750원', '1개 이상 개당']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(8).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(8).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624\ub864\uc628 (\ud384\uc564\ubdf0\ud2f0), 50ML, 114005808323166, 9,400\uc6d0, 7,500\uc6d0, \ud56b\uc378\uba38\ucfe8\ub7ec\ub2dd \ub86f\ub370KB\uad6d\ubbfc \uc2e0\ud654NH\ub18d\ud611\uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.013585297428831761
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 98,
#         "total_token_count": 2393
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(8).jpg):
# '니베아데오롤온 (펄앤뷰티), 50ML, 114005808323166, 9,400원, 7,500원, 핫썸머쿨러닝 롯데KB국민 신화NH농협삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(8).jpg): ['니베아데오롤온 (펄앤뷰티)', '50ML', '114005808323166', '9,400원', '7,500원', '핫썸머쿨러닝 롯데KB국민 신화NH농협삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 BDF\롯데 BDF(9).jpg
# 이미지 열기 성공: image/롯데 BDF\롯데 BDF(9).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub864\uc628 (\ub4dc\ub77c\uc774), 50ML, 334005808725212, 9,400\uc6d0, 7,500\uc6d0, \ud56b\uc378\uba38\ucfe8\ub7ec \ub86f\ub370 KB\uad6d\ubbfc\uc2e0\ud654\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.012855886144840971
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 94,
#         "total_token_count": 2389
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 BDF(9).jpg):
# '니베아 데오롤온 (드라이), 50ML, 334005808725212, 9,400원, 7,500원, 핫썸머쿨러 롯데 KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 BDF(9).jpg): ['니베아 데오롤온 (드라이)', '50ML', '334005808725212', '9,400원', '7,500원', '핫썸머쿨러 롯데 KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(1).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(1).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uce74\ubc00 \ud578\ub4dc&\ub124\uc77c\ud06c\ub9bc \ubbf8\ub2c8 \uae30\ud68d, 30ML*3, 8809369782532, 9,000\uc6d0, 6,900\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0020469102943152712
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(1).jpg):
# '카밀 핸드&네일크림 미니 기획, 30ML*3, 8809369782532, 9,000원, 6,900원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디(1).jpg): ['카밀 핸드&네일크림 미니 기획', '30ML*3', '8809369782532', '9,000원', '6,900원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(10).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(10).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \ubc14\ub514\ub85c\uc158 (\ub9b4\ub809\uc2f1), 450ML, 48801008004890, 17,900\uc6d0, 10,700\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -8.968697411232982e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 58,
#         "total_token_count": 2353
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(10).jpg):
# '뉴트로지나 바디로션 (릴렉싱), 450ML, 48801008004890, 17,900원, 10,700원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디(10).jpg): ['뉴트로지나 바디로션 (릴렉싱)', '450ML', '48801008004890', '17,900원', '10,700원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(11).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(11).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \ubc14\ub514\uc624\uc77c, 250ML, 8801008017623, 19,900\uc6d0, 13,900\uc6d0, 05/15-06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0005927169074614843
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 60,
#         "total_token_count": 2355
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(11).jpg):
# '뉴트로지나 바디오일, 250ML, 8801008017623, 19,900원, 13,900원, 05/15-06/04'
#
# 📌 개별 라인 분석 (롯데 바디(11).jpg): ['뉴트로지나 바디오일', '250ML', '8801008017623', '19,900원', '13,900원', '05/15-06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(12).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(12).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4\uc815\ub9d0\uc21c\ud55c\ubc14\ub514\ubc00\ud06c(\ubca0\uc774\ube44\ud30c\uc6b0\ub354), 400G, 8809803577236, 9,900\uc6d0, 5,990\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.04792945111384157
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 61,
#         "total_token_count": 2356
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(12).jpg):
# '해피바스정말순한바디밀크(베이비파우더), 400G, 8809803577236, 9,900원, 5,990원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디(12).jpg): ['해피바스정말순한바디밀크(베이비파우더)', '400G', '8809803577236', '9,900원', '5,990원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(13).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(13).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc815\ub9d0 \ucd09\ucd09\ud55c \ubc14\ub514\ubc00\ud06c (\uc560\ud50c &\ubc14\ub098\ub098), 400G, 1088098035772291, 9,900\uc6d0, 5,990\uc6d0, 05/15-06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011631623313233658
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 74,
#         "total_token_count": 2369
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(13).jpg):
# '해피바스 정말 촉촉한 바디밀크 (애플 &바나나), 400G, 1088098035772291, 9,900원, 5,990원, 05/15-06/04'
#
# 📌 개별 라인 분석 (롯데 바디(13).jpg): ['해피바스 정말 촉촉한 바디밀크 (애플 &바나나)', '400G', '1088098035772291', '9,900원', '5,990원', '05/15-06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(14).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(14).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc624\ub9ac\uc9c0\ub110\uceec\ub809\uc158 \ub85c\uc158 \uc624\ub9ac\uc9c0\ub110\ud5a5, 500G, 78809803540445, 9,900\uc6d0, 8,500\uc6d0, \uac00\uaca9\ud560\uc778 05/15-06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004589973655465531
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 73,
#         "total_token_count": 2368
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(14).jpg):
# '해피바스 오리지널컬렉션 로션 오리지널향, 500G, 78809803540445, 9,900원, 8,500원, 가격할인 05/15-06/04'
#
# 📌 개별 라인 분석 (롯데 바디(14).jpg): ['해피바스 오리지널컬렉션 로션 오리지널향', '500G', '78809803540445', '9,900원', '8,500원', '가격할인 05/15-06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(15).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(15).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc624\ub9ac\uc9c0\ub110 \uceec\ub809\uc158 \ub85c\uc158 \ud30c\uc6b0\ub354\ud5a5, 500G, 8809803540438, 9,900\uc6d0, 8,500\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0019381205240885417
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 60,
#         "total_token_count": 2355
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(15).jpg):
# '해피바스 오리지널 컬렉션 로션 파우더향, 500G, 8809803540438, 9,900원, 8,500원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디(15).jpg): ['해피바스 오리지널 컬렉션 로션 파우더향', '500G', '8809803540438', '9,900원', '8,500원', '가격할인']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(16).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(16).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc624\ub9ac\uc9c0\ub110\uceec\ub809\uc158 \ub85c\uc158 \ucf54\ud2bc\ud5a5, 500G, 38809803540421, 9,900\uc6d0, 8,500\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.014105004779363082
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(16).jpg):
# '해피바스 오리지널컬렉션 로션 코튼향, 500G, 38809803540421, 9,900원, 8,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디(16).jpg): ['해피바스 오리지널컬렉션 로션 코튼향', '500G', '38809803540421', '9,900원', '8,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(17).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(17).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AK \ubc14\uc138\ub9b0 \ud578\ub4dc&\ub124\uc77c \ub85c\uc158, 450ML, 8801046862438, 9,900\uc6d0, 9,900\uc6d0, 1+1\nAK \ubc14\uc138\ub9b0 \uc54c\ub85c\uc5d0 \uc218\ub529 \ub85c\uc158, 450ML, 8801046423905, 9,900\uc6d0, 9,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -4.325659635166327e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 108,
#         "total_token_count": 2403
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(17).jpg):
# 'AK 바세린 핸드&네일 로션, 450ML, 8801046862438, 9,900원, 9,900원, 1+1\nAK 바세린 알로에 수딩 로션, 450ML, 8801046423905, 9,900원, 9,900원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디(17).jpg): ['AK 바세린 핸드&네일 로션', '450ML', '8801046862438', '9,900원', '9,900원', '1+1']
#
# 📌 개별 라인 분석 (롯데 바디(17).jpg): ['AK 바세린 알로에 수딩 로션', '450ML', '8801046423905', '9,900원', '9,900원', '1+1']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(18).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(18).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub3c4\ube0c \ubc14\ub514\ub85c\uc158 (\ud558\uc774\ub4dc\ub808\uc774\uc158), 400ML, 148801619805138, 15,900\uc6d0, 15,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.047705140030174925
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(18).jpg):
# '도브 바디로션 (하이드레이션), 400ML, 148801619805138, 15,900원, 15,900원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디(18).jpg): ['도브 바디로션 (하이드레이션)', '400ML', '148801619805138', '15,900원', '15,900원', '1+1']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(19).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(19).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AK \ubc14\uc138\ub9b0 \ub370\uc77c \ub9ac\ubaa8\uc774\uc2a4\ucc98 \ub85c\uc158, 450ML, 8801046862421, 9,900\uc6d0, 9,900\uc6d0, 1+1\nAK \ubc14\uc138\ub9b0 \ub9ac\ud504 \ud305 \ub9ac\ud398\uc5b4 \ub85c\uc158, 450ML, 8801046871546, 9,900\uc6d0, 9,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004186021197925914
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 110,
#         "total_token_count": 2405
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(19).jpg):
# 'AK 바세린 데일 리모이스처 로션, 450ML, 8801046862421, 9,900원, 9,900원, 1+1\nAK 바세린 리프 팅 리페어 로션, 450ML, 8801046871546, 9,900원, 9,900원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디(19).jpg): ['AK 바세린 데일 리모이스처 로션', '450ML', '8801046862421', '9,900원', '9,900원', '1+1']
#
# 📌 개별 라인 분석 (롯데 바디(19).jpg): ['AK 바세린 리프 팅 리페어 로션', '450ML', '8801046871546', '9,900원', '9,900원', '1+1']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(2).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(2).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \ud2b9\ubcc4 \uae30\ud68d\ud329, \uc2dd\ubcc4\ubd88\uac00, 78809369782839, 11,300\uc6d0, 8,900\uc6d0, 05/15-06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006414581385869828
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 63,
#         "total_token_count": 2358
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(2).jpg):
# '카밀 핸드크림 특별 기획팩, 식별불가, 78809369782839, 11,300원, 8,900원, 05/15-06/04'
#
# 📌 개별 라인 분석 (롯데 바디(2).jpg): ['카밀 핸드크림 특별 기획팩', '식별불가', '78809369782839', '11,300원', '8,900원', '05/15-06/04']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(20).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(20).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub3c4\ube0c \ubc14\ub514\ub85c\uc158 (\uc154\ud50c\ubc14\uc6b4\uc2a4), 400ML, \uc2dd\ubcc4\ubd88\uac00, 15,900\uc6d0, 15,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0030345621964205866
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 46,
#         "total_token_count": 2341
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(20).jpg):
# '도브 바디로션 (셔플바운스), 400ML, 식별불가, 15,900원, 15,900원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디(20).jpg): ['도브 바디로션 (셔플바운스)', '400ML', '식별불가', '15,900원', '15,900원', '1+1']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(21).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(21).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub3c4\ube0c \ubc14\ub514\ub85c\uc158 (\ub108\ub9ac\uc2dc\ub4dc\ub77c\ub514\uc5b8\uc2a4), 400ML, 8801619805121, 15,900\uc6d0, 15,900\uc6d0, 1+1"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01694319005739891
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(21).jpg):
# '도브 바디로션 (너리시드라디언스), 400ML, 8801619805121, 15,900원, 15,900원, 1+1'
#
# 📌 개별 라인 분석 (롯데 바디(21).jpg): ['도브 바디로션 (너리시드라디언스)', '400ML', '8801619805121', '15,900원', '15,900원', '1+1']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(3).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(3).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \uc778\ud150\uc2dc\ube0c, 100ML, \uc2dd\ubcc4\ubd88\uac00, 5,400\uc6d0, 5,400\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \ud074\ub798\uc2dd, 100ML, \uc2dd\ubcc4\ubd88\uac00, 7,200\uc6d0, 7,200\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006431230278902276
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 86,
#         "total_token_count": 2381
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(3).jpg):
# '카밀 핸드크림 인텐시브, 100ML, 식별불가, 5,400원, 5,400원, 식별불가\n카밀 핸드크림 클래식, 100ML, 식별불가, 7,200원, 7,200원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디(3).jpg): ['카밀 핸드크림 인텐시브', '100ML', '식별불가', '5,400원', '5,400원', '식별불가']
#
# 📌 개별 라인 분석 (롯데 바디(3).jpg): ['카밀 핸드크림 클래식', '100ML', '식별불가', '7,200원', '7,200원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(4).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(4).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \ubc14\uc774\ud0c8 Q10, 75ML, 64000196936646, 7,200\uc6d0, 5,400\uc6d0, 05/15-06/04\n\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \uc790\ubabd, 75ML, 124000196936684, 7,200\uc6d0, 7,200\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008453797677467609
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 116,
#         "total_token_count": 2411
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(4).jpg):
# '카밀 핸드크림 바이탈 Q10, 75ML, 64000196936646, 7,200원, 5,400원, 05/15-06/04\n카밀 핸드크림 자몽, 75ML, 124000196936684, 7,200원, 7,200원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디(4).jpg): ['카밀 핸드크림 바이탈 Q10', '75ML', '64000196936646', '7,200원', '5,400원', '05/15-06/04']
#
# 📌 개별 라인 분석 (롯데 바디(4).jpg): ['카밀 핸드크림 자몽', '75ML', '124000196936684', '7,200원', '7,200원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(5).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(5).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ucfe4\ub2ec \ubc14\ub514\ub85c\uc158 (\uc77c\ub791\uc77c\ub791), 718ML, 8809953771621, 14,900\uc6d0, 9,900\uc6d0, 05/15~06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.006519351755419085
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 62,
#         "total_token_count": 2357
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(5).jpg):
# '쿤달 바디로션 (일랑일랑), 718ML, 8809953771621, 14,900원, 9,900원, 05/15~06/04'
#
# 📌 개별 라인 분석 (롯데 바디(5).jpg): ['쿤달 바디로션 (일랑일랑)', '718ML', '8809953771621', '14,900원', '9,900원', '05/15~06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(6).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(6).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ucfe4\ub2ec \ubc14\ub514\ub85c\uc158 (\ud654\uc774\ud2b8\uba38\uc2a4\ud06c), 718ML, 8809568748506, 14,900\uc6d0, 9,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0007207634410372486
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 54,
#         "total_token_count": 2349
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(6).jpg):
# '쿤달 바디로션 (화이트머스크), 718ML, 8809568748506, 14,900원, 9,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 바디(6).jpg): ['쿤달 바디로션 (화이트머스크)', '718ML', '8809568748506', '14,900원', '9,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(7).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(7).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ucfe4\ub2ec \ubc14\ub514\ub85c\uc158 (\ubca0\uc774\ube44\ud30c\uc6b0\ub354), 718ML, 8809568748490, 14,900\uc6d0, 9,900\uc6d0, 05/15-06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011973220854997635
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 64,
#         "total_token_count": 2359
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(7).jpg):
# '쿤달 바디로션 (베이비파우더), 718ML, 8809568748490, 14,900원, 9,900원, 05/15-06/04'
#
# 📌 개별 라인 분석 (롯데 바디(7).jpg): ['쿤달 바디로션 (베이비파우더)', '718ML', '8809568748490', '14,900원', '9,900원', '05/15-06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(8).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(8).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ube44\ub178 \uc2a4\ud2b8\ub808\uc2a4 \ub9b4\ub9ac\ud504 \ub85c\uc158, 354ML, 38801108003748, 21,900\uc6d0, 13,900\uc6d0, 05/15~06/04"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008755947993351863
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 65,
#         "total_token_count": 2360
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(8).jpg):
# '아비노 스트레스 릴리프 로션, 354ML, 38801108003748, 21,900원, 13,900원, 05/15~06/04'
#
# 📌 개별 라인 분석 (롯데 바디(8).jpg): ['아비노 스트레스 릴리프 로션', '354ML', '38801108003748', '21,900원', '13,900원', '05/15~06/04']
#
# 🚀 처리 중: image/롯데 바디\롯데 바디(9).jpg
# 이미지 열기 성공: image/롯데 바디\롯데 바디(9).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \ubc14\ub514\ub85c\uc158 (\ub370\uc77c\ub9ac), 450ML, 78801108000983, 17,900\uc6d0, 10,700\uc6d0, \uac00\uaca9\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009024161716987347
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 58,
#         "total_token_count": 2353
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 바디(9).jpg):
# '뉴트로지나 바디로션 (데일리), 450ML, 78801108000983, 17,900원, 10,700원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 바디(9).jpg): ['뉴트로지나 바디로션 (데일리)', '450ML', '78801108000983', '17,900원', '10,700원', '가격할인']
#
# 🚀 처리 중: image/롯데 선\롯데 선(1).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(1).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "AHC \ub9c8\uc2a4\ud130\uc988 \uc544\ucfe0\uc544\ub9ac\uce58 \uc120\ud06c\ub9bc (\uae30\ud68d), 30ML*2\uc785, 118809759093996, 18,000\uc6d0, 18,000\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002055015880614519
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 64,
#         "total_token_count": 2359
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(1).jpg):
# 'AHC 마스터즈 아쿠아리치 선크림 (기획), 30ML*2입, 118809759093996, 18,000원, 18,000원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선(1).jpg): ['AHC 마스터즈 아쿠아리치 선크림 (기획)', '30ML*2입', '118809759093996', '18,000원', '18,000원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~50)
#
# 🚀 처리 중: image/롯데 선\롯데 선(10).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(10).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud53c\uc9c0\uc624\uac94 DMT UV \uc120\ub85c\uc158, \uc2dd\ubcc4\ubd88\uac00, 98801051215991, 28,000\uc6d0, 28,000\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.001919350393538205
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 53,
#         "total_token_count": 2348
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(10).jpg):
# '피지오겔 DMT UV 선로션, 식별불가, 98801051215991, 28,000원, 28,000원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선(10).jpg): ['피지오겔 DMT UV 선로션', '식별불가', '98801051215991', '28,000원', '28,000원', '식별불가']
#
# 🚀 처리 중: image/롯데 선\롯데 선(11).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(11).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud53c\uc9c0\uc624\uac94 DMT \ub9c8\uc77c\ub4dc \ub9b4\ub9ac\ud504 \uc36c, 40G, 8801051293708, 28,000\uc6d0, 28,000\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008703640678472686
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(11).jpg):
# '피지오겔 DMT 마일드 릴리프 썬, 40G, 8801051293708, 28,000원, 28,000원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선(11).jpg): ['피지오겔 DMT 마일드 릴리프 썬', '40G', '8801051293708', '28,000원', '28,000원', '식별불가']
#
# 🚀 처리 중: image/롯데 선\롯데 선(12).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(12).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc2f8\uc774\ub2c9 \uc5d4\uc870\uc774 \uc120\ud06c\ub9bc, \uc2dd\ubcc4\ubd88\uac00, 8809546004730, 17,800\uc6d0, 8,900\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
# ...
#
# 🚀 처리 중: image/롯데 선\롯데 선(27).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(27).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \uc218\ubd84\uc7a5\ubcbd \uc120\ud06c\ub9bc, 40ML, 8809517476986, 12,900\uc6d0, 12,900\uc6d0, \ud56b\uc378\uba38\ud074\ub9ac\ub2dd \ub86f\ub370KB\uad6d\ubbfc\uc2e0NH\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0019533400472841766
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 95,
#         "total_token_count": 2390
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(27).jpg):
# '듀이트리 수분장벽 선크림, 40ML, 8809517476986, 12,900원, 12,900원, 핫썸머클리닝 롯데KB국민신NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 선(27).jpg): ['듀이트리 수분장벽 선크림', '40ML', '8809517476986', '12,900원', '12,900원', '핫썸머클리닝 롯데KB국민신NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 선\롯데 선(28).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(28).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \ucee4\ubc84\ube44\ube44 \uc120\ud06c\ub9bc, 40ML, 8809517476443, 11,500\uc6d0, 11,500\uc6d0, \ud56b\uc378\uba38\ud074\ub9ac\ub2dd \ub86f\ub370KB\uad6d\ubbfc\uc2e0\ud654\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01804516691910593
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 95,
#         "total_token_count": 2390
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(28).jpg):
# '듀이트리 커버비비 선크림, 40ML, 8809517476443, 11,500원, 11,500원, 핫썸머클리닝 롯데KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 선(28).jpg): ['듀이트리 커버비비 선크림', '40ML', '8809517476443', '11,500원', '11,500원', '핫썸머클리닝 롯데KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 7 처리 시작 (파일 61~70)
#
# 🚀 처리 중: image/롯데 선\롯데 선(29).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(29).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \ud551\ud06c\ud1a4\uc5c5 \uc120\ud06c\ub9bc, 50ML, 8809517476429, 13,200\uc6d0, 13,200\uc6d0, \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0006027218814079578
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 52,
#         "total_token_count": 2347
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(29).jpg):
# '듀이트리 핑크톤업 선크림, 50ML, 8809517476429, 13,200원, 13,200원, 증정'
#
# 📌 개별 라인 분석 (롯데 선(29).jpg): ['듀이트리 핑크톤업 선크림', '50ML', '8809517476429', '13,200원', '13,200원', '증정']
#
# 🚀 처리 중: image/롯데 선\롯데 선(3).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(3).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8 \uc120\uc2a4\ud2f1 (\uc9f1\uad6c), 19 g, 8809949560468, 19,900\uc6d0, 13,930\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002404434701143685
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(3).jpg):
# '퓨어더마 퍼펙트 선스틱 (짱구), 19 g, 8809949560468, 19,900원, 13,930원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(3).jpg): ['퓨어더마 퍼펙트 선스틱 (짱구)', '19 g', '8809949560468', '19,900원', '13,930원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 선\롯데 선(30).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(30).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \ucee4\ubc84\ube44\ube44 \uc120\ucfe0\uc158, 14G, 8809517476498, 13,300\uc6d0, 13,300\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00011051321437336364
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 53,
#         "total_token_count": 2348
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(30).jpg):
# '듀이트리 커버비비 선쿠션, 14G, 8809517476498, 13,300원, 13,300원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 선(30).jpg): ['듀이트리 커버비비 선쿠션', '14G', '8809517476498', '13,300원', '13,300원', '식별불가']
#
# 🚀 처리 중: image/롯데 선\롯데 선(31).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(31).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \uba40\ud2f0\ud1a4\uc5c5 \uc120\uc2a4\ud2f1, 13G, 8809517477006, 15,300\uc6d0, 15,300\uc6d0, \ud56b\uc378\uba38\ucfe8\ub7ec \ub86f\ub370 KB\uad6d\ubbfc\uc2e0\ud654\ub18d\ud611 \uc0bc\uc131\uce74\ub4dc 50,000\uc6d0\uc774\uc0c1\uad6c\ub9e4\uc2dc 5\ucc9c\uc6d0 \ub86f\ub370\uc0c1\ud488\uad8c\uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011838725993507786
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 95,
#         "total_token_count": 2390
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(31).jpg):
# '듀이트리 멀티톤업 선스틱, 13G, 8809517477006, 15,300원, 15,300원, 핫썸머쿨러 롯데 KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정'
#
# 📌 개별 라인 분석 (롯데 선(31).jpg): ['듀이트리 멀티톤업 선스틱', '13G', '8809517477006', '15,300원', '15,300원', '핫썸머쿨러 롯데 KB국민신화농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정']
#
# 🚀 처리 중: image/롯데 선\롯데 선(32).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(32).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc774\ud2b8\ub9ac \ucfe8\ub9c1\uc9c4\uc815 \uc120\uc2a4\ud2f1, 20G, 8809517476481, 10,200\uc6d0, 10,200\uc6d0, \uc99d\uc815"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03823059797286987
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 52,
#         "total_token_count": 2347
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(32).jpg):
# '듀이트리 쿨링진정 선스틱, 20G, 8809517476481, 10,200원, 10,200원, 증정'
#
# 📌 개별 라인 분석 (롯데 선(32).jpg): ['듀이트리 쿨링진정 선스틱', '20G', '8809517476481', '10,200원', '10,200원', '증정']
#
# 🚀 처리 중: image/롯데 선\롯데 선(4).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(4).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud4e8\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8\uc120\ucfe0\uc158 (\uc9f1\uad6c), 15ML, 378809949560475, 29,900\uc6d0, 20,930\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0019237439407676948
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 61,
#         "total_token_count": 2356
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(4).jpg):
# '퓨어더마 퍼펙트선쿠션 (짱구), 15ML, 378809949560475, 29,900원, 20,930원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(4).jpg): ['퓨어더마 퍼펙트선쿠션 (짱구)', '15ML', '378809949560475', '29,900원', '20,930원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 선\롯데 선(5).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(5).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub4c0\uc5b4\ub354\ub9c8 \ud37c\ud399\ud2b8 \uc120\ud06c\ub9bc (\uc9f1\uad6c), 80ML, 158809949560451, 16,900\uc6d0, 11,830\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.002590392456680048
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 61,
#         "total_token_count": 2356
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(5).jpg):
# '듀어더마 퍼펙트 선크림 (짱구), 80ML, 158809949560451, 16,900원, 11,830원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(5).jpg): ['듀어더마 퍼펙트 선크림 (짱구)', '80ML', '158809949560451', '16,900원', '11,830원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 선\롯데 선(6).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(6).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c\ud3ec\ucf13\ubaac UV\uaf2c\ubd80\uae30\uc120\ud06c\ub9bc, 80ML, 8809949544383, 16,900\uc6d0, 11,830\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -6.9908156435479195e-06
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 57,
#         "total_token_count": 2352
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(6).jpg):
# '벨먼포켓몬 UV꼬부기선크림, 80ML, 8809949544383, 16,900원, 11,830원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(6).jpg): ['벨먼포켓몬 UV꼬부기선크림', '80ML', '8809949544383', '16,900원', '11,830원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 선\롯데 선(7).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(7).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c\ud3ec\ucf13\ubaac UV \uc774\ube0c\uc774\uc120\uc2a4\ud2f1, 19.5G, 28809949544369, 19,900\uc6d0, 13,930\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.011006043354670206
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 60,
#         "total_token_count": 2355
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(7).jpg):
# '벨먼포켓몬 UV 이브이선스틱, 19.5G, 28809949544369, 19,900원, 13,930원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(7).jpg): ['벨먼포켓몬 UV 이브이선스틱', '19.5G', '28809949544369', '19,900원', '13,930원', '2개 이상 개당']
#
# 🚀 처리 중: image/롯데 선\롯데 선(8).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(8).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c\ud3ec\ucf13\ubaac UV \ud53c\uce74\uce04\uc120\uc2a4\ud2f1, 19.5G, 8809949544352, 19,900\uc6d0, 13,930\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00024240713377120132
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 59,
#         "total_token_count": 2354
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(8).jpg):
# '벨먼포켓몬 UV 피카츄선스틱, 19.5G, 8809949544352, 19,900원, 13,930원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(8).jpg): ['벨먼포켓몬 UV 피카츄선스틱', '19.5G', '8809949544352', '19,900원', '13,930원', '2개 이상 개당']
#
# ⏳ API 사용량 조절을 위해 60초 대기 중...
#
# 🔄 배치 8 처리 시작 (파일 71~71)
#
# 🚀 처리 중: image/롯데 선\롯데 선(9).jpg
# 이미지 열기 성공: image/롯데 선\롯데 선(9).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubca8\uba3c\ud3ec\ucf13\ubaac UV \ud53c\uce74\uce04\uc120\ud06c\ub9bc, 80ML, 48809949544376, 16,900\uc6d0, 11,830\uc6d0, 2\uac1c \uc774\uc0c1 \uac1c\ub2f9"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0009449060107099599
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2295,
#         "candidates_token_count": 58,
#         "total_token_count": 2353
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (롯데 선(9).jpg):
# '벨먼포켓몬 UV 피카츄선크림, 80ML, 48809949544376, 16,900원, 11,830원, 2개 이상 개당'
#
# 📌 개별 라인 분석 (롯데 선(9).jpg): ['벨먼포켓몬 UV 피카츄선크림', '80ML', '48809949544376', '16,900원', '11,830원', '2개 이상 개당']
#
# ✅ 롯데 BDF 카테고리 정보가 롯데 BDF.csv 파일에 저장되었습니다.
# 총 18개 상품 정보 처리 완료
#               파일명                       제품명     용량             상품코드   정상가_표시  \
# 0   롯데 BDF(1).jpg           니베아선 키브 프로텍트 로션  200ML    4040059006001  23,800원
# 1  롯데 BDF(10).jpg  니베아데오 더마컨트를 롤온 (퓨어 센서티브)   50ML  304005808676590  10,400원
# 2  롯데 BDF(11).jpg            니베아 데오롤온 (화이트)   50ML  614005808355020   9,400원
#
#     할인가_표시                                              할인 내용
# 0  11,900원                                           2개 이상 개당
# 1   8,900원  핫썸머클리닝 롯데 KB국민신NH농협 삼성카드 50,000원이상구매시 5천원 롯데상품권증정
# 2   7,500원                                                 증정
#
# ✅ 롯데 바디 카테고리 정보가 롯데 바디.csv 파일에 저장되었습니다.
# 총 25개 상품 정보 처리 완료
#              파일명               제품명      용량            상품코드   정상가_표시   할인가_표시  \
# 0   롯데 바디(1).jpg  카밀 핸드&네일크림 미니 기획  30ML*3   8809369782532   9,000원   6,900원
# 1  롯데 바디(10).jpg  뉴트로지나 바디로션 (릴렉싱)   450ML  48801008004890  17,900원  10,700원
# 2  롯데 바디(11).jpg        뉴트로지나 바디오일   250ML   8801008017623  19,900원  13,900원
#
#          할인 내용
# 0         가격할인
# 1         식별불가
# 2  05/15-06/04
#
# ✅ 롯데 선 카테고리 정보가 롯데 선.csv 파일에 저장되었습니다.
# 총 40개 상품 정보 처리 완료
#             파일명                      제품명       용량             상품코드   정상가_표시  \
# 0   롯데 선(1).jpg  AHC 마스터즈 아쿠아리치 선크림 (기획)  30ML*2입  118809759093996  18,000원
# 1  롯데 선(10).jpg          피지오겔 DMT UV 선로션     식별불가   98801051215991  28,000원
# 2  롯데 선(11).jpg       피지오겔 DMT 마일드 릴리프 썬      40G    8801051293708  28,000원
#
#     할인가_표시 할인 내용
# 0  18,000원  식별불가
# 1  28,000원  식별불가
# 2  28,000원  식별불가
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 83개 상품 정보 처리 완료
