# %%
# !pip install -q -U google-generativeai
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv


load_dotenv()

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")


genai.configure(api_key=GOOGLE_API_KEY)

# %%
# for m in genai.list_models():
#     if "generateContent" in m.supported_generation_methods:
#         print(m.name)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
from PIL import Image


def ask_for_product_info(image_path):
    try:
        # 이미지 열기
        img = Image.open(image_path)
        img = img.convert("L")
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # 모델에 이미지와 프롬프트 함께 전달
        response = model.generate_content(
            [
                "Instructions:\
                1. Detect the price tags in the image and extract the text from those price tags.\
                2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):\
                   - Product name\
                   - Capacity\
                   - Product code (13 digits)\
                   - Regular price (in KRW)\
                   - Discount price (in KRW)\
                   - Discount content\
                3. If the discount price is not provided, use the same value as the regular price.\
                4. If any item is incorrect or unclear, please write '식별불가' for that item.\
                5. Always add '원' after the price.\
                6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력.\
                7. If, for any reason, none of the items can be found, write '식별불가' for all items.\
                8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified.\
                9. Perform all tasks without any refusal to the greatest extent possible.\
                10. Only use the information from the price tag.\
                11. If a discount is included, please only list the final discounted price.\
                12. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다.\
                13. If the number presumed to be the product code is 13 digits or longer, only the last 13 digits are extracted. (Example: If it is 124834028 / 4005808725212(A)(B), the product code is 4005808725212)\
                출력 형식 예시(필수 준수)\
                각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]\
                예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당\
                예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1",
                img,
            ]
        )

        print(f"모델 응답: {response}")
        return response.text
    except Exception as e:
        print(f"오류 발생: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=30):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": items[2],
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 60
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (1).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (1).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \ud3ec\uc624\ubbf8\uba58\uc194, 175g, 7702018002344, 5,600\uc6d0, 3,920\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00016484203699388002
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (1).jpg):
# '질레트 포오미멘솔, 175g, 7702018002344, 5,600원, 3,920원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (1).jpg): ['질레트 포오미멘솔', '175g', '7702018002344', '5,600원', '3,920원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (10).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (10).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc00\ud06c\ubc14\uc624\ubc25 \ubaa8\uc774\uc2a4\ud2b8 \ubc14\ub514\ub85c\uc158 \ubc14\ub2d0\ub77c\uc624\ub80c\uc9c0, \uc2dd\ubcc4\ubd88\uac00, 8802667011236, 6,900\uc6d0, 6,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\ubc00\ud06c\ubc14\uc624\ubc25 \ubaa8\uc774\uc2a4\ud2b8 \ubc14\ub514\ub85c\uc158 \ud074\ub9b0\uc19d, 400m, 8802667011229, 6,900\uc6d0, 6,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0004332668951943389
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 117,
#         "total_token_count": 4046
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (10).jpg):
# '밀크바오밥 모이스트 바디로션 바닐라오렌지, 식별불가, 8802667011236, 6,900원, 6,900원, 식별불가\n밀크바오밥 모이스트 바디로션 클린솝, 400m, 8802667011229, 6,900원, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (10).jpg): ['밀크바오밥 모이스트 바디로션 바닐라오렌지', '식별불가', '8802667011236', '6,900원', '6,900원', '식별불가']
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (10).jpg): ['밀크바오밥 모이스트 바디로션 클린솝', '400m', '8802667011229', '6,900원', '6,900원', '식별불가']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (11).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (11).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uce74\ubc00 \ud578\ub4dc\ud06c\ub9bc \ubca0\uc2a4\ud2b8 \ud2b8\ub9ac\uc624 \uae30\ud68d\uc138\ud2b8, \uc2dd\ubcc4\ubd88\uac00, 8809369782563, 10,900\uc6d0, 10,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.003348043662006572
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 59,
#         "total_token_count": 3988
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (11).jpg):
# '카밀 핸드크림 베스트 트리오 기획세트, 식별불가, 8809369782563, 10,900원, 10,900원, 식별불가'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (11).jpg): ['카밀 핸드크림 베스트 트리오 기획세트', '식별불가', '8809369782563', '10,900원', '10,900원', '식별불가']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (12).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (12).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2ec\ub780 \ub514\uc62c\ub9ac\ube0c \uc778\ud150\uc2dc\ube0c \ud578\ub4dc\ud06c\ub9bc 2\uc885 \uc138\ud2b8, \uc2dd\ubcc4\ubd88\uac00, 8690529010400, 9,900\uc6d0, 8,900\uc6d0, 1,000\uc6d0 \ud560\uc778\n\uc624 \uae30\ud68d\uc138\ud2b8, \uc2dd\ubcc4\ubd88\uac00, 8809369782563, 900\uc6d0, 900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.
uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.008944541215896606
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2381,
#         "candidates_token_count": 64,
#         "total_token_count": 2445
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (16).jpg):
# '프로글라이드 퓨어원 쉐이빙폼, 245g, 4902430590013, 11,600원, 8,120원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (16).jpg): ['프로글라이드 퓨어원 쉐이빙폼', '245g', '4902430590013', '11,600원', '8,120원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (17).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (17).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc9c8\ub808\ud2b8 \uc2a4\ud0a8\ud14d \ud3fc, 245g, 4902430913836, 9,000\uc6d0, 6,300\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0016823222762659977
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2381,
#         "candidates_token_count": 57,
#         "total_token_count": 2438
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (17).jpg):
# '질레트 스킨텍 폼, 245g, 4902430913836, 9,000원, 6,300원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (17).jpg): ['질레트 스킨텍 폼', '245g', '4902430913836', '9,000원', '6,300원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (18).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (18).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub274\ud2b8\ub85c\uc9c0\ub098 \ub370\uc77c\ub9ac \ub9bd \ubc24 SPF15, 4g, 8801008004876, 4,900\uc6d0, 3,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0010378812589953022
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2381,
#         "candidates_token_count": 62,
#         "total_token_count": 2443
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (18).jpg):
# '뉴트로지나 데일리 립 밤 SPF15, 4g, 8801008004876, 4,900원, 3,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (18).jpg): ['뉴트로지나 데일리 립 밤 SPF15', '4g', '8801008004876', '4,900원', '3,900원', '신세계포인트 적립시 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (19).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (19).jpg, 크기: (721, 961)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc138\ub9b0 \ub9bd \ud14c\ub77c\ud53c \ucf54\ucf54\uc544\ubc84\ud130, 7g, 8801619049884, \uc2dd\ubcc4\ubd88\uac00, 6,000\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.04986103238730595
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 2381,
#         "candidates_token_count": 58,
#         "total_token_count": 2439
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (19).jpg):
# '바세린 립 테라피 코코아버터, 7g, 8801619049884, 식별불가, 6,000원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (19).jpg): ['바세린 립 테라피 코코아버터', '7g', '8801619049884', '식별불가', '6,000원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (2).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (2).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub3c4\ub8e8\ucf54 \ucfe8\ub9c1 \ud504\ub808\uc26c\ud5c8\ube0c \uc250\uc774\ube59\ud3fc, 210ml, 8809389188420, 4,200\uc6d0, 2,900\uc6d0, 1,300\uc6d0"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.024283626040474314
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 61,
#         "total_token_count": 3990
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (2).jpg):
# '도루코 쿨링 프레쉬허브 쉐이빙폼, 210ml, 8809389188420, 4,200원, 2,900원, 1,300원'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (2).jpg): ['도루코 쿨링 프레쉬허브 쉐이빙폼', '210ml', '8809389188420', '4,200원', '2,900원', '1,300원']
#
# 🚀 처리 중: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (3).jpg
# 이미지 열기 성공: image/경쟁사 바디맨핸드립 (1)\경쟁사 바디맨핸드립 (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ud574\ud53c\ubc14\uc2a4 \uc624\ub9ac\uc9c0\ub110 \ubc14\ub514\ub85c\uc158 \ud30c\uc6b0\ub354, 500g, 8809803540438, 9,900\uc6d0, 8,900\uc6d0, 1,000\uc6d0\n\uc120, 400g, 8809803577236, 3,800\uc6d0, 3,800\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.033083911125476546
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 104,
#         "total_token_count": 4033
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (3).jpg):
# '해피바스 오리지널 바디로션 파우더, 500g, 8809803540438, 9,900원, 8,900원, 1,000원\n선, 400g, 8809803577236, 3,800원, 3,800원, 식별불가'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (3).jpg): ['해피바스 오리지널 바디로션 파우더', '500g', '8809803540438', '9,900원', '8,900원', '1,000원']
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 
900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\ubc00\ud06c\ubc14\uc624\ubc25 \ubaa8\uc774\uc2a4\ud2b8\ubc14\ub514\ub85c\uc158 \ud654\uc774\ud2b8\uba38\uc2a4\ud06c, \uc2dd\ubcc4\ubd88\uac00, 8802667005761, 6,900\uc6d0, 6,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\ucfe4\ub2ec \ud4e8\uc5b4 \ubc14\ub514\ud06c, \uc2dd\ubcc4\ubd88\uac00, \uc2dd\ubcc4\ubd88\uac00, 13.900\uc6d0, 13.900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.005630704966731042
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 159,
#         "total_token_count": 4088
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (경쟁사 바디맨핸드립 (9).jpg):
# '밀크바오밥 모이스트바디로션 베이비파우더, 식별불가, 8802667005785, 6,900원, 6,900원, 식별불가\n밀크바오밥 모이스트바디로션 화이트머스크, 식별불가, 8802667005761, 6,900원, 6,900원, 식별불가\n쿤달 퓨어 바디크, 식별불가, 식별불가, 13.900원, 13.900원, 식별불가'
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (9).jpg): ['밀크바오밥 모이스트바디로션 베이비파우더', '식별불가', '8802667005785', '6,900원', '6,900원', '식별불가']
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (9).jpg): ['밀크바오밥 모이스트바디로션 화이트머스크', '식별불가', '8802667005761', '6,900원', '6,900원', '식별불가']
#
# 📌 개별 라인 분석 (경쟁사 바디맨핸드립 (9).jpg): ['쿤달 퓨어 바디크', '식별불가', '식별불가', '13.900원', '13.900원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (1).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (1).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub4dc\ub780\ud2b8 \uc2a4\ud2f1 \ud384 \ubdf0\ud2f0, 50ml, 8806322113549, 10,900\uc6d0, 8,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0025546057149767876
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 64,
#         "total_token_count": 3993
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (1).jpg):
# '니베아 데오드란트 스틱 펄 뷰티, 50ml, 8806322113549, 10,900원, 8,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (1).jpg): ['니베아 데오드란트 스틱 펄 뷰티', '50ml', '8806322113549', '10,900원', '8,900원', '신세계포인트 적립시 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (10).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (10).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ud0a4\uc988 \ud504\ub85c\ud14d\ud2b8 \uc564 \uc13c\uc11c\ud2f0\ube0c \ub864\uc628, 10ml\ub2f9 3560\uc6d0, 0000042354932, 17,800\uc6d0, 8,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0323564084370931
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 75,
#         "total_token_count": 4004
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (10).jpg):
# '니베아 선 키즈 프로텍트 앤 센서티브 롤온, 10ml당 3560원, 0000042354932, 17,800원, 8,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (10).jpg): ['니베아 선 키즈 프로텍트 앤 센서티브 롤온', '10ml당 3560원', '0000042354932', '17,800원', '8,900원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (11).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (11).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ud0a4\uc988 \uc13c\uc11c\ud2f0\ube0c \ub85c\uc158, 200ml, 4005900600172, 23,800\uc6d0, 11,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0013735027750954032
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 64,
#         "total_token_count": 3993
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (11).jpg):
# '니베아 선 키즈 센서티브 로션, 200ml, 4005900600172, 23,800원, 11,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (11).jpg): ['니베아 선 키즈 센서티브 로션', '200ml', '4005900600172', '23,800원', '11,900원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (12).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (12).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc6b8\ud2b8\ub77c \uc36c \uc138\ud2f0\ube0c \uc120\ub85c\uc158, 200ml, 4001900712288, 23,800\uc6d0, 11,900\uc6d0, \uc2e0\uc138\uacc4 \ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0
uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00012344555421309037
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 55,
#         "total_token_count": 3984
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (19).jpg):
# '니베아 리페어 앤 케어 크림, 식별불가, 6001051004744, 13,500원, 13,500원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (19).jpg): ['니베아 리페어 앤 케어 크림', '식별불가', '6001051004744', '13,500원', '13,500원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (2).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (2).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624\ub4dc\ub780\ud2b8 \uc2a4\ud2f1 \uc5d1\uc2a4\ud2b8\ub77c \ube0c\ub77c\uc774\ud2b8, \uc2dd\ubcc4\ubd88\uac00, 8806322113556, 10,900\uc6d0, 8,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01358014143119424
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 59,
#         "total_token_count": 3988
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (2).jpg):
# '니베아 데오드란트 스틱 엑스트라 브라이트, 식별불가, 8806322113556, 10,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (2).jpg): ['니베아 데오드란트 스틱 엑스트라 브라이트', '식별불가', '8806322113556', '10,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (20).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (20).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc778\uc0e4\uc6cc \ubc14\ub514\ub85c\uc158 \ub098\ub9ac\uc2f1(\uac74\uc870), 400ml, 4005800111723, 9,900\uc6d0, 9,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -4.283137667667249e-05
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (20).jpg):
# '니베아 인샤워 바디로션 나리싱(건조), 400ml, 4005800111723, 9,900원, 9,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (20).jpg): ['니베아 인샤워 바디로션 나리싱(건조)', '400ml', '4005800111723', '9,900원', '9,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (21).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (21).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ud2b8\ub9ad\uc2a4\ud578\ub4dc\ud06c\ub9bc(\ud29c\ube0c), 75ml, 4005808820221, \uc2dd\ubcc4\ubd88\uac00, 4,620\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.009189419600428368
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 49,
#         "total_token_count": 3978
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (21).jpg):
# '아트릭스핸드크림(튜브), 75ml, 4005808820221, 식별불가, 4,620원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (21).jpg): ['아트릭스핸드크림(튜브)', '75ml', '4005808820221', '식별불가', '4,620원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (22).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (22).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub9ac\ud398\uc5b4 \ubc14\ub514 \ub85c\uc158, 625ml, 0056594012288, 12,900\uc6d0, 12,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\uc2dd\ubcc4\ubd88\uac00, 400ml, 8808237470, 900\uc6d0, 900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0122121902222329
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 94,
#         "total_token_count": 4023
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (22).jpg):
# '니베아 리페어 바디 로션, 625ml, 0056594012288, 12,900원, 12,900원, 식별불가\n식별불가, 400ml, 8808237470, 900원, 900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (22).jpg): ['니베아 리페어 바디 로션', '625ml', '0056594012288', '12,900원', '12,900원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 BDF (22).jpg): ['식별불가', '400ml', '8808237470', '900원', '900원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (3).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624 \uc2a4\ud504\ub808\uc774 \ud384 \uc564 \ubdf0\ud2f0, 200ml, 4005808321933, 14,500\uc6d0, 11,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.046867934140292083
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 66,
#         "total_token_count": 3995
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (3).jpg):
# '니베아 데오 스프레이 펄 앤 뷰티, 200ml, 4005808321933, 14,500원, 11,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (3).jpg): ['니베아 데오 스프레이 펄 앤 뷰티', '200ml', '4005808321933', '14,500원', '11,900원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (4).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (4).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544\ub370\uc624 \uc88b\uc740 \ub9e5\uc2a4\ud2b8\ub77c\ud654\uc774\ud2b8 50ml, 50ml, 4005808355020, 9,400\uc6d0, 7,520\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.04769132286310196
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 64,
#         "total_token_count": 3993
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (4).jpg):
# '니베아데오 좋은 맥스트라화이트 50ml, 50ml, 4005808355020, 9,400원, 7,520원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (4).jpg): ['니베아데오 좋은 맥스트라화이트 50ml', '50ml', '4005808355020', '9,400원', '7,520원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (5).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (5).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624 \uc2a4\ud504\ub808\uc774 \uc5d1\uc2a4\ud2b8\ub77c \ube0c\ub77c\uc774\ud2b8, 10ml\ub2f9725\uc6d0/\uc2dd\ubcc4\ubd88\uac00, 4005900007513, 14,500\uc6d0, 11,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.038097496032714846
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 75,
#         "total_token_count": 4004
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (5).jpg):
# '니베아 데오 스프레이 엑스트라 브라이트, 10ml당725원/식별불가, 4005900007513, 14,500원, 11,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (5).jpg): ['니베아 데오 스프레이 엑스트라 브라이트', '10ml당725원/식별불가', '4005900007513', '14,500원', '11,900원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (6).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (6).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ub370\uc624 \ub864\uc628 \ud544\ub9e8\ubdf0\ud2f0, 50ml, 4005808323166, 9,400\uc6d0, 7,520\uc6d0, \uc815\uc0c1\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.14528790804056022
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 52,
#         "total_token_count": 3981
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (6).jpg):
# '니베아 데오 롤온 필맨뷰티, 50ml, 4005808323166, 9,400원, 7,520원, 정상가'
#
# 📌 개별 라인 분석 (이마트 BDF (6).jpg): ['니베아 데오 롤온 필맨뷰티', '50ml', '4005808323166', '9,400원', '7,520원', '정상가']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (7).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (7).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ub370\uc774\uc2a4 \uc564 \uba54\uc774\uc9c0 \ud06c\ub9bc, 50ml, 4005900475978, 15,800\uc6d0, 7,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.05521741605574085
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 62,
#         "total_token_count": 3991
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (7).jpg):
# '니베아 선 데이스 앤 메이지 크림, 50ml, 4005900475978, 15,800원, 7,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (7).jpg): ['니베아 선 데이스 앤 메이지 크림', '50ml', '4005900475978', '15,800원', '7,900원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (8).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (8).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \uc120 \ud398\uc774\uc2a4 \uc218\ub529 \uc13c\uc11c\ud2f0\ube0c \ud06c\ub9bc, 50ml, 4005900475220, 15,800\uc6d0, 7,900\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0010287475127440232
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 65,
#         "total_token_count": 3994
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (8).jpg):
# '니베아 선 페이스 수딩 센서티브 크림, 50ml, 4005900475220, 15,800원, 7,900원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (8).jpg): ['니베아 선 페이스 수딩 센서티브 크림', '50ml', '4005900475220', '15,800원', '7,900원', '신세계포인트 적립시 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~50)
#
# 🚀 처리 중: image/이마트 BDF (1)\이마트 BDF (9).jpg
# 이미지 열기 성공: image/이마트 BDF (1)\이마트 BDF (9).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2c8\ubca0\uc544 \ud0a4\uc988 \uc6b8\ud2b8\ub77c \ud504\ub85c\ud14d\ud2b8 \ub85c\uc158, 150ml, 4005808518494, 19,800\uc6d0, 9,900\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.00960511701148853
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 57,
#         "total_token_count": 3986
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 BDF (9).jpg):
# '니베아 키즈 울트라 프로텍트 로션, 150ml, 4005808518494, 19,800원, 9,900원, 식별불가'
#
# ...
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \uc21c\ud55c \ubb34\uae30\uc790\ucc28 \uc120\uc2a4\ud2f1 14G(\uc2dc\ub098\ubaa8, 14G, 8801166407953, 29,980\uc6d0, 14,990\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778\n\uadf8\ub9b0\ud551\uac70 \uc57c\uc678\ub180\uc774 \uc6cc\uc154\ube14 \uc120\ud06c\ub9bc 80ml(\uc2dc, \uc2dd\ubcc4\ubd88\uac00, 8801166407922, 25,980\uc6d0, 12,990\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.003924126718558517
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 153,
#         "total_token_count": 4082
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (17).jpg):
# '그린핑거 순한 무기자차 선스틱 14G(시나모, 14G, 8801166407953, 29,980원, 14,990원, S포인트 적립시 2개 50%할인\n그린핑거 야외놀이 워셔블 선크림 80ml(시, 식별불가, 8801166407922, 25,980원, 12,990원, S포인트 적립시 2개 50%할인'
#
# 📌 개별 라인 분석 (이마트 선 (17).jpg): ['그린핑거 순한 무기자차 선스틱 14G(시나모', '14G', '8801166407953', '29,980원', '14,990원', 'S포인트 적립시 2개 50%할인']
#
# 📌 개별 라인 분석 (이마트 선 (17).jpg): ['그린핑거 야외놀이 워셔블 선크림 80ml(시', '식별불가', '8801166407922', '25,980원', '12,990원', 'S포인트 적립시 2개 50%할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 6 처리 시작 (파일 51~60)
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (18).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (18).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubc14\uc774\uc624\ub354\ub9c8 \ud3ec\ud1a0\ub364 \uc544\ucfe0\uc544 \ud50c\ub8e8\uc774\ub4dc SPF50+, \uc2dd\ubcc4\ubd88\uac00, 3701129807385, 31,980\uc6d0, 15,990\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0028510149290312584
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 67,
#         "total_token_count": 3996
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (18).jpg):
# '바이오더마 포토덤 아쿠아 플루이드 SPF50+, 식별불가, 3701129807385, 31,980원, 15,990원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 선 (18).jpg): ['바이오더마 포토덤 아쿠아 플루이드 SPF50+', '식별불가', '3701129807385', '31,980원', '15,990원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (19).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (19).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uadf8\ub9b0\ud551\uac70 \ubb3c\ub180\uc774 \uc120\ud06c\ub9bc \uc6cc\ud130\ud504\ub8e8\ud504, 50ml, 8801166388122, 21,980\uc6d0, 10,990\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778\n\uadf8\ub9b0\ud551\uac70 \uc21c\ud55c \ubb34\uae30\uc790\ucc28 \uc120\ucfe0\uc158, 12G, 8801156407946, 29,980\uc6d0, 14,990\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.004387425099100385
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 140,
#         "total_token_count": 4069
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (19).jpg):
# '그린핑거 물놀이 선크림 워터프루프, 50ml, 8801166388122, 21,980원, 10,990원, S포인트 적립시 2개 50%할인\n그린핑거 순한 무기자차 선쿠션, 12G, 8801156407946, 29,980원, 14,990원, S포인트 적립시 2개 50%할인'
#
# 📌 개별 라인 분석 (이마트 선 (19).jpg): ['그린핑거 물놀이 선크림 워터프루프', '50ml', '8801166388122', '21,980원', '10,990원', 'S포인트 적립시 2개 50%할인']
#
# 📌 개별 라인 분석 (이마트 선 (19).jpg): ['그린핑거 순한 무기자차 선쿠션', '12G', '8801156407946', '29,980원', '14,990원', 'S포인트 적립시 2개 50%할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (2).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (2).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2e5\ud130\uc9c0 \ube0c\ub77c\uc774\ud2b8\ub2dd \uc120, 35ML, 8809695361210, 25,980\uc6d0, 12,990\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0003729177767346645
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 58,
#         "total_token_count": 3987
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (2).jpg):
# '닥터지 브라이트닝 선, 35ML, 8809695361210, 25,980원, 12,990원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 선 (2).jpg): ['닥터지 브라이트닝 선', '35ML', '8809695361210', '25,980원', '12,990원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (3).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (3).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc140\ud4e8\uc804\uc528 \ub808\uc774\uc800 \uc36c\uc2a4\ud06c\ub9b0 100, 35ml, 8809694620417, 27,980\uc6d0, 13,990\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\uc57c\ub2e4 \uc120 \uc5d0\uc13c\uc2a4, \uc2dd\ubcc4\ubd88\uac00, 8809340386919, 20,980\uc6d0, 10,490\uc6d0, \uae30\ud68d"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.03232692309788295
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 105,
#         "total_token_count": 4034
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (3).jpg):
# '셀퓨전씨 레이저 썬스크린 100, 35ml, 8809694620417, 27,980원, 13,990원, 식별불가\n야다 선 에센스, 식별불가, 8809340386919, 20,980원, 10,490원, 기획'
#
# 📌 개별 라인 분석 (이마트 선 (3).jpg): ['셀퓨전씨 레이저 썬스크린 100', '35ml', '8809694620417', '27,980원', '13,990원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 선 (3).jpg): ['야다 선 에센스', '식별불가', '8809340386919', '20,980원', '10,490원', '기획']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (4).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (4).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uba54\uc774\ub514 \uadf8\ub9b0\ud504\ub85c\ud3f4\ub9ac\uc2a4 \uc62c\ub9c8\uc77c\ub4dc\uc120, 40ml, 8805915777014, 11,900\uc6d0, 11,900\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.046210542091956505
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 65,
#         "total_token_count": 3994
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (4).jpg):
# '메이디 그린프로폴리스 올마일드선, 40ml, 8805915777014, 11,900원, 11,900원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 선 (4).jpg): ['메이디 그린프로폴리스 올마일드선', '40ml', '8805915777014', '11,900원', '11,900원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (5).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (5).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ubcf8\ud2b8\ub9ac \ubca0\ub9ac\uc158\ube14\ub7ed SPF50+PA++++, 50ml, 2000001211373, 14,980\uc6d0, 7,490\uc6d0, \uc2e0\uc138\uacc4\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.007830710638137091
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 63,
#         "total_token_count": 3992
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (5).jpg):
# '본트리 베리션블럭 SPF50+PA++++, 50ml, 2000001211373, 14,980원, 7,490원, 신세계포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 선 (5).jpg): ['본트리 베리션블럭 SPF50+PA++++', '50ml', '2000001211373', '14,980원', '7,490원', '신세계포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (6).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (6).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc2a4\ud2b8\ub77c\uc774\ub371\uc2a4 \uce74\ubc0d \ud328\ub4dc 70\ub9e4, \uc2dd\ubcc4\ubd88\uac00, 8809724701253, 19,980\uc6d0, 13,980\uc6d0, \uc2dd\ubcc4\ubd88\uac00\n\uc2a4\ud2b8\ub9ac\ubbf8\uc2a4 \uc13c\uc2dc\ud2f0\ube0c \ud328\ub4dc 55\ub9e4, \uc2dd\ubcc4\ubd88\uac00, 0041388008134, 10,980\uc6d0, 7,980\uc6d0, \uc2dd\ubcc4\ubd88\uac00"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.0034194467342005368
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 113,
#         "total_token_count": 4042
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (6).jpg):
# '스트라이덱스 카밍 패드 70매, 식별불가, 8809724701253, 19,980원, 13,980원, 식별불가\n스트리미스 센시티브 패드 55매, 식별불가, 0041388008134, 10,980원, 7,980원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 선 (6).jpg): ['스트라이덱스 카밍 패드 70매', '식별불가', '8809724701253', '19,980원', '13,980원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 선 (6).jpg): ['스트리미스 센시티브 패드 55매', '식별불가', '0041388008134', '10,980원', '7,980원', '식별불가']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (7).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (7).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uc544\ud1a0\ud31c \ud1a1\ud1a1 \ud398\uc774\uc15c \uc120\ud329\ud2b8, 15g, 8809723787128, 24,000\uc6d0, 12,000\uc6d0, 2\uac1c 50%\ud560\uc778\n\uc544\ud1a0\ud31c \uc57c\uc678\ub180\uc774 \uc120\uc2a4\ud2f1, 21g, 8809723787142, 24,000\uc6d0, 12,000\uc6d0, 2\uac1c 50%\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.01408142302216602
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 119,
#         "total_token_count": 4048
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (7).jpg):
# '아토팜 톡톡 페이셜 선팩트, 15g, 8809723787128, 24,000원, 12,000원, 2개 50%할인\n아토팜 야외놀이 선스틱, 21g, 8809723787142, 24,000원, 12,000원, 2개 50%할인'
#
# 📌 개별 라인 분석 (이마트 선 (7).jpg): ['아토팜 톡톡 페이셜 선팩트', '15g', '8809723787128', '24,000원', '12,000원', '2개 50%할인']
#
# 📌 개별 라인 분석 (이마트 선 (7).jpg): ['아토팜 야외놀이 선스틱', '21g', '8809723787142', '24,000원', '12,000원', '2개 50%할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (8).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (8).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\ub2e5\ud130\uc544\ud1a0 \uc54c\ub85c\uc5d0\ubca0\ub77c \uc36c\uc2a4\ud2f1, 150ml, 880109202133, 33,980\uc6d0, 16,990\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778\n\uc544\ud1a0\ud31c \uc57c\uc678\ub180\uc774 \uc120\ubc00\ud06c 55g + \ud074\ub80c\uc9d5\ud328\ub4dc, 55g, 8809723787111, 28,000\uc6d0, 14,000\uc6d0, S\ud3ec\uc778\ud2b8 \uc801\ub9bd\uc2dc 2\uac1c 50%\ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.013240021136071947
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 144,
#         "total_token_count": 4073
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (8).jpg):
# '닥터아토 알로에베라 썬스틱, 150ml, 880109202133, 33,980원, 16,990원, S포인트 적립시 2개 50%할인\n아토팜 야외놀이 선밀크 55g + 클렌징패드, 55g, 8809723787111, 28,000원, 14,000원, S포인트 적립시 2개 50%할인'
#
# 📌 개별 라인 분석 (이마트 선 (8).jpg): ['닥터아토 알로에베라 썬스틱', '150ml', '880109202133', '33,980원', '16,990원', 'S포인트 적립시 2개 50%할인']
#
# 📌 개별 라인 분석 (이마트 선 (8).jpg): ['아토팜 야외놀이 선밀크 55g + 클렌징패드', '55g', '8809723787111', '28,000원', '14,000원', 'S포인트 적립시 2개 50%할인']
#
# 🚀 처리 중: image/이마트 선 (1)\이마트 선 (9).jpg
# 이미지 열기 성공: image/이마트 선 (1)\이마트 선 (9).jpg, 크기: (4000, 3000)
# 모델 응답: response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "\uad81\uc911\ube44\uc801 \ud504\ub809\uc2dc \uc13c\uc2a4\ud2f1 \ub9c8\uc77c\ub4dc, 23g, 8809278717243, 26,980\uc6d0, 13,490\uc6d0, 2\uac1c 50%\ud560\uc778\n\uad81\uc911\ube44\ubca0\uc774\ube44 \uc774\uc9c0\uc6cc\uc2dc \uc120\ub85c\uc158, 60g, 8809278716833, 20,000\uc6d0, 20,000\uc6d0, 2\uac1c \uad6c\ub9e4\uc2dc 50% \ud560\uc778"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.016761462519487996
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 3929,
#         "candidates_token_count": 127,
#         "total_token_count": 4056
#       },
#       "model_version": "gemini-2.0-flash"
#     }),
# )
#
# 📌 반환 텍스트 (이마트 선 (9).jpg):
# '궁중비적 프렉시 센스틱 마일드, 23g, 8809278717243, 26,980원, 13,490원, 2개 50%할인\n궁중비베이비 이지워시 선로션, 60g, 8809278716833, 20,000원, 20,000원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 선 (9).jpg): ['궁중비적 프렉시 센스틱 마일드', '23g', '8809278717243', '26,980원', '13,490원', '2개 50%할인']
#
# 📌 개별 라인 분석 (이마트 선 (9).jpg): ['궁중비베이비 이지워시 선로션', '60g', '8809278716833', '20,000원', '20,000원', '2개 구매시 50% 할인']
#
# ✅ 경쟁사 바디맨핸드립 (1) 카테고리 정보가 경쟁사 바디맨핸드립 (1).csv 파일에 저장되었습니다.
# 총 26개 상품 정보 처리 완료
#                    파일명                     제품명    용량           상품코드  정상가_표시  \
# 0   경쟁사 바디맨핸드립 (1).jpg               질레트 포오미멘솔  175g  7702018002344  5,600원
# 1  경쟁사 바디맨핸드립 (10).jpg  밀크바오밥 모이스트 바디로션 바닐라오렌지  식별불가  8802667011236  6,900원
# 2  경쟁사 바디맨핸드립 (10).jpg     밀크바오밥 모이스트 바디로션 클린솝  400m  8802667011229  6,900원
#
#    할인가_표시          할인 내용
# 0  3,920원  신세계포인트 적립시 할인
# 1  6,900원           식별불가
# 2  6,900원           식별불가
#
# ✅ 이마트 BDF (1) 카테고리 정보가 이마트 BDF (1).csv 파일에 저장되었습니다.
# 총 23개 상품 정보 처리 완료
#                 파일명                      제품명           용량           상품코드  \
# 0   이마트 BDF (1).jpg        니베아 데오드란트 스틱 펄 뷰티         50ml  8806322113549
# 1  이마트 BDF (10).jpg  니베아 선 키즈 프로텍트 앤 센서티브 롤온  10ml당 3560원  0000042354932
# 2  이마트 BDF (11).jpg         니베아 선 키즈 센서티브 로션        200ml  4005900600172
#
#     정상가_표시   할인가_표시          할인 내용
# 0  10,900원   8,900원  신세계포인트 적립시 할인
# 1  17,800원   8,900원  신세계포인트 적립시 할인
# 2  23,800원  11,900원  신세계포인트 적립시 할인
#
# ✅ 이마트 선 (1) 카테고리 정보가 이마트 선 (1).csv 파일에 저장되었습니다.
# 총 29개 상품 정보 처리 완료
#               파일명               제품명    용량           상품코드   정상가_표시   할인가_표시  \
# 0   이마트 선 (1).jpg     닥터지 그린마일드 업 선  35ml  8809838651307  25,980원  12,990원
# 1  이마트 선 (10).jpg  궁중비책 워터풀 선로션 마일드   80g  8809278716802  26,980원  13,490원
# 2  이마트 선 (11).jpg  그린핑거 야외놀이 힘센 선크림  70ml  8801166404754  21,980원  10,990원
#
#                할인 내용
# 0               식별불가
# 1           2개 50%할인
# 2  S포인트 적립시 2개 50%할인
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 78개 상품 정보 처리 완료
