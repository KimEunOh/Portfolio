# %%
# !pip install -q -U google-cloud-aiplatform python-dotenv

# %%
import pathlib
import textwrap

from vertexai import init
from vertexai.generative_models import GenerativeModel, Part, Image as VertexImage

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv
from google.oauth2 import service_account
from google.auth.exceptions import DefaultCredentialsError


load_dotenv()

PROJECT_ID = os.getenv("VERTEX_PROJECT_ID") or os.getenv("GOOGLE_CLOUD_PROJECT")
LOCATION = os.getenv("VERTEX_LOCATION", "us-central1")
SA_PATH = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

assert PROJECT_ID, "환경변수 VERTEX_PROJECT_ID 또는 GOOGLE_CLOUD_PROJECT가 필요합니다."

creds = None
if SA_PATH and os.path.exists(SA_PATH):
    creds = service_account.Credentials.from_service_account_file(
        SA_PATH,
        scopes=["https://www.googleapis.com/auth/cloud-platform"],
    )

try:
    if creds is not None:
        init(project=PROJECT_ID, location=LOCATION, credentials=creds)
    else:
        init(project=PROJECT_ID, location=LOCATION)
    print(
        f"Vertex init ok: project={PROJECT_ID}, location={LOCATION}, sa={'yes' if creds else 'no'}"
    )
except DefaultCredentialsError as e:
    raise AssertionError(
        "ADC(기본 자격증명)가 없습니다. 옵션: 1) gcloud auth application-default login 실행, 2) 서비스계정 키 경로를 GOOGLE_APPLICATION_CREDENTIALS에 설정"
    ) from e
# Out:
# Python-dotenv could not parse statement starting at line 4
# Vertex init ok: project=norse-baton-471707-t3, location=us-central1, sa=yes

# %%
# 인증/환경 자가진단 (SA 우선, 없으면 ADC)
import os as _os
import google.auth as _g_auth
from google.cloud import aiplatform as _aip
from google.oauth2 import service_account as _sa

_effective_creds = None
_sa_path = _os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

if _sa_path and _os.path.exists(_sa_path):
    try:
        _effective_creds = _sa.Credentials.from_service_account_file(
            _sa_path, scopes=["https://www.googleapis.com/auth/cloud-platform"]
        )
        print("Service Account creds loaded:", _sa_path)
    except Exception as e:
        print("SA 로드 오류:", e)

if _effective_creds is None:
    try:
        _adc_creds, _adc_project = _g_auth.default(
            scopes=["https://www.googleapis.com/auth/cloud-platform"]
        )
        _effective_creds = _adc_creds
        print("ADC project:", _adc_project)
    except Exception as e:
        print("ADC 미설정:", e)

print("ENV PROJECT:", PROJECT_ID)
print("LOCATION:", LOCATION)
print("MODEL_NAME:", os.getenv("VERTEX_MODEL_NAME", "gemini-2.0-flash"))

try:
    _aip.init(project=PROJECT_ID, location=LOCATION, credentials=_effective_creds)
    print(
        "AI Platform init ok (",
        ("SA" if _sa_path and _effective_creds else "ADC/None"),
        ")",
    )
except Exception as e:
    print("AI Platform init error:", e)
# Out:
# Service Account creds loaded: C:\\keo\\portfolio-ai\\03_cv-multimodal\\OCR\\OCR\\norse-baton-471707-t3-027d359779dd.json
# ENV PROJECT: norse-baton-471707-t3
# LOCATION: us-central1
# MODEL_NAME: gemini-2.0-flash
# AI Platform init ok ( SA )

# %%
import os

MODEL_NAME = os.getenv("VERTEX_MODEL_NAME", "gemini-2.0-flash")
print(f"Using Vertex AI model: {MODEL_NAME}")
# Out:
# Using Vertex AI model: gemini-2.0-flash

# %%
model = GenerativeModel(MODEL_NAME)

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
import re


def sanitize_product_code(raw_code: str) -> str:
    """상품코드를 13자리 숫자로 강제한다.
    - 숫자만 추출
    - 13자리보다 길면 마지막 13자리 사용
    - 13자리보다 짧으면 '식별불가'
    """
    digits = re.sub(r"\D", "", raw_code or "")
    if len(digits) >= 13:
        return digits[-13:]
    return "식별불가"

# %%
from PIL import Image
import time
import os
from google.api_core.exceptions import (
    ResourceExhausted,
    ServiceUnavailable,
    InternalServerError,
    DeadlineExceeded,
)


def ask_for_product_info(image_path):
    try:
        img = Image.open(image_path)
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # Vertex AI 이미지 입력: 파일에서 직접 로드
        image_part = VertexImage.load_from_file(image_path)

        prompt = (
            "Instructions:"
            "1. Detect the price tags in the image and extract the text from those price tags."
            "2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):"
            "   - Product name"
            "   - Capacity"
            "   - Product code (13 digits)"
            "   - Regular price (in KRW)"
            "   - Discount price (in KRW)"
            "   - Discount content"
            "3. If the discount price is not provided, use the same value as the regular price."
            "4. If any item is incorrect or unclear, please write '식별불가' for that item."
            "5. Always add '원' after the price."
            "6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력."
            "7. If, for any reason, none of the items can be found, write '식별불가' for all items."
            "8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified."
            "9. Only use the information from the price tag."
            "10. If a discount is included, please only list the final discounted price."
            "11. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다."
            "12. If the number presumed to be the product code is 13 digits or longer, only the last 13 digits are extracted. (Example: If it is 124834028 / 4005808725212(A)(B), the product code is 4005808725212)"
            "13. Product code MUST BE EXACTLY 13 digits. Extract digits only: if longer, use LAST 13 digits; if shorter than 13 after digit-only filtering, output '식별불가'."
            "출력 형식 예시(필수 준수)"
            "각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]"
            "예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당"
            "예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1"
        )

        # 단순 지수 백오프
        backoff_seconds = 5
        for attempt in range(4):
            try:
                response = model.generate_content([prompt, image_part])
                print(f"모델 응답: {response}")
                return response.text
            except (
                ResourceExhausted,
                ServiceUnavailable,
                InternalServerError,
                DeadlineExceeded,
            ) as e:
                if attempt == 3:
                    raise
                sleep_for = backoff_seconds * (2**attempt)
                print(
                    f"일시적 오류: {e.__class__.__name__}: {e}. {sleep_for}초 후 재시도 ({attempt+1}/4)"
                )
                time.sleep(sleep_for)

    except Exception as e:
        print(f"오류 발생: {e.__class__.__name__}: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=30):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # 보정: 상품코드 13자리 강제
                    raw_code = items[2]
                    fixed_code = sanitize_product_code(raw_code)
                    if fixed_code != raw_code:
                        print(f"상품코드 보정: {raw_code} -> {fixed_code}")

                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": fixed_code,
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 41
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (1).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (1).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 립, 4G, 8801008004876, 3,900원, 3,900원, 켄뷰 30,000원 미상 구매시 롯데 상품권 5천원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0011582546670671919
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 71
#   total_token_count: 4014
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (1).jpg):
# '뉴트로지나 립, 4G, 8801008004876, 3,900원, 3,900원, 켄뷰 30,000원 미상 구매시 롯데 상품권 5천원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (1).jpg): ['뉴트로지나 립', '4G', '8801008004876', '3,900원', '3,900원', '켄뷰 30,000원 미상 구매시 롯데 상품권 5천원권 증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (10).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (10).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아비노 데일리 모이스춰라이징 로션, 354ML, 8801108003670, 21,900원, 14,200원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0067486107349395748
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (10).jpg):
# '아비노 데일리 모이스춰라이징 로션, 354ML, 8801108003670, 21,900원, 14,200원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (10).jpg): ['아비노 데일리 모이스춰라이징 로션', '354ML', '8801108003670', '21,900원', '14,200원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (11).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (11).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아비노 스트레스 릴리프 로션, 354ML, 8801108003748, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0007302045256276674
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 79
#   total_token_count: 4022
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (11).jpg):
# '아비노 스트레스 릴리프 로션, 354ML, 8801108003748, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (11).jpg): ['아비노 스트레스 릴리프 로션', '354ML', '8801108003748', '21,900원', '21,900원', '켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (12).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (12).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아비노 스킨 릴리프 로션, 354ML, 8801108003717, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정\n스릴리프 로션, 식별불가, 8801108003748, 21,900원, 21,900원, 원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.003998663074286409
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 129
#   total_token_count: 4072
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (12).jpg):
# '아비노 스킨 릴리프 로션, 354ML, 8801108003717, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정\n스릴리프 로션, 식별불가, 8801108003748, 21,900원, 21,900원, 원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (12).jpg): ['아비노 스킨 릴리프 로션', '354ML', '8801108003717', '21,900원', '21,900원', '켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정']
#
# 📌 개별 라인 분석 (롯데 시즌2동 (12).jpg): ['스릴리프 로션', '식별불가', '8801108003748', '21,900원', '21,900원', '원권 증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (13).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (13).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아비노 에너자이징 로션, 354ML, 8801108003946, 21,900원, 14,200원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.010433945518273573
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 52
#   total_token_count: 3995
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (13).jpg):
# '아비노 에너자이징 로션, 354ML, 8801108003946, 21,900원, 14,200원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (13).jpg): ['아비노 에너자이징 로션', '354ML', '8801108003946', '21,900원', '14,200원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (14).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (14).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "존슨즈 베이비로션(핑크), 500ML+200ML, 8801106001041, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0017955352862675984
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 84
#   total_token_count: 4027
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (14).jpg):
# '존슨즈 베이비로션(핑크), 500ML+200ML, 8801106001041, 21,900원, 21,900원, 켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (14).jpg): ['존슨즈 베이비로션(핑크)', '500ML+200ML', '8801106001041', '21,900원', '21,900원', '켄뷰 30,000원 이상 구매시 롯데상품권 5천원권 증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (15).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (15).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "존슨즈 베이비로션 (핑크), 식별불가, 8801108001041, 1,900원, 1,900원, 식별불가\n존슨즈 베이비로션 (화이트), 500ML, 8801008020937, 17,900원, 17,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0018209361091808037
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 108
#   total_token_count: 4051
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (15).jpg):
# '존슨즈 베이비로션 (핑크), 식별불가, 8801108001041, 1,900원, 1,900원, 식별불가\n존슨즈 베이비로션 (화이트), 500ML, 8801008020937, 17,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (15).jpg): ['존슨즈 베이비로션 (핑크)', '식별불가', '8801108001041', '1,900원', '1,900원', '식별불가']
#
# 📌 개별 라인 분석 (롯데 시즌2동 (15).jpg): ['존슨즈 베이비로션 (화이트)', '500ML', '8801008020937', '17,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (16).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (16).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "존슨즈 베드타임로션, 500ML, 8801008101247, 20,900원, 20,900원, 켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -9.2542877322749086e-05
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 76
#   total_token_count: 4019
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (16).jpg):
# '존슨즈 베드타임로션, 500ML, 8801008101247, 20,900원, 20,900원, 켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (16).jpg): ['존슨즈 베드타임로션', '500ML', '8801008101247', '20,900원', '20,900원', '켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (17).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (17).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "존슨즈 베이비오일 (레귤러), 500ML, 7880100802123, 15,900원, 15,900원, 10/16-10/29"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.041501030325889587
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 64
#   total_token_count: 4007
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (17).jpg):
# '존슨즈 베이비오일 (레귤러), 500ML, 7880100802123, 15,900원, 15,900원, 10/16-10/29'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (17).jpg): ['존슨즈 베이비오일 (레귤러)', '500ML', '7880100802123', '15,900원', '15,900원', '10/16-10/29']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (18).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (18).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "존슨즈 베이비오일(레귤러), 식별불가, 7880100802123, 15,900원, 15,900원, 식별불가\n존슨즈 베드타임오일, 식별불가, 128801008020418, 18,900원, 18,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.026714916662736371
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 110
#   total_token_count: 4053
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (18).jpg):
# '존슨즈 베이비오일(레귤러), 식별불가, 7880100802123, 15,900원, 15,900원, 식별불가\n존슨즈 베드타임오일, 식별불가, 128801008020418, 18,900원, 18,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (18).jpg): ['존슨즈 베이비오일(레귤러)', '식별불가', '7880100802123', '15,900원', '15,900원', '식별불가']
#
# 📌 개별 라인 분석 (롯데 시즌2동 (18).jpg): ['존슨즈 베드타임오일', '식별불가', '128801008020418', '18,900원', '18,900원', '식별불가']
# 상품코드 보정: 128801008020418 -> 8801008020418
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (19).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (19).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아케어&컬러 립밤 딥레드, 4.8G, 4006000098791, 식별불가, 6,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0075755489093286017
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 54
#   total_token_count: 3997
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (19).jpg):
# '니베아케어&컬러 립밤 딥레드, 4.8G, 4006000098791, 식별불가, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (19).jpg): ['니베아케어&컬러 립밤 딥레드', '4.8G', '4006000098791', '식별불가', '6,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (2).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (2).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 립 (2번들), 4G, 8801108001218, 6,500원, 6,500원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.016685612347661232
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 49
#   total_token_count: 3992
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (2).jpg):
# '뉴트로지나 립 (2번들), 4G, 8801108001218, 6,500원, 6,500원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (2).jpg): ['뉴트로지나 립 (2번들)', '4G', '8801108001218', '6,500원', '6,500원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (20).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (20).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아케어&컬러 립밤 크림코랄, 4.8G, 4006000102184, 6,900원, 6,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -1.1175521649420261e-05
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (20).jpg):
# '니베아케어&컬러 립밤 크림코랄, 4.8G, 4006000102184, 6,900원, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (20).jpg): ['니베아케어&컬러 립밤 크림코랄', '4.8G', '4006000102184', '6,900원', '6,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (21).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (21).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어 딥 모이스춰 언센티드 (무향, 2.2G, 8806322114744, 6,900원, 6,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00016208855648998355
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 61
#   total_token_count: 4004
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (21).jpg):
# '니베아 립케어 딥 모이스춰 언센티드 (무향, 2.2G, 8806322114744, 6,900원, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (21).jpg): ['니베아 립케어 딥 모이스춰 언센티드 (무향', '2.2G', '8806322114744', '6,900원', '6,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (22).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (22).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어 히알루론 로제, 5.2G, 4005800324741, 6,500원, 6,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -3.1418323686177081e-05
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (22).jpg):
# '니베아 립케어 히알루론 로제, 5.2G, 4005800324741, 6,500원, 6,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (22).jpg): ['니베아 립케어 히알루론 로제', '5.2G', '4005800324741', '6,500원', '6,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (23).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (23).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 히알루론 모이스쳐 플러스 립밤, 5.2G, 8806322114263, 6,500원, 6,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.01050714583232485
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 58
#   total_token_count: 4001
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (23).jpg):
# '니베아 히알루론 모이스쳐 플러스 립밤, 5.2G, 8806322114263, 6,500원, 6,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (23).jpg): ['니베아 히알루론 모이스쳐 플러스 립밤', '5.2G', '8806322114263', '6,500원', '6,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (24).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (24).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립(에센셜), 4.8G, 4005808369485, 4,400원, 4,400원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -9.158549159217406e-06
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 51
#   total_token_count: 3994
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (24).jpg):
# '니베아 립(에센셜), 4.8G, 4005808369485, 4,400원, 4,400원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (24).jpg): ['니베아 립(에센셜)', '4.8G', '4005808369485', '4,400원', '4,400원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (25).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (25).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아립 (딸기), 4.8G, 4005806372881, 5,500원, 5,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0034066888750815877
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 49
#   total_token_count: 3992
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (25).jpg):
# '니베아립 (딸기), 4.8G, 4005806372881, 5,500원, 5,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (25).jpg): ['니베아립 (딸기)', '4.8G', '4005806372881', '5,500원', '5,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (26).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (26).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어기획 (체리), 4.8G, 78806322102147, 7,500원, 7,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.011868317560716109
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (26).jpg):
# '니베아 립케어기획 (체리), 4.8G, 78806322102147, 7,500원, 7,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (26).jpg): ['니베아 립케어기획 (체리)', '4.8G', '78806322102147', '7,500원', '7,500원', '식별불가']
# 상품코드 보정: 78806322102147 -> 8806322102147
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (27).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (27).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어기획 (모이스처), 4.8G, 8806322102468, 7,500원, 7,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00011668510057709434
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (27).jpg):
# '니베아 립케어기획 (모이스처), 4.8G, 8806322102468, 7,500원, 7,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (27).jpg): ['니베아 립케어기획 (모이스처)', '4.8G', '8806322102468', '7,500원', '7,500원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (28).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (28).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립 (포맨), 4.8G, 4005808373000, 4,400원, 4,400원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00031689058989286422
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 50
#   total_token_count: 3993
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (28).jpg):
# '니베아 립 (포맨), 4.8G, 4005808373000, 4,400원, 4,400원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (28).jpg): ['니베아 립 (포맨)', '4.8G', '4005808373000', '4,400원', '4,400원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (29).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (29).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아립 (메드 프로텍션), 4.8G, 4005808850631, 6,500원, 6,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00032305140764667437
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 52
#   total_token_count: 3995
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (29).jpg):
# '니베아립 (메드 프로텍션), 4.8G, 4005808850631, 6,500원, 6,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (29).jpg): ['니베아립 (메드 프로텍션)', '4.8G', '4005808850631', '6,500원', '6,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (3).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (3).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 인텐스 리페어 핸드크림 2번들, 56g, 8801108001201, 13,400원, 9,000원, 10/16~10/29"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.024329735551561628
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 70
#   total_token_count: 4013
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (3).jpg):
# '뉴트로지나 인텐스 리페어 핸드크림 2번들, 56g, 8801108001201, 13,400원, 9,000원, 10/16~10/29'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (3).jpg): ['뉴트로지나 인텐스 리페어 핸드크림 2번들', '56g', '8801108001201', '13,400원', '9,000원', '10/16~10/29']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (30).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (30).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 소프트 크림 (튜브), 75ML, 4005900497727, 4,200원, 4,200원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.020083250907751229
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 52
#   total_token_count: 3995
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (30).jpg):
# '니베아 소프트 크림 (튜브), 75ML, 4005900497727, 4,200원, 4,200원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (30).jpg): ['니베아 소프트 크림 (튜브)', '75ML', '4005900497727', '4,200원', '4,200원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (31).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (31).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 핸드크림 (SOS), 75ML, 7000004233261, 8,900원, 8,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.004858101992046132
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 51
#   total_token_count: 3994
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (31).jpg):
# '니베아 핸드크림 (SOS), 75ML, 7000004233261, 8,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (31).jpg): ['니베아 핸드크림 (SOS)', '75ML', '7000004233261', '8,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (32).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (32).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아트릭스 핸드 크림 (튜브), 75ML, 4005808820221, 2,800원, 2,800원, 10/16-10/29\n아트릭스 핸드 네일크림, 100ML, 4005808639014, 4,500원, 4,500원, 10/16-10/29"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00020571785971401182
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 123
#   total_token_count: 4066
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (32).jpg):
# '아트릭스 핸드 크림 (튜브), 75ML, 4005808820221, 2,800원, 2,800원, 10/16-10/29\n아트릭스 핸드 네일크림, 100ML, 4005808639014, 4,500원, 4,500원, 10/16-10/29'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (32).jpg): ['아트릭스 핸드 크림 (튜브)', '75ML', '4005808820221', '2,800원', '2,800원', '10/16-10/29']
#
# 📌 개별 라인 분석 (롯데 시즌2동 (32).jpg): ['아트릭스 핸드 네일크림', '100ML', '4005808639014', '4,500원', '4,500원', '10/16-10/29']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (33).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (33).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아트릭스 핸드크림, 250ML, 4005808858224, 8,500원, 8,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -9.6333347827050024e-06
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 51
#   total_token_count: 3994
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (33).jpg):
# '아트릭스 핸드크림, 250ML, 4005808858224, 8,500원, 8,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (33).jpg): ['아트릭스 핸드크림', '250ML', '4005808858224', '8,500원', '8,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (34).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (34).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 크림, 150ML, 4005808801046, 7,200원, 5,800원, 가격할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00076810207138670254
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 47
#   total_token_count: 3990
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (34).jpg):
# '니베아 크림, 150ML, 4005808801046, 7,200원, 5,800원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (34).jpg): ['니베아 크림', '150ML', '4005808801046', '7,200원', '5,800원', '가격할인']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (35).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (35).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 바디로션 (SOS), 400ML, 4005808891450, 19,800원, 17,820원, 가격할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.039286424528877692
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 53
#   total_token_count: 3996
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (35).jpg):
# '니베아 바디로션 (SOS), 400ML, 4005808891450, 19,800원, 17,820원, 가격할인'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (35).jpg): ['니베아 바디로션 (SOS)', '400ML', '4005808891450', '19,800원', '17,820원', '가격할인']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (36).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (36).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 바디로션 (인텐시브), 400ML, 4005808891412, 17,800원, 16,020원, 가격 할인\n"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00926589756681208
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (36).jpg):
# '니베아 바디로션 (인텐시브), 400ML, 4005808891412, 17,800원, 16,020원, 가격 할인'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (36).jpg): ['니베아 바디로션 (인텐시브)', '400ML', '4005808891412', '17,800원', '16,020원', '가격 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (37).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (37).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아트릭스 핸드네일크림, 400ML, 4005808820924, 12,500원, 12,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: 7.1851774753833357e-07
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (37).jpg):
# '아트릭스 핸드네일크림, 400ML, 4005808820924, 12,500원, 12,500원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (37).jpg): ['아트릭스 핸드네일크림', '400ML', '4005808820924', '12,500원', '12,500원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (38).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (38).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 바디로션 (익스프레스), 400ML, 4005808891436, 16,900원, 16,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -4.4290822448341971e-06
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (38).jpg):
# '니베아 바디로션 (익스프레스), 400ML, 4005808891436, 16,900원, 16,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (38).jpg): ['니베아 바디로션 (익스프레스)', '400ML', '4005808891436', '16,900원', '16,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (39).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (39).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아바디로션 (스무드), 400ML, 4005808891474, 16,900원, 16,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -2.2296867841346697e-06
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (39).jpg):
# '니베아바디로션 (스무드), 400ML, 4005808891474, 16,900원, 16,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (39).jpg): ['니베아바디로션 (스무드)', '400ML', '4005808891474', '16,900원', '16,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (4).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (4).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 풋크림, 112G, 8801108002710, 15,900원, 11,600원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00068522120515505469
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 51
#   total_token_count: 3994
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (4).jpg):
# '뉴트로지나 풋크림, 112G, 8801108002710, 15,900원, 11,600원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (4).jpg): ['뉴트로지나 풋크림', '112G', '8801108002710', '15,900원', '11,600원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (40).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (40).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 리치 바디로션 (Q10), 400ML, 4005800098833, 16,900원, 8,450원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0023729399378810611
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (40).jpg):
# '니베아 리치 바디로션 (Q10), 400ML, 4005800098833, 16,900원, 8,450원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (40).jpg): ['니베아 리치 바디로션 (Q10)', '400ML', '4005800098833', '16,900원', '8,450원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (41).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (41).jpg, 크기: (4032, 3024)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 바디로션 (Q10), 400ML, 4005808237470, 16,900원, 8,450원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0016153613450350585
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 54
#   total_token_count: 3997
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (41).jpg):
# '니베아 바디로션 (Q10), 400ML, 4005808237470, 16,900원, 8,450원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (41).jpg): ['니베아 바디로션 (Q10)', '400ML', '4005808237470', '16,900원', '8,450원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (5).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (5).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 시카 에멀젼, 310ML, 8801108002475, 22,000원, 13,200원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.000806862201828223
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 52
#   total_token_count: 3995
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (5).jpg):
# '뉴트로지나 시카 에멀젼, 310ML, 8801108002475, 22,000원, 13,200원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (5).jpg): ['뉴트로지나 시카 에멀젼', '310ML', '8801108002475', '22,000원', '13,200원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (6).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (6).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 바디로션 (데일리), 450ML, 8801108000983, 17,900원, 17,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.01166050580509922
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (6).jpg):
# '뉴트로지나 바디로션 (데일리), 450ML, 8801108000983, 17,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (6).jpg): ['뉴트로지나 바디로션 (데일리)', '450ML', '8801108000983', '17,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (7).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (7).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 바디로션 (릴렉싱), 450ML, 8801008004890, 17,900원, 17,900원, 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0005353414876894517
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (7).jpg):
# '뉴트로지나 바디로션 (릴렉싱), 450ML, 8801008004890, 17,900원, 17,900원, 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (7).jpg): ['뉴트로지나 바디로션 (릴렉싱)', '450ML', '8801008004890', '17,900원', '17,900원', '증정']
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (8).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (8).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 바디로션 (비져블리), 450ML, 108801008004883, 18,900원, 18,900원, 켄뷰 30,000원 이상구매시 롯데상품권 5천원권 증정"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.000507799731124015
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 84
#   total_token_count: 4027
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (8).jpg):
# '뉴트로지나 바디로션 (비져블리), 450ML, 108801008004883, 18,900원, 18,900원, 켄뷰 30,000원 이상구매시 롯데상품권 5천원권 증정'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (8).jpg): ['뉴트로지나 바디로션 (비져블리)', '450ML', '108801008004883', '18,900원', '18,900원', '켄뷰 30,000원 이상구매시 롯데상품권 5천원권 증정']
# 상품코드 보정: 108801008004883 -> 8801008004883
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~41)
#
# 🚀 처리 중: image/롯데 시즌2동 (1)\롯데 시즌2동 (9).jpg
# 이미지 열기 성공: image/롯데 시즌2동 (1)\롯데 시즌2동 (9).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 바디오일, 250ML, 8801008017623, 19,900원, 13,900원, 10/16~10/29"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.03011474609375
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 60
#   total_token_count: 4003
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (롯데 시즌2동 (9).jpg):
# '뉴트로지나 바디오일, 250ML, 8801008017623, 19,900원, 13,900원, 10/16~10/29'
#
# 📌 개별 라인 분석 (롯데 시즌2동 (9).jpg): ['뉴트로지나 바디오일', '250ML', '8801008017623', '19,900원', '13,900원', '10/16~10/29']
#
# ✅ 롯데 시즌2동 (1) 카테고리 정보가 롯데 시즌2동 (1).csv 파일에 저장되었습니다.
# 총 45개 상품 정보 처리 완료
#                 파일명                 제품명     용량           상품코드   정상가_표시  \
# 0   롯데 시즌2동 (1).jpg             뉴트로지나 립     4G  8801008004876   3,900원
# 1  롯데 시즌2동 (10).jpg  아비노 데일리 모이스춰라이징 로션  354ML  8801108003670  21,900원
# 2  롯데 시즌2동 (11).jpg     아비노 스트레스 릴리프 로션  354ML  8801108003748  21,900원
#
#     할인가_표시                             할인 내용
# 0   3,900원  켄뷰 30,000원 미상 구매시 롯데 상품권 5천원권 증정
# 1  14,200원                                증정
# 2  21,900원  켄뷰 30,000원 이상 구매시 롯데 상품권 5천원권 증정
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 45개 상품 정보 처리 완료
