# %%
# !pip install -q -U google-cloud-aiplatform python-dotenv

# %%
import pathlib
import textwrap

from vertexai import init
from vertexai.generative_models import GenerativeModel, Part, Image as VertexImage

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
    text = text.replace("•", "  *")
    return Markdown(textwrap.indent(text, "> ", predicate=lambda _: True))

# %%
import os
from dotenv import load_dotenv
from google.oauth2 import service_account
from google.auth.exceptions import DefaultCredentialsError


load_dotenv()

PROJECT_ID = os.getenv("VERTEX_PROJECT_ID") or os.getenv("GOOGLE_CLOUD_PROJECT")
LOCATION = os.getenv("VERTEX_LOCATION", "us-central1")
SA_PATH = os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

assert PROJECT_ID, "환경변수 VERTEX_PROJECT_ID 또는 GOOGLE_CLOUD_PROJECT가 필요합니다."

creds = None
if SA_PATH and os.path.exists(SA_PATH):
    creds = service_account.Credentials.from_service_account_file(
        SA_PATH,
        scopes=["https://www.googleapis.com/auth/cloud-platform"],
    )

try:
    if creds is not None:
        init(project=PROJECT_ID, location=LOCATION, credentials=creds)
    else:
        init(project=PROJECT_ID, location=LOCATION)
    print(
        f"Vertex init ok: project={PROJECT_ID}, location={LOCATION}, sa={'yes' if creds else 'no'}"
    )
except DefaultCredentialsError as e:
    raise AssertionError(
        "ADC(기본 자격증명)가 없습니다. 옵션: 1) gcloud auth application-default login 실행, 2) 서비스계정 키 경로를 GOOGLE_APPLICATION_CREDENTIALS에 설정"
    ) from e
# Out:
# Python-dotenv could not parse statement starting at line 4
# Vertex init ok: project=norse-baton-471707-t3, location=us-central1, sa=yes

# %%
# 인증/환경 자가진단 (SA 우선, 없으면 ADC)
import os as _os
import google.auth as _g_auth
from google.cloud import aiplatform as _aip
from google.oauth2 import service_account as _sa

_effective_creds = None
_sa_path = _os.getenv("GOOGLE_APPLICATION_CREDENTIALS")

if _sa_path and _os.path.exists(_sa_path):
    try:
        _effective_creds = _sa.Credentials.from_service_account_file(
            _sa_path, scopes=["https://www.googleapis.com/auth/cloud-platform"]
        )
        print("Service Account creds loaded:", _sa_path)
    except Exception as e:
        print("SA 로드 오류:", e)

if _effective_creds is None:
    try:
        _adc_creds, _adc_project = _g_auth.default(
            scopes=["https://www.googleapis.com/auth/cloud-platform"]
        )
        _effective_creds = _adc_creds
        print("ADC project:", _adc_project)
    except Exception as e:
        print("ADC 미설정:", e)

print("ENV PROJECT:", PROJECT_ID)
print("LOCATION:", LOCATION)
print("MODEL_NAME:", os.getenv("VERTEX_MODEL_NAME", "gemini-2.0-flash"))

try:
    _aip.init(project=PROJECT_ID, location=LOCATION, credentials=_effective_creds)
    print(
        "AI Platform init ok (",
        ("SA" if _sa_path and _effective_creds else "ADC/None"),
        ")",
    )
except Exception as e:
    print("AI Platform init error:", e)
# Out:
# Service Account creds loaded: C:\\keo\\portfolio-ai\\03_cv-multimodal\\OCR\\OCR\\norse-baton-471707-t3-027d359779dd.json
# ENV PROJECT: norse-baton-471707-t3
# LOCATION: us-central1
# MODEL_NAME: gemini-2.0-flash
# AI Platform init ok ( SA )

# %%
import os

MODEL_NAME = os.getenv("VERTEX_MODEL_NAME", "gemini-2.0-flash")
print(f"Using Vertex AI model: {MODEL_NAME}")
# Out:
# Using Vertex AI model: gemini-2.0-flash

# %%
model = GenerativeModel(MODEL_NAME)

# %%
import base64
import os
from PIL import Image
import io


IMAGE_FOLDER = "image/"

# %%
import re


def sanitize_product_code(raw_code: str) -> str:
    """상품코드를 13자리 숫자로 강제한다.
    - 숫자만 추출
    - 13자리보다 길면 마지막 13자리 사용
    - 13자리보다 짧으면 '식별불가'
    """
    digits = re.sub(r"\D", "", raw_code or "")
    if len(digits) >= 13:
        return digits[-13:]
    return "식별불가"

# %%
from PIL import Image
import time
import os
from google.api_core.exceptions import (
    ResourceExhausted,
    ServiceUnavailable,
    InternalServerError,
    DeadlineExceeded,
)


def ask_for_product_info(image_path):
    try:
        img = Image.open(image_path)
        print(f"이미지 열기 성공: {image_path}, 크기: {img.size}")

        # Vertex AI 이미지 입력: 파일에서 직접 로드
        image_part = VertexImage.load_from_file(image_path)

        prompt = (
            "Instructions:"
            "1. Detect the price tags in the image and extract the text from those price tags."
            "2. For each price tag (label), identify the following five items and output them in one line separated by commas (,):"
            "   - Product name"
            "   - Capacity"
            "   - Product code (13 digits)"
            "   - Regular price (in KRW)"
            "   - Discount price (in KRW)"
            "   - Discount content"
            "3. If the discount price is not provided, use the same value as the regular price."
            "4. If any item is incorrect or unclear, please write '식별불가' for that item."
            "5. Always add '원' after the price."
            "6. [용량] 의 내용이 '10g당6,667원/4.5G' 이면 '4.5G' 라고 출력. 4,5G로 인식될 경우 4.5G로 출력."
            "7. If, for any reason, none of the items can be found, write '식별불가' for all items."
            "8. Do not arbitrarily add or omit any information from the original text; present it exactly as identified."
            "9. Only use the information from the price tag."
            "10. If a discount is included, please only list the final discounted price."
            "11. [용량]당 가격은 할인가가 아니므로, 할인가에 삽입하지 않는다."
            "12. If the number presumed to be the product code is 13 digits or longer, only the last 13 digits are extracted. (Example: If it is 124834028 / 4005808725212(A)(B), the product code is 4005808725212)"
            "13. Product code MUST BE EXACTLY 13 digits. Extract digits only: if longer, use LAST 13 digits; if shorter than 13 after digit-only filtering, output '식별불가'."
            "출력 형식 예시(필수 준수)"
            "각 상품당 한 줄로: [제품명], [용량], [상품코드(13자리)], [정상가], [할인가], [할인 내용]"
            "예시: 클립램프 영양립밤, 식별불가, 8809704424769, 1,090원, 980원, 2개 이상 개당"
            "예시: AK 바세린 알로에 수딩 로션, 450ML, 8801046432905, 1,090원, 1,090원, 1+1"
        )

        # 단순 지수 백오프
        backoff_seconds = 5
        for attempt in range(4):
            try:
                response = model.generate_content([prompt, image_part])
                print(f"모델 응답: {response}")
                return response.text
            except (
                ResourceExhausted,
                ServiceUnavailable,
                InternalServerError,
                DeadlineExceeded,
            ) as e:
                if attempt == 3:
                    raise
                sleep_for = backoff_seconds * (2**attempt)
                print(
                    f"일시적 오류: {e.__class__.__name__}: {e}. {sleep_for}초 후 재시도 ({attempt+1}/4)"
                )
                time.sleep(sleep_for)

    except Exception as e:
        print(f"오류 발생: {e.__class__.__name__}: {e}")
        return None

# %%
import os
import re
import pandas as pd
import time
from collections import defaultdict


def process_images_from_folder(folder_path, batch_size=10, delay_seconds=30):
    """
    폴더 내 모든 이미지 파일을 처리하고 디렉토리 또는 파일명 패턴에 따라 CSV로 저장

    Args:
        folder_path (str): 이미지 파일이 있는 폴더 경로
        batch_size (int): 딜레이 전 처리할 이미지 개수
        delay_seconds (int): 배치 처리 후 대기할 시간(초)
    """
    # 카테고리별 데이터를 저장할 딕셔너리
    category_data = defaultdict(list)

    # 이미지 파일 목록 가져오기 (하위 디렉토리 포함)
    image_files = []

    # 재귀적으로 폴더 탐색
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg")):
                image_files.append(os.path.join(root, file))

    print(f"총 처리할 이미지 파일 수: {len(image_files)}")

    # 배치 단위로 처리
    for batch_idx, i in enumerate(range(0, len(image_files), batch_size)):
        batch_files = image_files[i : i + batch_size]

        # 첫 번째 배치가 아니고, 배치 크기가 설정된 경우 딜레이 적용
        if batch_idx > 0 and batch_size > 0:
            print(f"\n⏳ API 사용량 조절을 위해 {delay_seconds}초 대기 중...")
            time.sleep(delay_seconds)

        print(
            f"\n🔄 배치 {batch_idx+1} 처리 시작 (파일 {i+1}~{min(i+batch_size, len(image_files))})"
        )

        for image_path in batch_files:
            print(f"\n🚀 처리 중: {image_path}")

            # 파일명과 카테고리 추출
            filename = os.path.basename(image_path)

            # 카테고리 추출 방법 1: 디렉토리 구조 활용 (image/바디/image01.jpg → 바디)
            if folder_path in image_path:
                rel_path = os.path.relpath(image_path, folder_path)
                parts = rel_path.split(os.sep)
                if len(parts) > 1:  # 하위 디렉토리가 있는 경우
                    category = parts[0]  # 첫 번째 하위 디렉토리 이름을 카테고리로 사용
                else:
                    # 하위 디렉토리가 없는 경우, 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                    match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                    category = match.group(1) if match else "기타"
            else:
                # 파일명에서 카테고리 추출 (예: '홈 바디 (1).jpg' → '바디')
                match = re.search(r"[가-힣]+ ([가-힣]+)", filename)
                category = match.group(1) if match else "기타"

            result = ask_for_product_info(image_path)

            # 모델의 응답에서 추출된 텍스트 가져오기
            if result is not None:
                extracted_text = result.strip()
            else:
                extracted_text = "식별불가"

            print(f"\n📌 반환 텍스트 ({filename}):")
            print(repr(extracted_text))

            # 🔹 "\n\n" -> "\n" 로 변환하여 줄바꿈 정리
            extracted_text = extracted_text.replace("\n\n", "\n")

            # 🔹 가격 쉼표(`,`)를 임시로 다른 문자(#)로 변환하여 데이터 분리 문제 방지
            # 개선된 정규식 패턴: 숫자,숫자원 형태를 찾아 #로 대체
            temp_text = re.sub(r"(\d[\d,]*),(\d+원)", r"\1#\2", extracted_text)

            # 🔹 리스트 변환 시 공백 제거 후 줄바꿈 기준으로 분리
            lines = [line.strip() for line in temp_text.split("\n") if line.strip()]

            for line in lines:
                # 여기서 쉼표(,)로 항목을 분리할 때 가격에 있는 쉼표를 보호하기 위해
                # 임시로 #로 바꾼 부분을 처리
                items = [
                    item.strip().replace("#", ",") for item in line.split(",")
                ]  # 쉼표 임시 문자 복원
                print(f"\n📌 개별 라인 분석 ({filename}): {repr(items)}")

                if len(items) == 6:
                    # 보정: 상품코드 13자리 강제
                    raw_code = items[2]
                    fixed_code = sanitize_product_code(raw_code)
                    if fixed_code != raw_code:
                        print(f"상품코드 보정: {raw_code} -> {fixed_code}")

                    # CSV 저장 시 가격 필드의 쉼표를 제거하여 열 구분 문제 방지
                    정상가 = items[3].replace(",", "")  # 쉼표 제거
                    할인가 = items[4].replace(",", "")  # 쉼표 제거

                    # 카테고리별로 데이터 저장
                    category_data[category].append(
                        {
                            "파일명": filename,
                            "제품명": items[0],
                            "용량": items[1],
                            "상품코드": fixed_code,
                            "정상가_표시": items[3],  # 원본 값 보존(표시용)
                            "할인가_표시": items[4],  # 원본 값 보존(표시용)
                            "할인 내용": items[5],
                        }
                    )

    # 카테고리별로 CSV 파일 저장
    for category, data in category_data.items():
        if data:  # 데이터가 있는 경우에만 저장
            df = pd.DataFrame(data)
            output_csv = f"{category}.csv"
            df.to_csv(output_csv, index=False, encoding="utf-8-sig")
            print(
                f"\n✅ {category} 카테고리 정보가 {output_csv} 파일에 저장되었습니다."
            )
            print(f"총 {len(df)}개 상품 정보 처리 완료")
            print(df.head(3))  # 처음 3개 행만 표시

    # 전체 데이터도 하나의 파일로 저장
    all_data = []
    for data_list in category_data.values():
        all_data.extend(data_list)

    if all_data:
        df_all = pd.DataFrame(all_data)
        df_all.to_csv("전체_가격표.csv", index=False, encoding="utf-8-sig")
        print(f"\n✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.")
        print(f"총 {len(df_all)}개 상품 정보 처리 완료")

# %%
# 실행
process_images_from_folder(IMAGE_FOLDER)
# Out:
# 총 처리할 이미지 파일 수: 54
#
# 🔄 배치 1 처리 시작 (파일 1~10)
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (1).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (1).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 모이스춰 립케어, 4.8g, 4005808517572, 5,500원, 4,400원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -4.5556836483771344e-05
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (1).jpg):
# '니베아 모이스춰 립케어, 4.8g, 4005808517572, 5,500원, 4,400원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (1).jpg): ['니베아 모이스춰 립케어', '4.8g', '4005808517572', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (10).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (10).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 SOS 바디 로션, 400ml, 4005808891450, 17,820원, 17,820원, 추천 상품\n니베아 인텐시브 바디 로션, 400ml, 4005808891412, 16,020원, 16,020원, 추천 상품"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0071623972002065406
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 106
#   total_token_count: 4049
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (10).jpg):
# '니베아 SOS 바디 로션, 400ml, 4005808891450, 17,820원, 17,820원, 추천 상품\n니베아 인텐시브 바디 로션, 400ml, 4005808891412, 16,020원, 16,020원, 추천 상품'
#
# 📌 개별 라인 분석 (이마트 BDF (10).jpg): ['니베아 SOS 바디 로션', '400ml', '4005808891450', '17,820원', '17,820원', '추천 상품']
#
# 📌 개별 라인 분석 (이마트 BDF (10).jpg): ['니베아 인텐시브 바디 로션', '400ml', '4005808891412', '16,020원', '16,020원', '추천 상품']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (11).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (11).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 소프트 크림, 200ml, 4005808519149, 7,600원, 6,080원, 20%"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -4.8470299225300548e-06
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 50
#   total_token_count: 3993
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (11).jpg):
# '니베아 소프트 크림, 200ml, 4005808519149, 7,600원, 6,080원, 20%'
#
# 📌 개별 라인 분석 (이마트 BDF (11).jpg): ['니베아 소프트 크림', '200ml', '4005808519149', '7,600원', '6,080원', '20%']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (2).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (2).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 스트로베리 립케여, 4.8g, 4005808372881, 5,500원, 4,400원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00068947275058697842
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 59
#   total_token_count: 4002
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (2).jpg):
# '니베아 스트로베리 립케여, 4.8g, 4005808372881, 5,500원, 4,400원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (2).jpg): ['니베아 스트로베리 립케여', '4.8g', '4005808372881', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (3).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (3).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 에센셜 립케어, 4.8g, 4005808369485, 5,500원, 4,400원, S포인트 적립시 할인\n니베아 포맨 액티브 립케어, 4.8g, 4005808373000, 5,500원, 4,400원, S포인트 적립시 할인\n식별불가, 식별불가, 식별불가, 4,830원, 4,830원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.01254551209412612
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 154
#   total_token_count: 4097
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (3).jpg):
# '니베아 에센셜 립케어, 4.8g, 4005808369485, 5,500원, 4,400원, S포인트 적립시 할인\n니베아 포맨 액티브 립케어, 4.8g, 4005808373000, 5,500원, 4,400원, S포인트 적립시 할인\n식별불가, 식별불가, 식별불가, 4,830원, 4,830원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (3).jpg): ['니베아 에센셜 립케어', '4.8g', '4005808369485', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 BDF (3).jpg): ['니베아 포맨 액티브 립케어', '4.8g', '4005808373000', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 BDF (3).jpg): ['식별불가', '식별불가', '식별불가', '4,830원', '4,830원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (4).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (4).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어 후르티샤인 피치4.Bg, 4.8g, 4005808904358, 5,500원, 4,400원, S포인트 적립시 할인\n니삐아 립케어 히알루론 모이스쳐 플러스, 식별불가, 8806322114263, 6,500원, 5,200원, S포인트 적립시 할인\n니베아 립케어 모이스춰 케어, 식별불가, 식별불가, 7,500원, 7,500원, 식별불가\n니베아 립케어 모이스춰 케어, 식별불가, 식별불가, 4,400원, 4,400원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.015729323581412987
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 216
#   total_token_count: 4159
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (4).jpg):
# '니베아 립케어 후르티샤인 피치4.Bg, 4.8g, 4005808904358, 5,500원, 4,400원, S포인트 적립시 할인\n니삐아 립케어 히알루론 모이스쳐 플러스, 식별불가, 8806322114263, 6,500원, 5,200원, S포인트 적립시 할인\n니베아 립케어 모이스춰 케어, 식별불가, 식별불가, 7,500원, 7,500원, 식별불가\n니베아 립케어 모이스춰 케어, 식별불가, 식별불가, 4,400원, 4,400원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (4).jpg): ['니베아 립케어 후르티샤인 피치4.Bg', '4.8g', '4005808904358', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 BDF (4).jpg): ['니삐아 립케어 히알루론 모이스쳐 플러스', '식별불가', '8806322114263', '6,500원', '5,200원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 BDF (4).jpg): ['니베아 립케어 모이스춰 케어', '식별불가', '식별불가', '7,500원', '7,500원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 BDF (4).jpg): ['니베아 립케어 모이스춰 케어', '식별불가', '식별불가', '4,400원', '4,400원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (5).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (5).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 립케어 딥 모이스처 올리브&레몬, 4.5G, 8806322114751, 9,900원, 6,930원, S포인트 적립시 할인\n니베아 립케어 우후르티샤인 체리, 4.Bg, 4005808517589, 5,500원, 4,400원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0076014296276362865
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 127
#   total_token_count: 4070
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (5).jpg):
# '니베아 립케어 딥 모이스처 올리브&레몬, 4.5G, 8806322114751, 9,900원, 6,930원, S포인트 적립시 할인\n니베아 립케어 우후르티샤인 체리, 4.Bg, 4005808517589, 5,500원, 4,400원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 BDF (5).jpg): ['니베아 립케어 딥 모이스처 올리브&레몬', '4.5G', '8806322114751', '9,900원', '6,930원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 BDF (5).jpg): ['니베아 립케어 우후르티샤인 체리', '4.Bg', '4005808517589', '5,500원', '4,400원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (6).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (6).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 더마 SOS 케어 4.8g, 4.8g, 4005808850631, 6,500원, 5,200원, 식별불가\n니베아 립케어 딥 모이스처 연센티드, 식별불가, 8806322114744, 9,900원, 6,930원, 식별불가\n식별불가, 식별불가, 식별불가, 4,400원, 4,400원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0033209903928257474
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 149
#   total_token_count: 4092
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (6).jpg):
# '니베아 더마 SOS 케어 4.8g, 4.8g, 4005808850631, 6,500원, 5,200원, 식별불가\n니베아 립케어 딥 모이스처 연센티드, 식별불가, 8806322114744, 9,900원, 6,930원, 식별불가\n식별불가, 식별불가, 식별불가, 4,400원, 4,400원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (6).jpg): ['니베아 더마 SOS 케어 4.8g', '4.8g', '4005808850631', '6,500원', '5,200원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 BDF (6).jpg): ['니베아 립케어 딥 모이스처 연센티드', '식별불가', '8806322114744', '9,900원', '6,930원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 BDF (6).jpg): ['식별불가', '식별불가', '식별불가', '4,400원', '4,400원', '식별불가']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (7).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (7).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아크림, 150ml, 4005808801046, 6,500원, 5,760원, 할상인품"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.014776299608514664
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 47
#   total_token_count: 3990
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (7).jpg):
# '니베아크림, 150ml, 4005808801046, 6,500원, 5,760원, 할상인품'
#
# 📌 개별 라인 분석 (이마트 BDF (7).jpg): ['니베아크림', '150ml', '4005808801046', '6,500원', '5,760원', '할상인품']
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (8).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (8).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 익스프레스 바디 로션, 400ml, 4005808891436, 16,900원, 16,900원, 1+1\n로션, 400ml, 4005800098833, 6,900원, 6,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00041056369053255211
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 101
#   total_token_count: 4044
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (8).jpg):
# '니베아 익스프레스 바디 로션, 400ml, 4005808891436, 16,900원, 16,900원, 1+1\n로션, 400ml, 4005800098833, 6,900원, 6,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 BDF (8).jpg): ['니베아 익스프레스 바디 로션', '400ml', '4005808891436', '16,900원', '16,900원', '1+1']
#
# 📌 개별 라인 분석 (이마트 BDF (8).jpg): ['로션', '400ml', '4005800098833', '6,900원', '6,900원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 2 처리 시작 (파일 11~20)
#
# 🚀 처리 중: image/이마트 BDF (9)\이마트 BDF (9).jpg
# 이미지 열기 성공: image/이마트 BDF (9)\이마트 BDF (9).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "니베아 스무드 바디 로션, 400ml, 4005808891474, 16,900원, 16,900원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0021686879573044955
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 54
#   total_token_count: 3997
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 BDF (9).jpg):
# '니베아 스무드 바디 로션, 400ml, 4005808891474, 16,900원, 16,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 BDF (9).jpg): ['니베아 스무드 바디 로션', '400ml', '4005808891474', '16,900원', '16,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (1).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (1).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "해피바스 퍼퓸부티크 바디로션 상탈머스크, 100ml당 2829원, 8809925195363, 12,900원, 9,900원, 할인상품"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0063586598810027629
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 68
#   total_token_count: 4011
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (1).jpg):
# '해피바스 퍼퓸부티크 바디로션 상탈머스크, 100ml당 2829원, 8809925195363, 12,900원, 9,900원, 할인상품'
#
# 📌 개별 라인 분석 (이마트 바디 (1).jpg): ['해피바스 퍼퓸부티크 바디로션 상탈머스크', '100ml당 2829원', '8809925195363', '12,900원', '9,900원', '할인상품']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (10).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (10).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아비노 스릴리프 로션, 354ml, 9801108003717, 21,900원, 21,900원, 2개 50%(※교자/일부제외)\n아비노 스트레스릴리프 로션, 354ml, 식별불가, 21,900원, 21,900원, 2개50%※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.019638129922210194
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 122
#   total_token_count: 4065
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (10).jpg):
# '아비노 스릴리프 로션, 354ml, 9801108003717, 21,900원, 21,900원, 2개 50%(※교자/일부제외)\n아비노 스트레스릴리프 로션, 354ml, 식별불가, 21,900원, 21,900원, 2개50%※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (10).jpg): ['아비노 스릴리프 로션', '354ml', '9801108003717', '21,900원', '21,900원', '2개 50%(※교자/일부제외)']
#
# 📌 개별 라인 분석 (이마트 바디 (10).jpg): ['아비노 스트레스릴리프 로션', '354ml', '식별불가', '21,900원', '21,900원', '2개50%※교차/일부제외)']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (11).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (11).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "Here are the price tag detections:\n```json\n[\n  {\"box_2d\": [417, 677, 718, 784], \"text\": \"뉴트로지나 아비노x밀크바오밥\\n2개 50%(※교차/일부제외)801108003670\\n■ 아비노 데일리 로션 354ml\\n담을수록 100㎡당 6186원\\n이득\\n25.00.18 25.09.21\\n25/0정 1\\n21,900\"},\n  {\"box_2d\": [104, 690, 191, 754], \"text\": \"2개 50%(※교차/일부제외)\\n담을수록 100㎡\\n이득\\n25.09.18-25.09.21\\n4/12정 1\"}\n]\n```\nHere are the formatted results:\n아비노 데일리 로션, 354ml, 8801108003670, 21,900원, 21,900원, 2개 50%(※교차/일부제외)\n식별불가, 100㎡, 식별불가, 식별불가, 식별불가, 2개 50%(※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.10846439783142584
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 371
#   total_token_count: 4314
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (11).jpg):
# 'Here are the price tag detections:\n```json\n[\n  {"box_2d": [417, 677, 718, 784], "text": "뉴트로지나 아비노x밀크바오밥\\n2개 50%(※교차/일부제외)801108003670\\n■ 아비노 데일리 로션 354ml\\n담을수록 100㎡당 6186원\\n이득\\n25.00.18 25.09.21\\n25/0정 1\\n21,900"},\n  {"box_2d": [104, 690, 191, 754], "text": "2개 50%(※교차/일부제외)\\n담을수록 100㎡\\n이득\\n25.09.18-25.09.21\\n4/12정 1"}\n]\n```\nHere are the formatted results:\n아비노 데일리 로션, 354ml, 8801108003670, 21,900원, 21,900원, 2개 50%(※교차/일부제외)\n식별불가, 100㎡, 식별불가, 식별불가, 식별불가, 2개 50%(※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['Here are the price tag detections:']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['```json']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['[']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['{"box_2d": [417', '677', '718', '784]', '"text": "뉴트로지나 아비노x밀크바오밥\\n2개 50%(※교차/일부제외)801108003670\\n■ 아비노 데일리 로션 354ml\\n담을수록 100㎡당 6186원\\n이득\\n25.00.18 25.09.21\\n25/0정 1\\n21', '900"}', '']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['{"box_2d": [104', '690', '191', '754]', '"text": "2개 50%(※교차/일부제외)\\n담을수록 100㎡\\n이득\\n25.09.18-25.09.21\\n4/12정 1"}']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): [']']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['```']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['Here are the formatted results:']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['아비노 데일리 로션', '354ml', '8801108003670', '21,900원', '21,900원', '2개 50%(※교차/일부제외)']
#
# 📌 개별 라인 분석 (이마트 바디 (11).jpg): ['식별불가', '100㎡', '식별불가', '식별불가', '식별불가', '2개 50%(※교차/일부제외)']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (12).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (12).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "나드 퍼퓸드 모이스처 바디로션 시그니처플, 식별불가, 8809981365359, 12,900원, 12,900원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00053408442706358241
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 61
#   total_token_count: 4004
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (12).jpg):
# '나드 퍼퓸드 모이스처 바디로션 시그니처플, 식별불가, 8809981365359, 12,900원, 12,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디 (12).jpg): ['나드 퍼퓸드 모이스처 바디로션 시그니처플', '식별불가', '8809981365359', '12,900원', '12,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (13).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (13).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "나드 퍼퓸드 모이스처 바디로션 클린코튼 1, 식별불가, 8809981365366, 12,900원, 12,900원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.000475601323189274
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 62
#   total_token_count: 4005
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (13).jpg):
# '나드 퍼퓸드 모이스처 바디로션 클린코튼 1, 식별불가, 8809981365366, 12,900원, 12,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디 (13).jpg): ['나드 퍼퓸드 모이스처 바디로션 클린코튼 1', '식별불가', '8809981365366', '12,900원', '12,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (14).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (14).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "Here are the outputs based on the image data:\n\n1.  히말라야 코코아/너리싱/수딩 로션, 400ml, 8801188820117, 17,900원, 17,900원, 1+1\n2.  금글 시드니&로즈 바디, 500m, 식별불가, 9,900원, 9,900원, 식별불가\n3. SUPER BOTANE ROSE PEONY, 식별불가, 식별불가, 8,900원, 8,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.12140283584594727
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 160
#   total_token_count: 4103
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (14).jpg):
# 'Here are the outputs based on the image data:\n\n1.  히말라야 코코아/너리싱/수딩 로션, 400ml, 8801188820117, 17,900원, 17,900원, 1+1\n2.  금글 시드니&로즈 바디, 500m, 식별불가, 9,900원, 9,900원, 식별불가\n3. SUPER BOTANE ROSE PEONY, 식별불가, 식별불가, 8,900원, 8,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (14).jpg): ['Here are the outputs based on the image data:']
#
# 📌 개별 라인 분석 (이마트 바디 (14).jpg): ['1.  히말라야 코코아/너리싱/수딩 로션', '400ml', '8801188820117', '17,900원', '17,900원', '1+1']
#
# 📌 개별 라인 분석 (이마트 바디 (14).jpg): ['2.  금글 시드니&로즈 바디', '500m', '식별불가', '9,900원', '9,900원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 바디 (14).jpg): ['3. SUPER BOTANE ROSE PEONY', '식별불가', '식별불가', '8,900원', '8,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (15).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (15).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "히말라야 코코아/너리싱/수딩 로션, 400ml, 8901138508159, 17,900원, 17,900원, 1+1\n히말라야 코코아/너리싱/수딩 로션, 400ml, 8901138508166, 17,900원, 17,900원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0015995869459199512
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 121
#   total_token_count: 4064
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (15).jpg):
# '히말라야 코코아/너리싱/수딩 로션, 400ml, 8901138508159, 17,900원, 17,900원, 1+1\n히말라야 코코아/너리싱/수딩 로션, 400ml, 8901138508166, 17,900원, 17,900원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디 (15).jpg): ['히말라야 코코아/너리싱/수딩 로션', '400ml', '8901138508159', '17,900원', '17,900원', '1+1']
#
# 📌 개별 라인 분석 (이마트 바디 (15).jpg): ['히말라야 코코아/너리싱/수딩 로션', '400ml', '8901138508166', '17,900원', '17,900원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (16).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (16).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 아비노밀크바오밥, 450ml, 8801008124925, 17,900원, 17,900원, 2개 50%(※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.00093273710513460469
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 69
#   total_token_count: 4012
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (16).jpg):
# '뉴트로지나 아비노밀크바오밥, 450ml, 8801008124925, 17,900원, 17,900원, 2개 50%(※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (16).jpg): ['뉴트로지나 아비노밀크바오밥', '450ml', '8801008124925', '17,900원', '17,900원', '2개 50%(※교차/일부제외)']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (17).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (17).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "클립램프 영양립밤, 식별불가, 8801008004883, 18,900원, 18,900원, 2개 50%(※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.059946567293197389
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 63
#   total_token_count: 4006
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (17).jpg):
# '클립램프 영양립밤, 식별불가, 8801008004883, 18,900원, 18,900원, 2개 50%(※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (17).jpg): ['클립램프 영양립밤', '식별불가', '8801008004883', '18,900원', '18,900원', '2개 50%(※교차/일부제외)']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 3 처리 시작 (파일 21~30)
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (18).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (18).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나x아비노x밀크바오밥, 식별불가, 8801008017623, 19,900원, 19,900원, 2개 50%(※교자/일부제외)\n뉴트로지나 시카 메밀전, 310ml, 8801108002475, 22,000원, 22,000원, 2개 50%(※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0014865246132342485
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 137
#   total_token_count: 4080
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (18).jpg):
# '뉴트로지나x아비노x밀크바오밥, 식별불가, 8801008017623, 19,900원, 19,900원, 2개 50%(※교자/일부제외)\n뉴트로지나 시카 메밀전, 310ml, 8801108002475, 22,000원, 22,000원, 2개 50%(※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (18).jpg): ['뉴트로지나x아비노x밀크바오밥', '식별불가', '8801008017623', '19,900원', '19,900원', '2개 50%(※교자/일부제외)']
#
# 📌 개별 라인 분석 (이마트 바디 (18).jpg): ['뉴트로지나 시카 메밀전', '310ml', '8801108002475', '22,000원', '22,000원', '2개 50%(※교차/일부제외)']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (19).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (19).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "뉴트로지나 릴렉싱 바디 로션, 450ml, 8801008004890, 17,900원, 17,900원, 2개 50%(※교차/일부제외)\n뉴트로지나 데일리 바디 로션, 450ml, 8801108000983, 17,900원, 17,900원, 2개 50%(※교차/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.001711947546488997
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 138
#   total_token_count: 4081
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (19).jpg):
# '뉴트로지나 릴렉싱 바디 로션, 450ml, 8801008004890, 17,900원, 17,900원, 2개 50%(※교차/일부제외)\n뉴트로지나 데일리 바디 로션, 450ml, 8801108000983, 17,900원, 17,900원, 2개 50%(※교차/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (19).jpg): ['뉴트로지나 릴렉싱 바디 로션', '450ml', '8801008004890', '17,900원', '17,900원', '2개 50%(※교차/일부제외)']
#
# 📌 개별 라인 분석 (이마트 바디 (19).jpg): ['뉴트로지나 데일리 바디 로션', '450ml', '8801108000983', '17,900원', '17,900원', '2개 50%(※교차/일부제외)']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (2).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (2).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "해피바스 퍼퓸부티크 바디로션 로즈 블러쉬, 식별불가, 8809925195356, 12,900원, 9,900원, 인품"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.016533639471409685
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 59
#   total_token_count: 4002
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (2).jpg):
# '해피바스 퍼퓸부티크 바디로션 로즈 블러쉬, 식별불가, 8809925195356, 12,900원, 9,900원, 인품'
#
# 📌 개별 라인 분석 (이마트 바디 (2).jpg): ['해피바스 퍼퓸부티크 바디로션 로즈 블러쉬', '식별불가', '8809925195356', '12,900원', '9,900원', '인품']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (20).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (20).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "더마비 데일리 모이스처 바디 워시, 1000ml, 8809723783274, 13,300원, 13,300원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.017805897583395749
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 59
#   total_token_count: 4002
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (20).jpg):
# '더마비 데일리 모이스처 바디 워시, 1000ml, 8809723783274, 13,300원, 13,300원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (20).jpg): ['더마비 데일리 모이스처 바디 워시', '1000ml', '8809723783274', '13,300원', '13,300원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (21).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (21).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "더마비AC컨트롤바디로션, 400ML, 8809911690575, 11,100원, 11,100원, 추석상품\n더마비 세라엠디 리페어 로션, 450ml, 8809723789405, 15,400원, 15,400원, 추석상품"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.018198668956756592
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 112
#   total_token_count: 4055
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (21).jpg):
# '더마비AC컨트롤바디로션, 400ML, 8809911690575, 11,100원, 11,100원, 추석상품\n더마비 세라엠디 리페어 로션, 450ml, 8809723789405, 15,400원, 15,400원, 추석상품'
#
# 📌 개별 라인 분석 (이마트 바디 (21).jpg): ['더마비AC컨트롤바디로션', '400ML', '8809911690575', '11,100원', '11,100원', '추석상품']
#
# 📌 개별 라인 분석 (이마트 바디 (21).jpg): ['더마비 세라엠디 리페어 로션', '450ml', '8809723789405', '15,400원', '15,400원', '추석상품']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (22).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (22).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "더마비 울트라 모이스처 바디크림, 430ml, 8809048410664, 식별불가, 14,950원, 식별불가\n뉴더마비 1데일리모이스처바디로션, 500ml, 8809554840337, 식별불가, 13,650원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0012854725659430565
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 111
#   total_token_count: 4054
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (22).jpg):
# '더마비 울트라 모이스처 바디크림, 430ml, 8809048410664, 식별불가, 14,950원, 식별불가\n뉴더마비 1데일리모이스처바디로션, 500ml, 8809554840337, 식별불가, 13,650원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (22).jpg): ['더마비 울트라 모이스처 바디크림', '430ml', '8809048410664', '식별불가', '14,950원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 바디 (22).jpg): ['뉴더마비 1데일리모이스처바디로션', '500ml', '8809554840337', '식별불가', '13,650원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (23).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (23).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "W.D 퍼퓸 핸드크림 97 에이프릴코튼, 식별불가, 8805301011876, 7,900원, 5,900원, 할인\nW.D 퍼퓸 핸드크림 30 화이트머스크, 식별불가, 8805301011845, 7,900원, 5,900원, 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.010378884454058785
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 117
#   total_token_count: 4060
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (23).jpg):
# 'W.D 퍼퓸 핸드크림 97 에이프릴코튼, 식별불가, 8805301011876, 7,900원, 5,900원, 할인\nW.D 퍼퓸 핸드크림 30 화이트머스크, 식별불가, 8805301011845, 7,900원, 5,900원, 할인'
#
# 📌 개별 라인 분석 (이마트 바디 (23).jpg): ['W.D 퍼퓸 핸드크림 97 에이프릴코튼', '식별불가', '8805301011876', '7,900원', '5,900원', '할인']
#
# 📌 개별 라인 분석 (이마트 바디 (23).jpg): ['W.D 퍼퓸 핸드크림 30 화이트머스크', '식별불가', '8805301011845', '7,900원', '5,900원', '할인']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (3).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (3).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "일리윤 히알루론수분크림, 105ml, 8800283640670, 17,900원, 17,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.024074985764243387
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (3).jpg):
# '일리윤 히알루론수분크림, 105ml, 8800283640670, 17,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (3).jpg): ['일리윤 히알루론수분크림', '105ml', '8800283640670', '17,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (4).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (4).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "일리윤MD 레드이치 케이크림, 150ml*2, 8800283644876, 17,900원, 17,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0052316230640076754
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (4).jpg):
# '일리윤MD 레드이치 케이크림, 150ml*2, 8800283644876, 17,900원, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (4).jpg): ['일리윤MD 레드이치 케이크림', '150ml*2', '8800283644876', '17,900원', '17,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (5).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (5).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "일리윤 세라마이드 아토 로션 275ML*2, 식별불가, 8800283638462, 16,500원, 16,500원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0035482982794443766
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 60
#   total_token_count: 4003
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (5).jpg):
# '일리윤 세라마이드 아토 로션 275ML*2, 식별불가, 8800283638462, 16,500원, 16,500원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (5).jpg): ['일리윤 세라마이드 아토 로션 275ML*2', '식별불가', '8800283638462', '16,500원', '16,500원', '식별불가']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 4 처리 시작 (파일 31~40)
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (6).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (6).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "일리윤 울트라 리페어 로션 기획, 275ml×2, 8800283636734, 식별불가, 17,900원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0099416109068053114
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (6).jpg):
# '일리윤 울트라 리페어 로션 기획, 275ml×2, 8800283636734, 식별불가, 17,900원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 바디 (6).jpg): ['일리윤 울트라 리페어 로션 기획', '275ml×2', '8800283636734', '식별불가', '17,900원', '식별불가']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (7).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (7).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "해피바스 정말 촉촉한 바디로션, 식별불가, 8809803577229, 10,800원, 10,800원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.014080692801559181
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 57
#   total_token_count: 4000
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (7).jpg):
# '해피바스 정말 촉촉한 바디로션, 식별불가, 8809803577229, 10,800원, 10,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디 (7).jpg): ['해피바스 정말 촉촉한 바디로션', '식별불가', '8809803577229', '10,800원', '10,800원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (8).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (8).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "해피바스 정말순한바디로션, 400g, 8809803577236, 10,800원, 10,800원, 1+1"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0015596909714596613
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (8).jpg):
# '해피바스 정말순한바디로션, 400g, 8809803577236, 10,800원, 10,800원, 1+1'
#
# 📌 개별 라인 분석 (이마트 바디 (8).jpg): ['해피바스 정말순한바디로션', '400g', '8809803577236', '10,800원', '10,800원', '1+1']
#
# 🚀 처리 중: image/이마트 바디 (1)\이마트 바디 (9).jpg
# 이미지 열기 성공: image/이마트 바디 (1)\이마트 바디 (9).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "바세린 라벤더 카밍 로션, 400ML, 8801513534224, 14,900원, 14,900원, 식별불가\n아비노 메너자이징 로션, 354ml, 8801108003946, 21,900원, 21,900원, 2개 50%(※교자/일부제외)"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.050538007878074963
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 121
#   total_token_count: 4064
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 바디 (9).jpg):
# '바세린 라벤더 카밍 로션, 400ML, 8801513534224, 14,900원, 14,900원, 식별불가\n아비노 메너자이징 로션, 354ml, 8801108003946, 21,900원, 21,900원, 2개 50%(※교자/일부제외)'
#
# 📌 개별 라인 분석 (이마트 바디 (9).jpg): ['바세린 라벤더 카밍 로션', '400ML', '8801513534224', '14,900원', '14,900원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 바디 (9).jpg): ['아비노 메너자이징 로션', '354ml', '8801108003946', '21,900원', '21,900원', '2개 50%(※교자/일부제외)']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (1).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (1).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "슬릭 모션 쉐이빙폼, 210ml, 식별불가, 6,200원, 3,906원, 37%\n쉬허브 쉐이빙폼, 210ml, 8805385186420, 4,200원, 4,200원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0028427272387172866
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 92
#   total_token_count: 4035
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (1).jpg):
# '슬릭 모션 쉐이빙폼, 210ml, 식별불가, 6,200원, 3,906원, 37%\n쉬허브 쉐이빙폼, 210ml, 8805385186420, 4,200원, 4,200원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 썬 (1).jpg): ['슬릭 모션 쉐이빙폼', '210ml', '식별불가', '6,200원', '3,906원', '37%']
#
# 📌 개별 라인 분석 (이마트 썬 (1).jpg): ['쉬허브 쉐이빙폼', '210ml', '8805385186420', '4,200원', '4,200원', '식별불가']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (10).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (10).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "자차선 크림50G, 식별불가, 8809620751227, 10,490원, 10,490원, 식별불가\n아토앤오투워터쿨선팩트15G, 15G, 8809620751246, 20,980원, 10,490원, S포인트 적립시 할인 2개 20% 추가할인\n아토앤오투베이비썬스틱20GSPF50+PA++++, 식별불가, 8809620752434, 17,980원, 8,990원, S포인트 적립시 할인 2개 20% 추가할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.045648914752620284
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 202
#   total_token_count: 4145
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (10).jpg):
# '자차선 크림50G, 식별불가, 8809620751227, 10,490원, 10,490원, 식별불가\n아토앤오투워터쿨선팩트15G, 15G, 8809620751246, 20,980원, 10,490원, S포인트 적립시 할인 2개 20% 추가할인\n아토앤오투베이비썬스틱20GSPF50+PA++++, 식별불가, 8809620752434, 17,980원, 8,990원, S포인트 적립시 할인 2개 20% 추가할인'
#
# 📌 개별 라인 분석 (이마트 썬 (10).jpg): ['자차선 크림50G', '식별불가', '8809620751227', '10,490원', '10,490원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 썬 (10).jpg): ['아토앤오투워터쿨선팩트15G', '15G', '8809620751246', '20,980원', '10,490원', 'S포인트 적립시 할인 2개 20% 추가할인']
#
# 📌 개별 라인 분석 (이마트 썬 (10).jpg): ['아토앤오투베이비썬스틱20GSPF50+PA++++', '식별불가', '8809620752434', '17,980원', '8,990원', 'S포인트 적립시 할인 2개 20% 추가할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (11).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (11).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "물표전 레이져 벌스크린 100, 35ml, 8809694620417, 27,980원, 16,788원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.019096911930647054
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 61
#   total_token_count: 4004
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (11).jpg):
# '물표전 레이져 벌스크린 100, 35ml, 8809694620417, 27,980원, 16,788원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (11).jpg): ['물표전 레이져 벌스크린 100', '35ml', '8809694620417', '27,980원', '16,788원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (12).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (12).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "밀크바오밥 베이비&키즈 선스틱, 18g, 8802667008694, 12,900원, 7,000원, 식별불가"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0027883952217442648
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (12).jpg):
# '밀크바오밥 베이비&키즈 선스틱, 18g, 8802667008694, 12,900원, 7,000원, 식별불가'
#
# 📌 개별 라인 분석 (이마트 썬 (12).jpg): ['밀크바오밥 베이비&키즈 선스틱', '18g', '8802667008694', '12,900원', '7,000원', '식별불가']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (13).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (13).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아쿠아 선 에센스, 식별불가, 8809340386919, 20,980원, 12,588원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.017918164079839535
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 55
#   total_token_count: 3998
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (13).jpg):
# '아쿠아 선 에센스, 식별불가, 8809340386919, 20,980원, 12,588원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (13).jpg): ['아쿠아 선 에센스', '식별불가', '8809340386919', '20,980원', '12,588원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (14).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (14).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "닥터지 그린마일드 업 선, 35ml, 8809838651307, 25,980원, 15,588원, S포인트 적립시"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0096183962055615014
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (14).jpg):
# '닥터지 그린마일드 업 선, 35ml, 8809838651307, 25,980원, 15,588원, S포인트 적립시'
#
# 📌 개별 라인 분석 (이마트 썬 (14).jpg): ['닥터지 그린마일드 업 선', '35ml', '8809838651307', '25,980원', '15,588원', 'S포인트 적립시']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 5 처리 시작 (파일 41~50)
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (15).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (15).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "닥터지 브라이트닝 선, 35ML, 8809635351210, 25,980원, 15,588원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.07645240851811
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 56
#   total_token_count: 3999
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (15).jpg):
# '닥터지 브라이트닝 선, 35ML, 8809635351210, 25,980원, 15,588원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (15).jpg): ['닥터지 브라이트닝 선', '35ML', '8809635351210', '25,980원', '15,588원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (16).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (16).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "그린핑거 순한 무기자차 선쿠션 12G(시나모, 12G, 8801166407946, 29,980원, 29,980원, 2개 구매시 50% 할인 [교차가능]"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0075215231149624558
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 78
#   total_token_count: 4021
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (16).jpg):
# '그린핑거 순한 무기자차 선쿠션 12G(시나모, 12G, 8801166407946, 29,980원, 29,980원, 2개 구매시 50% 할인 [교차가능]'
#
# 📌 개별 라인 분석 (이마트 썬 (16).jpg): ['그린핑거 순한 무기자차 선쿠션 12G(시나모', '12G', '8801166407946', '29,980원', '29,980원', '2개 구매시 50% 할인 [교차가능]']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (17).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (17).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "그린핑거 이외놀이 워셔블 선팩트 15g 시나, 4.5G, 8801166407939, 식별불가, 29,980원, 2개 구매시 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.032679709835328918
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 69
#   total_token_count: 4012
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (17).jpg):
# '그린핑거 이외놀이 워셔블 선팩트 15g 시나, 4.5G, 8801166407939, 식별불가, 29,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (17).jpg): ['그린핑거 이외놀이 워셔블 선팩트 15g 시나', '4.5G', '8801166407939', '식별불가', '29,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (18).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (18).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "그린핑거 야외놀이 선크림 파워블록 플러스, 식별불가, 8801166405119, 19,980원, 19,980원, 2개 구매시 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -2.4757322693324607e-05
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 69
#   total_token_count: 4012
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (18).jpg):
# '그린핑거 야외놀이 선크림 파워블록 플러스, 식별불가, 8801166405119, 19,980원, 19,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (18).jpg): ['그린핑거 야외놀이 선크림 파워블록 플러스', '식별불가', '8801166405119', '19,980원', '19,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (19).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (19).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "그린핑거 야외놀이 힘센 선크림, 70ml, 8801166404754, 21,980원, 21,980원, 2개 구매시 50% 할인\n그린핑거 순한 무기자차 선쿠션 12G(시나모, 12G, 8801166407946, 29,980원, 29,980원, 2개 구매시 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.022132633388906284
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 138
#   total_token_count: 4081
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (19).jpg):
# '그린핑거 야외놀이 힘센 선크림, 70ml, 8801166404754, 21,980원, 21,980원, 2개 구매시 50% 할인\n그린핑거 순한 무기자차 선쿠션 12G(시나모, 12G, 8801166407946, 29,980원, 29,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (19).jpg): ['그린핑거 야외놀이 힘센 선크림', '70ml', '8801166404754', '21,980원', '21,980원', '2개 구매시 50% 할인']
#
# 📌 개별 라인 분석 (이마트 썬 (19).jpg): ['그린핑거 순한 무기자차 선쿠션 12G(시나모', '12G', '8801166407946', '29,980원', '29,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (2).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (2).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "질레트랩스 래피드포밍쉐이브젤, 198ml, 4987176132284, 15,900원, 11,130원, 6/0정 2\n"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0045116330896105084
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 63
#   total_token_count: 4006
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (2).jpg):
# '질레트랩스 래피드포밍쉐이브젤, 198ml, 4987176132284, 15,900원, 11,130원, 6/0정 2'
#
# 📌 개별 라인 분석 (이마트 썬 (2).jpg): ['질레트랩스 래피드포밍쉐이브젤', '198ml', '4987176132284', '15,900원', '11,130원', '6/0정 2']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (20).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (20).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "바이오더마 포토덤 아쿠아 플루이드 SPF50+, 식별불가, 3701129807385, 31,980원, 15,990원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.0019309976926216712
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 65
#   total_token_count: 4008
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (20).jpg):
# '바이오더마 포토덤 아쿠아 플루이드 SPF50+, 식별불가, 3701129807385, 31,980원, 15,990원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (20).jpg): ['바이오더마 포토덤 아쿠아 플루이드 SPF50+', '식별불가', '3701129807385', '31,980원', '15,990원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (3).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (3).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "본트리 베리션블럭 SPF50+PA++++, 50ml, 2000001211373, 14,980원, 8,988원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.011181291986684331
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 61
#   total_token_count: 4004
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (3).jpg):
# '본트리 베리션블럭 SPF50+PA++++, 50ml, 2000001211373, 14,980원, 8,988원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (3).jpg): ['본트리 베리션블럭 SPF50+PA++++', '50ml', '2000001211373', '14,980원', '8,988원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (4).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (4).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "스트라이덱스 센시티브 패드 55매, 식별불가, 0041388008134, 10,980원, 7,980원, S포인트 적립시 할인\n스트라이덱스 카밍 패드 70매, 식별불가, 8809724701253, 19,980원, 13,980원, S포인트 적립시 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.014229285038583646
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 123
#   total_token_count: 4066
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (4).jpg):
# '스트라이덱스 센시티브 패드 55매, 식별불가, 0041388008134, 10,980원, 7,980원, S포인트 적립시 할인\n스트라이덱스 카밍 패드 70매, 식별불가, 8809724701253, 19,980원, 13,980원, S포인트 적립시 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (4).jpg): ['스트라이덱스 센시티브 패드 55매', '식별불가', '0041388008134', '10,980원', '7,980원', 'S포인트 적립시 할인']
#
# 📌 개별 라인 분석 (이마트 썬 (4).jpg): ['스트라이덱스 카밍 패드 70매', '식별불가', '8809724701253', '19,980원', '13,980원', 'S포인트 적립시 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (5).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (5).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "Here are the results:\n아토팜 톡톡 페이셜 선팩트, 15g, 8809723787128, 24,000원, 24,000원, 2개 구매시 50% 할인\n아토랑 야외놀이 선스틱, 21g, 8809723787142, 24,000원, 24,000원, 2개 구매시 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.025909351028558861
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 131
#   total_token_count: 4074
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (5).jpg):
# 'Here are the results:\n아토팜 톡톡 페이셜 선팩트, 15g, 8809723787128, 24,000원, 24,000원, 2개 구매시 50% 할인\n아토랑 야외놀이 선스틱, 21g, 8809723787142, 24,000원, 24,000원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (5).jpg): ['Here are the results:']
#
# 📌 개별 라인 분석 (이마트 썬 (5).jpg): ['아토팜 톡톡 페이셜 선팩트', '15g', '8809723787128', '24,000원', '24,000원', '2개 구매시 50% 할인']
#
# 📌 개별 라인 분석 (이마트 썬 (5).jpg): ['아토랑 야외놀이 선스틱', '21g', '8809723787142', '24,000원', '24,000원', '2개 구매시 50% 할인']
#
# ⏳ API 사용량 조절을 위해 30초 대기 중...
#
# 🔄 배치 6 처리 시작 (파일 51~54)
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (6).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (6).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "아토팜 야외놀이 선밀크 55g + 클렌징패드, 식별불가, 8809723787111, 28,000원, 28,000원, 50% 할인\n닥터)알로에베라 젤, 150ml, 8801093522133, 33,980원, 33,980원, 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.042075215793046794
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 122
#   total_token_count: 4065
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (6).jpg):
# '아토팜 야외놀이 선밀크 55g + 클렌징패드, 식별불가, 8809723787111, 28,000원, 28,000원, 50% 할인\n닥터)알로에베라 젤, 150ml, 8801093522133, 33,980원, 33,980원, 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (6).jpg): ['아토팜 야외놀이 선밀크 55g + 클렌징패드', '식별불가', '8809723787111', '28,000원', '28,000원', '50% 할인']
#
# 📌 개별 라인 분석 (이마트 썬 (6).jpg): ['닥터)알로에베라 젤', '150ml', '8801093522133', '33,980원', '33,980원', '50% 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (7).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (7).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "Here are the results:\n\n클립램프 영양립밤, 식별불가, 8809278717243, 26,980원, 26,980원, 2개 구매시 50% 할인 [교차가능]\n클립램프 영양립밤, 식별불가, 8809278716802, 26,980원, 26,980원, 2개 구매시 50% 할인 [교차가능]"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.02261422498382791
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 137
#   total_token_count: 4080
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (7).jpg):
# 'Here are the results:\n\n클립램프 영양립밤, 식별불가, 8809278717243, 26,980원, 26,980원, 2개 구매시 50% 할인 [교차가능]\n클립램프 영양립밤, 식별불가, 8809278716802, 26,980원, 26,980원, 2개 구매시 50% 할인 [교차가능]'
#
# 📌 개별 라인 분석 (이마트 썬 (7).jpg): ['Here are the results:']
#
# 📌 개별 라인 분석 (이마트 썬 (7).jpg): ['클립램프 영양립밤', '식별불가', '8809278717243', '26,980원', '26,980원', '2개 구매시 50% 할인 [교차가능]']
#
# 📌 개별 라인 분석 (이마트 썬 (7).jpg): ['클립램프 영양립밤', '식별불가', '8809278716802', '26,980원', '26,980원', '2개 구매시 50% 할인 [교차가능]']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (8).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (8).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "그린핑거 야외놀이 선크림 파워블록 플리스, 식별불가, 8801166405119, 19,980원, 19,980원, 2개 구매시 50% 할인\n그린핑거 야외놀이 워셔블 선크림 BDmlit(시, 식별불가, 8801166407922, 25,980원, 25,980원, 2개 구매시 50% 할인"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.011813570771898542
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 140
#   total_token_count: 4083
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (8).jpg):
# '그린핑거 야외놀이 선크림 파워블록 플리스, 식별불가, 8801166405119, 19,980원, 19,980원, 2개 구매시 50% 할인\n그린핑거 야외놀이 워셔블 선크림 BDmlit(시, 식별불가, 8801166407922, 25,980원, 25,980원, 2개 구매시 50% 할인'
#
# 📌 개별 라인 분석 (이마트 썬 (8).jpg): ['그린핑거 야외놀이 선크림 파워블록 플리스', '식별불가', '8801166405119', '19,980원', '19,980원', '2개 구매시 50% 할인']
#
# 📌 개별 라인 분석 (이마트 썬 (8).jpg): ['그린핑거 야외놀이 워셔블 선크림 BDmlit(시', '식별불가', '8801166407922', '25,980원', '25,980원', '2개 구매시 50% 할인']
#
# 🚀 처리 중: image/이마트 썬 (20)\이마트 썬 (9).jpg
# 이미지 열기 성공: image/이마트 썬 (20)\이마트 썬 (9).jpg, 크기: (4000, 3000)
# 모델 응답: candidates {
#   content {
#     role: "model"
#     parts {
#       text: "GREEN FINGER 야외놀이 선크림 파워블록 플러스, 식별불가, 8801166405119, 19,980원, 19,980원, 식별불가\n아토앤오투 무기자차선 크림, 50G, 8809620751222, 20,980원, 10,490원, S포인트 적립시 할인 2개 20% 추가할인\n"
#     }
#   }
#   finish_reason: STOP
#   avg_logprobs: -0.043302210894497956
# }
# usage_metadata {
#   prompt_token_count: 3943
#   candidates_token_count: 132
#   total_token_count: 4075
# }
# model_version: "gemini-2.0-flash"
#
#
# 📌 반환 텍스트 (이마트 썬 (9).jpg):
# 'GREEN FINGER 야외놀이 선크림 파워블록 플러스, 식별불가, 8801166405119, 19,980원, 19,980원, 식별불가\n아토앤오투 무기자차선 크림, 50G, 8809620751222, 20,980원, 10,490원, S포인트 적립시 할인 2개 20% 추가할인'
#
# 📌 개별 라인 분석 (이마트 썬 (9).jpg): ['GREEN FINGER 야외놀이 선크림 파워블록 플러스', '식별불가', '8801166405119', '19,980원', '19,980원', '식별불가']
#
# 📌 개별 라인 분석 (이마트 썬 (9).jpg): ['아토앤오투 무기자차선 크림', '50G', '8809620751222', '20,980원', '10,490원', 'S포인트 적립시 할인 2개 20% 추가할인']
#
# ✅ 이마트 BDF (9) 카테고리 정보가 이마트 BDF (9).csv 파일에 저장되었습니다.
# 총 21개 상품 정보 처리 완료
#                 파일명             제품명     용량           상품코드   정상가_표시   할인가_표시  \
# 0   이마트 BDF (1).jpg    니베아 모이스춰 립케어   4.8g  4005808517572   5,500원   4,400원
# 1  이마트 BDF (10).jpg   니베아 SOS 바디 로션  400ml  4005808891450  17,820원  17,820원
# 2  이마트 BDF (10).jpg  니베아 인텐시브 바디 로션  400ml  4005808891412  16,020원  16,020원
#
#          할인 내용
# 0  S포인트 적립시 할인
# 1        추천 상품
# 2        추천 상품
#
# ✅ 이마트 바디 (1) 카테고리 정보가 이마트 바디 (1).csv 파일에 저장되었습니다.
# 총 34개 상품 정보 처리 완료
#                파일명                    제품명            용량           상품코드  \
# 0   이마트 바디 (1).jpg  해피바스 퍼퓸부티크 바디로션 상탈머스크  100ml당 2829원  8809925195363
# 1  이마트 바디 (10).jpg            아비노 스릴리프 로션         354ml  9801108003717
# 2  이마트 바디 (10).jpg         아비노 스트레스릴리프 로션         354ml           식별불가
#
#     정상가_표시   할인가_표시             할인 내용
# 0  12,900원   9,900원              할인상품
# 1  21,900원  21,900원  2개 50%(※교자/일부제외)
# 2  21,900원  21,900원    2개50%※교차/일부제외)
#
# ✅ 이마트 썬 (20) 카테고리 정보가 이마트 썬 (20).csv 파일에 저장되었습니다.
# 총 30개 상품 정보 처리 완료
#               파일명         제품명     용량           상품코드   정상가_표시   할인가_표시 할인 내용
# 0   이마트 썬 (1).jpg  슬릭 모션 쉐이빙폼  210ml           식별불가   6,200원   3,906원   37%
# 1   이마트 썬 (1).jpg    쉬허브 쉐이빙폼  210ml  8805385186420   4,200원   4,200원  식별불가
# 2  이마트 썬 (10).jpg   자차선 크림50G   식별불가  8809620751227  10,490원  10,490원  식별불가
#
# ✅ 모든 가격표 정보가 전체_가격표.csv 파일에 저장되었습니다.
# 총 85개 상품 정보 처리 완료
